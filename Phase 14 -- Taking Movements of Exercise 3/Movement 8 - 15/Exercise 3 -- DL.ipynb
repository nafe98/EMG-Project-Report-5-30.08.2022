# %% [markdown]
# # Importing Libraires

# %%
import pandas as pd
from scipy.io import loadmat

# %% [markdown]
# #  Loading Exercise 3

# %%
Exercise_3 = loadmat(r"S1_A1_E3.mat")

# %%
print(Exercise_3)
print("************************************************************************************************************")
print(Exercise_3.keys())
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Mon Jul 28 11:54:18 2014', '__version__': '1.0', '__globals__': [], 'emg': array([[0.0024, 0.0024, 0.0024, ..., 0.0732, 0.0024, 0.0903],
#        [0.0024, 0.0024, 0.0024, ..., 0.0757, 0.0024, 0.0928],
#        [0.0024, 0.0024, 0.0024, ..., 0.0879, 0.0024, 0.0903],
#        ...,
#        [0.0024, 0.0024, 0.0024, ..., 0.0513, 0.127 , 0.0024],
#        [0.0024, 0.0024, 0.0024, ..., 0.0488, 0.1294, 0.0024],
#        [0.0024, 0.0024, 0.0024, ..., 0.0439, 0.1294, 0.0024]]), 'stimulus': array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8), 'glove': array([[152., 137., 111., ..., 139., 134., 108.],
#        [152., 137., 111., ..., 139., 134., 108.],
#        [152., 137., 111., ..., 139., 134., 108.],
#        ...,
#        [152., 131., 114., ..., 124., 133., 120.],
#        [152., 131., 114., ..., 124., 133., 120.],
#        [152., 131., 114., ..., 124., 133., 120.]]), 'subject': array([[1]], dtype=uint8), 'exercise': array([[3]], dtype=uint8), 'repetition': array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8), 'restimulus': array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8), 'rerepetition': array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8)}
# ************************************************************************************************************
# dict_keys(['__header__', '__version__', '__globals__', 'emg', 'stimulus', 'glove', 'subject', 'exercise', 'repetition', 'restimulus', 'rerepetition'])

# %%
emg_3 = Exercise_3['emg']
stimulus_3 = Exercise_3['stimulus']
restimulus_3 = Exercise_3['restimulus']

# %% [markdown]
# # DataFramae

# %%
df_3= pd.DataFrame(emg_3, 
                  columns = ['Emg1','Emg2','Emg3','Emg4','Emg5','Emg6','Emg7','Emg8','Emg9','Emg10'])

# %%
df_3
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 0       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0317  0.0732
# 1       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366  0.0757
# 2       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0415  0.0879
# 3       0.0024  0.0024  0.0049  0.0024  0.0024  0.0024  0.0366  0.0952
# 4       0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0293  0.0952
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 227488  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0562
# 227489  0.0024  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0513
# 227490  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0513
# 227491  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0488
# 227492  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0439
#
#           Emg9   Emg10
# 0       0.0024  0.0903
# 1       0.0024  0.0928
# 2       0.0024  0.0903
# 3       0.0024  0.0830
# 4       0.0024  0.0708
# ...        ...     ...
# 227488  0.1221  0.0024
# 227489  0.1270  0.0024
# 227490  0.1270  0.0024
# 227491  0.1294  0.0024
# 227492  0.1294  0.0024
#
# [227493 rows x 10 columns]

# %%
stimulus_3 = pd.DataFrame(stimulus_3)
restimulus_3 = pd.DataFrame(restimulus_3)

# %% [markdown]
# # Adding new column to existing DataFrame

# %%
df_3['stimulus'] = stimulus_3
df_3['restimulus'] = restimulus_3

# %%
df_3.describe()
# Out:
#                 Emg1           Emg2           Emg3           Emg4  \
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.177020       0.125848       0.195590       0.060284
# std         0.332936       0.303522       0.430584       0.183509
# min         0.002400       0.000000       0.002400       0.000000
# 25%         0.002400       0.002400       0.002400       0.002400
# 50%         0.034200       0.002400       0.002400       0.002400
# 75%         0.195300       0.097700       0.180700       0.034200
# max         4.665500       4.660600       4.658200       4.619100
#
#                 Emg5           Emg6           Emg7           Emg8  \
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.018392       0.018891       0.218081       0.289072
# std         0.038278       0.043190       0.410667       0.346111
# min         0.002400       0.000000       0.002400       0.002400
# 25%         0.002400       0.002400       0.012200       0.087900
# 50%         0.002400       0.002400       0.048800       0.146500
# 75%         0.014600       0.009800       0.231900       0.351600
# max         0.876500       0.632300       4.663100       4.577600
#
#                 Emg9          Emg10       stimulus     restimulus
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.134195       0.057882       6.284220       4.962707
# std         0.248078       0.129270       7.679851       7.434667
# min         0.002400       0.002400       0.000000       0.000000
# 25%         0.002400       0.009800       0.000000       0.000000
# 50%         0.102500       0.036600       2.000000       0.000000
# 75%         0.148900       0.058600      13.000000      10.000000
# max         4.660600       4.628900      23.000000      23.000000

# %% [markdown]
# # Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, classification_report

# %%
raw_data = df_3
raw_data.sample(5)
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 7543    0.0464  0.0024  0.0024  0.0024  0.0024  0.0024  0.0146  0.0952
# 94507   0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0024  0.0684
# 134459  0.0024  0.0024  0.1514  0.0024  0.0342  0.0122  0.0952  0.1880
# 104417  1.0913  0.5005  0.3271  0.0439  0.0146  0.0537  1.4380  1.4355
# 205183  0.0952  0.0024  0.0024  0.0024  0.0024  0.0293  0.5591  0.5981
#
#           Emg9   Emg10  stimulus  restimulus
# 7543    0.0024  0.0391         1           0
# 94507   0.0024  0.0366         0           0
# 134459  0.1758  0.0024        14          14
# 104417  0.1636  0.2490        11          11
# 205183  0.1294  0.0220         0           0

# %%
print("The Shape of the Dataset is : ",raw_data.shape)
print("************************************************************************************************************")
print("Column Names of the Dataset are : ",raw_data.columns)
print("************************************************************************************************************")
print(raw_data.info())
print("************************************************************************************************************")
raw_data.describe(include='all')
# Out:
# The Shape of the Dataset is :  (227493, 12)
# ************************************************************************************************************
# Column Names of the Dataset are :  Index(['Emg1', 'Emg2', 'Emg3', 'Emg4', 'Emg5', 'Emg6', 'Emg7', 'Emg8', 'Emg9',
#        'Emg10', 'stimulus', 'restimulus'],
#       dtype='object')
# ************************************************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227493 entries, 0 to 227492
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Emg1        227493 non-null  float64
#  1   Emg2        227493 non-null  float64
#  2   Emg3        227493 non-null  float64
#  3   Emg4        227493 non-null  float64
#  4   Emg5        227493 non-null  float64
#  5   Emg6        227493 non-null  float64
#  6   Emg7        227493 non-null  float64
#  7   Emg8        227493 non-null  float64
#  8   Emg9        227493 non-null  float64
#  9   Emg10       227493 non-null  float64
#  10  stimulus    227493 non-null  uint8
#  11  restimulus  227493 non-null  uint8
# dtypes: float64(10), uint8(2)
# memory usage: 17.8 MB
# None
# ************************************************************************************************************
#                 Emg1           Emg2           Emg3           Emg4  \
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.177020       0.125848       0.195590       0.060284
# std         0.332936       0.303522       0.430584       0.183509
# min         0.002400       0.000000       0.002400       0.000000
# 25%         0.002400       0.002400       0.002400       0.002400
# 50%         0.034200       0.002400       0.002400       0.002400
# 75%         0.195300       0.097700       0.180700       0.034200
# max         4.665500       4.660600       4.658200       4.619100
#
#                 Emg5           Emg6           Emg7           Emg8  \
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.018392       0.018891       0.218081       0.289072
# std         0.038278       0.043190       0.410667       0.346111
# min         0.002400       0.000000       0.002400       0.002400
# 25%         0.002400       0.002400       0.012200       0.087900
# 50%         0.002400       0.002400       0.048800       0.146500
# 75%         0.014600       0.009800       0.231900       0.351600
# max         0.876500       0.632300       4.663100       4.577600
#
#                 Emg9          Emg10       stimulus     restimulus
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.134195       0.057882       6.284220       4.962707
# std         0.248078       0.129270       7.679851       7.434667
# min         0.002400       0.002400       0.000000       0.000000
# 25%         0.002400       0.009800       0.000000       0.000000
# 50%         0.102500       0.036600       2.000000       0.000000
# 75%         0.148900       0.058600      13.000000      10.000000
# max         4.660600       4.628900      23.000000      23.000000

# %%
print("Unique Dependent values and their counts :")
print(raw_data["stimulus"].value_counts())
# Out:
# Unique Dependent values and their counts :
# 0     108449
# 18      5210
# 20      5202
# 14      5191
# 9       5190
# 19      5189
# 12      5189
# 2       5188
# 13      5186
# 21      5185
# 17      5184
# 10      5182
# 11      5182
# 8       5182
# 7       5177
# 4       5174
# 23      5166
# 16      5165
# 1       5162
# 22      5161
# 15      5161
# 5       5153
# 3       5133
# 6       5132
# Name: stimulus, dtype: int64

# %%
count_classes = pd.value_counts(raw_data['stimulus'], sort = True)

count_classes.plot(kind = 'bar', rot=0)

plt.title("stimulus Class Distribution")

plt.xlabel("Class")

plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
print(raw_data.isnull().any())
# Out:
# Emg1          False
# Emg2          False
# Emg3          False
# Emg4          False
# Emg5          False
# Emg6          False
# Emg7          False
# Emg8          False
# Emg9          False
# Emg10         False
# stimulus      False
# restimulus    False
# dtype: bool

# %% [markdown]
# # Custom Outlier Detection

# %%
index_names = raw_data[ (raw_data['stimulus'] != raw_data['restimulus'])].index
raw_data.drop(index_names, inplace = True)

# %%
raw_data.sample(5)
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 44333   0.0269  0.0024  0.0024  0.0024  0.0024  0.0024  0.0049  0.1074
# 174132  0.0391  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0977
# 41578   0.0586  0.0928  0.7178  0.2954  0.0024  0.0024  0.1294  0.1294
# 38388   0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0171
# 77735   0.3491  0.4468  0.2002  0.1514  0.0220  0.0610  1.2671  0.7227
#
#           Emg9   Emg10  stimulus  restimulus
# 44333   0.0024  0.0342         0           0
# 174132  0.1025  0.0122         0           0
# 41578   0.1953  0.0659         5           5
# 38388   0.0024  0.0391         0           0
# 77735   0.0708  0.0928         8           8

# %%
raw_data.shape
# Out:
# (195668, 12)

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195668 entries, 0 to 227492
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Emg1        195668 non-null  float64
#  1   Emg2        195668 non-null  float64
#  2   Emg3        195668 non-null  float64
#  3   Emg4        195668 non-null  float64
#  4   Emg5        195668 non-null  float64
#  5   Emg6        195668 non-null  float64
#  6   Emg7        195668 non-null  float64
#  7   Emg8        195668 non-null  float64
#  8   Emg9        195668 non-null  float64
#  9   Emg10       195668 non-null  float64
#  10  stimulus    195668 non-null  uint8
#  11  restimulus  195668 non-null  uint8
# dtypes: float64(10), uint8(2)
# memory usage: 16.8 MB

# %%
print(raw_data.isnull().any())
# Out:
# Emg1          False
# Emg2          False
# Emg3          False
# Emg4          False
# Emg5          False
# Emg6          False
# Emg7          False
# Emg8          False
# Emg9          False
# Emg10         False
# stimulus      False
# restimulus    False
# dtype: bool

# %% [markdown]
# # Filtering

# %%
index_names = raw_data[ (raw_data['stimulus'] >=16)].index
raw_data.drop(index_names, inplace = True)

# %%
index_names = raw_data[ (raw_data['stimulus'] <=7)].index
raw_data.drop(index_names, inplace = True)

# %%
raw_data['stimulus'] = raw_data['stimulus'].replace(
    to_replace=[8,9,10,11,12,13,14,15], 
    value=[0,1,2,3,4,5,6,7])
print(raw_data)
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 70124   0.0024  0.0024  0.0024  0.0513  0.0122  0.0024  0.1050  0.1123
# 70125   0.0024  0.0024  0.0171  0.1025  0.0269  0.0024  0.1147  0.1147
# 70126   0.0024  0.0024  0.0439  0.1465  0.0415  0.0073  0.1221  0.1270
# 70127   0.0024  0.0024  0.0537  0.1636  0.0439  0.0122  0.1465  0.1318
# 70128   0.0073  0.0024  0.0562  0.1611  0.0562  0.0122  0.1489  0.1392
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 147202  0.0562  0.0024  0.0024  0.0024  0.0049  0.0024  0.2100  0.3882
# 147203  0.0562  0.0024  0.0024  0.0024  0.0024  0.0024  0.2124  0.3589
# 147204  0.0488  0.0024  0.0024  0.0024  0.0024  0.0024  0.2295  0.3296
# 147205  0.0415  0.0024  0.0049  0.0024  0.0024  0.0024  0.2222  0.3223
# 147206  0.0488  0.0024  0.0024  0.0024  0.0024  0.0024  0.2246  0.3345
#
#           Emg9   Emg10  stimulus  restimulus
# 70124   0.0195  0.0635         0           8
# 70125   0.0415  0.0757         0           8
# 70126   0.0537  0.0757         0           8
# 70127   0.0562  0.0708         0           8
# 70128   0.0488  0.0781         0           8
# ...        ...     ...       ...         ...
# 147202  0.0342  0.0732         7          15
# 147203  0.0317  0.0781         7          15
# 147204  0.0293  0.0830         7          15
# 147205  0.0244  0.0879         7          15
# 147206  0.0220  0.0903         7          15
#
# [29733 rows x 12 columns]

# %%
print("The Shape of the Dataset is : ",raw_data.shape)
print("************************************************************************************************************")
print("Column Names of the Dataset are : ",raw_data.columns)
print("************************************************************************************************************")
print(raw_data.info())
print("************************************************************************************************************")
raw_data.describe(include='all')
# Out:
# The Shape of the Dataset is :  (29733, 12)
# ************************************************************************************************************
# Column Names of the Dataset are :  Index(['Emg1', 'Emg2', 'Emg3', 'Emg4', 'Emg5', 'Emg6', 'Emg7', 'Emg8', 'Emg9',
#        'Emg10', 'stimulus', 'restimulus'],
#       dtype='object')
# ************************************************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29733 entries, 70124 to 147206
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Emg1        29733 non-null  float64
#  1   Emg2        29733 non-null  float64
#  2   Emg3        29733 non-null  float64
#  3   Emg4        29733 non-null  float64
#  4   Emg5        29733 non-null  float64
#  5   Emg6        29733 non-null  float64
#  6   Emg7        29733 non-null  float64
#  7   Emg8        29733 non-null  float64
#  8   Emg9        29733 non-null  float64
#  9   Emg10       29733 non-null  float64
#  10  stimulus    29733 non-null  uint8
#  11  restimulus  29733 non-null  uint8
# dtypes: float64(10), uint8(2)
# memory usage: 2.6 MB
# None
# ************************************************************************************************************
#                Emg1          Emg2          Emg3          Emg4          Emg5  \
# count  29733.000000  29733.000000  29733.000000  29733.000000  29733.000000
# mean       0.359538      0.240909      0.348805      0.073120      0.033312
# std        0.443237      0.388690      0.388804      0.125164      0.038197
# min        0.002400      0.000000      0.002400      0.002400      0.002400
# 25%        0.046400      0.002400      0.051300      0.002400      0.002400
# 50%        0.195300      0.117200      0.224600      0.019500      0.019500
# 75%        0.539600      0.297900      0.520000      0.085400      0.051300
# max        4.663100      4.660600      3.032200      1.340300      0.310100
#
#                Emg6          Emg7          Emg8          Emg9         Emg10  \
# count  29733.000000  29733.000000  29733.000000  29733.000000  29733.000000
# mean       0.042058      0.422707      0.455235      0.165243      0.087657
# std        0.066070      0.482481      0.340311      0.183261      0.127952
# min        0.002400      0.002400      0.007300      0.002400      0.002400
# 25%        0.002400      0.122100      0.219700      0.122100      0.026900
# 50%        0.014600      0.236800      0.358900      0.144000      0.053700
# 75%        0.051300      0.517600      0.590800      0.161100      0.097700
# max        0.632300      3.762200      2.763700      4.655800      3.496100
#
#            stimulus    restimulus
# count  29733.000000  29733.000000
# mean       3.562506     11.562506
# std        2.215571      2.215571
# min        0.000000      8.000000
# 25%        2.000000     10.000000
# 50%        4.000000     12.000000
# 75%        6.000000     14.000000
# max        7.000000     15.000000

# %% [markdown]
# # Initializing Inputs and Outputs Variables

# %%
X = raw_data.iloc[:,0:10]
y = raw_data.stimulus

# %% [markdown]
# # One Hot Encoding

# %%
num_classes = 8

# %%
# One hot encoding for categorical labels
import keras
from keras import utils as np_utils

y = keras.utils.to_categorical(y, num_classes)
#y = keras.utils.np_utils.to_categorical(y, num_classes)

# %%
input_dim = X.shape[1]

# %% [markdown]
# # Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
standardscaler=StandardScaler()

# %%
sc = pd.DataFrame(standardscaler.fit_transform(X))

# %%
sc
# Out:
#               0         1         2         3         4         5         6  \
# 0     -0.805762 -0.613634 -0.890964 -0.174334 -0.552715 -0.600248 -0.658496
# 1     -0.805762 -0.613634 -0.853155  0.234735 -0.167863 -0.600248 -0.638391
# 2     -0.805762 -0.613634 -0.784225  0.586279  0.214371 -0.526083 -0.623053
# 3     -0.805762 -0.613634 -0.759019  0.722902  0.277204 -0.451917 -0.572481
# 4     -0.794707 -0.613634 -0.752589  0.702928  0.599223 -0.451917 -0.567506
# ...         ...       ...       ...       ...       ...       ...       ...
# 29728 -0.684380 -0.613634 -0.890964 -0.565027 -0.743832 -0.600248 -0.440867
# 29729 -0.684380 -0.613634 -0.890964 -0.565027 -0.809283 -0.600248 -0.435893
# 29730 -0.701076 -0.613634 -0.890964 -0.565027 -0.809283 -0.600248 -0.400450
# 29731 -0.717546 -0.613634 -0.884534 -0.565027 -0.809283 -0.600248 -0.415581
# 29732 -0.701076 -0.613634 -0.890964 -0.565027 -0.809283 -0.600248 -0.410606
#
#               7         8         9
# 0     -1.007729 -0.795290 -0.188804
# 1     -1.000676 -0.675241 -0.093454
# 2     -0.964532 -0.608668 -0.093454
# 3     -0.950427 -0.595026 -0.131750
# 4     -0.928682 -0.635406 -0.074697
# ...         ...       ...       ...
# 29728 -0.196985 -0.715075 -0.112993
# 29729 -0.283084 -0.728717 -0.074697
# 29730 -0.369184 -0.741813 -0.036400
# 29731 -0.390635 -0.768552  0.001896
# 29732 -0.354785 -0.781648  0.020654
#
# [29733 rows x 10 columns]

# %% [markdown]
# # Splitting data for training and testing

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 39)

# %% [markdown]
# # Deep Learning Architecture

# %%
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adadelta, Adagrad, Adamax, Nadam, Ftrl

# %% [raw]
# from sklearn.preprocessing import MinMaxScaler
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Input
# from tensorflow.keras.layers import Dense
# from tensorflow.keras.layers import LeakyReLU,ELU
# from tensorflow.keras.layers import BatchNormalization
# from tensorflow.keras.utils import plot_model
# import tensorflow as tf
# from sklearn.model_selection import cross_val_score
# from keras.models import Sequential
# from keras.layers import Dense, BatchNormalization, Dropout
# from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adadelta, Adagrad, Adamax, Nadam, Ftrl
# from keras.callbacks import EarlyStopping, ModelCheckpoint
# from keras.wrappers.scikit_learn import KerasClassifier
# from sklearn.metrics import make_scorer, accuracy_score
# from sklearn.model_selection import StratifiedKFold

# %% [raw]
# from keras.layers import LeakyReLU
# LeakyReLU = LeakyReLU(alpha=0.1)
# from keras.models import Sequential
# from keras.layers import Dense, Flatten, Convolution1D, Dropout
# from keras.initializers import random_uniform

# %% [markdown]
# # 1. Define Network

# %%
num_classes = 8
input_dim = X.shape[1]

# %%
visible = Input(shape=(input_dim,))
hidden1 = Dense(3000, activation='relu')(visible)
hidden2 = Dense(1500, activation='relu')(hidden1)
hidden3 = Dropout(0.2)(hidden2)
hidden4 = Dense(750, activation='relu')(hidden3)
hidden5 = Dense(375, activation='relu')(hidden4)
hidden6 = Dense(48, activation='relu')(hidden5)
output = Dense(num_classes, activation='softmax')(hidden6)
model = Model(inputs=visible, outputs=output)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 10)]              0
#
#  dense (Dense)               (None, 3000)              33000
#
#  dense_1 (Dense)             (None, 1500)              4501500
#
#  dropout (Dropout)           (None, 1500)              0
#
#  dense_2 (Dense)             (None, 750)               1125750
#
#  dense_3 (Dense)             (None, 375)               281625
#
#  dense_4 (Dense)             (None, 48)                18048
#
#  dense_5 (Dense)             (None, 8)                 392
#
# =================================================================
# Total params: 5,960,315
# Trainable params: 5,960,315
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 2. Compile Network

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
plot_model(model, 'EMG_ANN.png', show_shapes = True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# # 3. Fit Network

# %%
import time
start_time = time.time()

history = model.fit(X_train, y_train, batch_size=9000, epochs=300, validation_data = (X_test, y_test))

print (time.time() - start_time, "seconds")
# Out:
# Epoch 1/300
# 3/3 [==============================] - 15s 4s/step - loss: 2.0400 - accuracy: 0.1667 - val_loss: 1.9391 - val_accuracy: 0.3171
# Epoch 2/300
# 3/3 [==============================] - 13s 4s/step - loss: 1.8524 - accuracy: 0.3702 - val_loss: 1.7199 - val_accuracy: 0.4035
# Epoch 3/300
# 3/3 [==============================] - 12s 4s/step - loss: 1.6489 - accuracy: 0.4120 - val_loss: 1.5269 - val_accuracy: 0.4270
# Epoch 4/300
# 3/3 [==============================] - 11s 4s/step - loss: 1.4685 - accuracy: 0.4656 - val_loss: 1.4151 - val_accuracy: 0.4670
# Epoch 5/300
# 3/3 [==============================] - 11s 4s/step - loss: 1.3834 - accuracy: 0.4739 - val_loss: 1.3395 - val_accuracy: 0.4839
# Epoch 6/300
# 3/3 [==============================] - 13s 5s/step - loss: 1.3178 - accuracy: 0.5101 - val_loss: 1.2837 - val_accuracy: 0.5161
# Epoch 7/300
# 3/3 [==============================] - 14s 5s/step - loss: 1.2516 - accuracy: 0.5299 - val_loss: 1.2122 - val_accuracy: 0.5380
# Epoch 8/300
# 3/3 [==============================] - 14s 5s/step - loss: 1.1958 - accuracy: 0.5609 - val_loss: 1.1375 - val_accuracy: 0.5965
# Epoch 9/300
# 3/3 [==============================] - 15s 5s/step - loss: 1.1463 - accuracy: 0.5928 - val_loss: 1.0946 - val_accuracy: 0.6157
# Epoch 10/300
300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0833 - accuracy: 0.9703 - val_loss: 0.1064 - val_accuracy: 0.9613
# Epoch 212/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0777 - accuracy: 0.9736 - val_loss: 0.1084 - val_accuracy: 0.9600
# Epoch 213/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0784 - accuracy: 0.9736 - val_loss: 0.1059 - val_accuracy: 0.9627
# Epoch 214/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0777 - accuracy: 0.9737 - val_loss: 0.1043 - val_accuracy: 0.9620
# Epoch 215/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0799 - accuracy: 0.9731 - val_loss: 0.1059 - val_accuracy: 0.9623
# Epoch 216/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0778 - accuracy: 0.9712 - val_loss: 0.1040 - val_accuracy: 0.9640
# Epoch 217/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0764 - accuracy: 0.9744 - val_loss: 0.1061 - val_accuracy: 0.9654
# Epoch 218/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0759 - accuracy: 0.9731 - val_loss: 0.1028 - val_accuracy: 0.9633
# Epoch 219/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0797 - accuracy: 0.9703 - val_loss: 0.1021 - val_accuracy: 0.9630
# Epoch 220/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0787 - accuracy: 0.9726 - val_loss: 0.1002 - val_accuracy: 0.9677
# Epoch 221/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0739 - accuracy: 0.9752 - val_loss: 0.1014 - val_accuracy: 0.9674
# Epoch 222/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0721 - accuracy: 0.9746 - val_loss: 0.0998 - val_accuracy: 0.9657
# Epoch 223/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0719 - accuracy: 0.9754 - val_loss: 0.1002 - val_accuracy: 0.9677
# Epoch 224/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0702 - accuracy: 0.9759 - val_loss: 0.1027 - val_accuracy: 0.9644
# Epoch 225/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0709 - accuracy: 0.9761 - val_loss: 0.1011 - val_accuracy: 0.9660
# Epoch 226/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0693 - accuracy: 0.9759 - val_loss: 0.0966 - val_accuracy: 0.9681
# Epoch 227/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0658 - accuracy: 0.9778 - val_loss: 0.0971 - val_accuracy: 0.9684
# Epoch 228/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0682 - accuracy: 0.9772 - val_loss: 0.1018 - val_accuracy: 0.9657
# Epoch 229/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0701 - accuracy: 0.9757 - val_loss: 0.0996 - val_accuracy: 0.9670
# Epoch 230/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0689 - accuracy: 0.9763 - val_loss: 0.0990 - val_accuracy: 0.9660
# Epoch 231/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0672 - accuracy: 0.9771 - val_loss: 0.1009 - val_accuracy: 0.9660
# Epoch 232/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0685 - accuracy: 0.9768 - val_loss: 0.0972 - val_accuracy: 0.9684
# Epoch 233/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0675 - accuracy: 0.9771 - val_loss: 0.0984 - val_accuracy: 0.9670
# Epoch 234/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0661 - accuracy: 0.9770 - val_loss: 0.0980 - val_accuracy: 0.9664
# Epoch 235/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0673 - accuracy: 0.9767 - val_loss: 0.0962 - val_accuracy: 0.9670
# Epoch 236/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0673 - accuracy: 0.9764 - val_loss: 0.0988 - val_accuracy: 0.9674
# Epoch 237/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0705 - accuracy: 0.9749 - val_loss: 0.1152 - val_accuracy: 0.9603
# Epoch 238/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0744 - accuracy: 0.9736 - val_loss: 0.1116 - val_accuracy: 0.9644
# Epoch 239/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0743 - accuracy: 0.9734 - val_loss: 0.1008 - val_accuracy: 0.9681
# Epoch 240/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0692 - accuracy: 0.9751 - val_loss: 0.1012 - val_accuracy: 0.9647
# Epoch 241/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0670 - accuracy: 0.9775 - val_loss: 0.0971 - val_accuracy: 0.9670
# Epoch 242/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0664 - accuracy: 0.9774 - val_loss: 0.1002 - val_accuracy: 0.9644
# Epoch 243/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0680 - accuracy: 0.9759 - val_loss: 0.0956 - val_accuracy: 0.9657
# Epoch 244/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0669 - accuracy: 0.9772 - val_loss: 0.1015 - val_accuracy: 0.9681
# Epoch 245/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0654 - accuracy: 0.9776 - val_loss: 0.0944 - val_accuracy: 0.9687
# Epoch 246/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0636 - accuracy: 0.9784 - val_loss: 0.0980 - val_accuracy: 0.9681
# Epoch 247/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0623 - accuracy: 0.9793 - val_loss: 0.0941 - val_accuracy: 0.9721
# Epoch 248/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0627 - accuracy: 0.9791 - val_loss: 0.0920 - val_accuracy: 0.9697
# Epoch 249/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0620 - accuracy: 0.9792 - val_loss: 0.0992 - val_accuracy: 0.9677
# Epoch 250/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0674 - accuracy: 0.9759 - val_loss: 0.0979 - val_accuracy: 0.9681
# Epoch 251/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0638 - accuracy: 0.9776 - val_loss: 0.1015 - val_accuracy: 0.9640
# Epoch 252/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0692 - accuracy: 0.9749 - val_loss: 0.1009 - val_accuracy: 0.9684
# Epoch 253/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0676 - accuracy: 0.9761 - val_loss: 0.1067 - val_accuracy: 0.9633
# Epoch 254/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0729 - accuracy: 0.9733 - val_loss: 0.1069 - val_accuracy: 0.9617
# Epoch 255/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0697 - accuracy: 0.9750 - val_loss: 0.0961 - val_accuracy: 0.9657
# Epoch 256/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0644 - accuracy: 0.9788 - val_loss: 0.1017 - val_accuracy: 0.9684
# Epoch 257/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0633 - accuracy: 0.9779 - val_loss: 0.1001 - val_accuracy: 0.9694
# Epoch 258/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0621 - accuracy: 0.9776 - val_loss: 0.0923 - val_accuracy: 0.9731
# Epoch 259/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0608 - accuracy: 0.9790 - val_loss: 0.0934 - val_accuracy: 0.9704
# Epoch 260/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0602 - accuracy: 0.9790 - val_loss: 0.0941 - val_accuracy: 0.9701
# Epoch 261/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0605 - accuracy: 0.9789 - val_loss: 0.0912 - val_accuracy: 0.9691
# Epoch 262/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0567 - accuracy: 0.9806 - val_loss: 0.0955 - val_accuracy: 0.9687
# Epoch 263/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0575 - accuracy: 0.9800 - val_loss: 0.0923 - val_accuracy: 0.9687
# Epoch 264/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0577 - accuracy: 0.9794 - val_loss: 0.0970 - val_accuracy: 0.9681
# Epoch 265/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0595 - accuracy: 0.9793 - val_loss: 0.0908 - val_accuracy: 0.9721
# Epoch 266/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0588 - accuracy: 0.9801 - val_loss: 0.0942 - val_accuracy: 0.9674
# Epoch 267/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0642 - accuracy: 0.9776 - val_loss: 0.0935 - val_accuracy: 0.9707
# Epoch 268/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0617 - accuracy: 0.9782 - val_loss: 0.0933 - val_accuracy: 0.9694
# Epoch 269/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0613 - accuracy: 0.9777 - val_loss: 0.0983 - val_accuracy: 0.9677
# Epoch 270/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0600 - accuracy: 0.9787 - val_loss: 0.0952 - val_accuracy: 0.9707
# Epoch 271/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.
300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0561 - accuracy: 0.9794 - val_loss: 0.0844 - val_accuracy: 0.9728
# Epoch 300/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.0531 - accuracy: 0.9815 - val_loss: 0.0869 - val_accuracy: 0.9738
# 3389.3083827495575 seconds

# %% [markdown]
# # 4.Evaluate Network

# %% [markdown]
# # 4.1. Plotting Loss and Accuracy¶

# %%
#Loss Curve


plt.plot(figsize = [8,6])

plt.plot(history.history['loss'],'r',linewidth = 3.0)
plt.plot(history.history['val_loss'],'b',linewidth = 3.0)

plt.legend(['Training Loss', 'Validation Loss'], fontsize = 18)

plt.xlabel('Epochs', fontsize = 16)
plt.ylabel('Loss', fontsize = 16)

plt.title('Loss Curve of Deep Neural Netowork' , fontsize = 16 )
# Out:
# Text(0.5, 1.0, 'Loss Curve of Deep Neural Netowork')

# %%
#Accuracy Curve

plt.plot(figsize = [8,6])
plt.plot(history.history['accuracy'],'r',linewidth = 3.0)
plt.plot(history.history['val_accuracy'],'b',linewidth = 3.0)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize = 18)

plt.xlabel('Epochs', fontsize = 16)
plt.ylabel('Accuracy', fontsize = 16)


plt.title('Accuracy Curve of Deep Neural Netowork' , fontsize = 16 )
# Out:
# Text(0.5, 1.0, 'Accuracy Curve of Deep Neural Netowork')

# %% [markdown]
# # 4.2 Make Predictions

# %%
predictions = model.predict(X_test)
predictions = np.argmax(predictions, axis = 1)
# Out:
# 93/93 [==============================] - 2s 14ms/step

# %%
predictions
# Out:
# array([0, 6, 4, ..., 7, 0, 3], dtype=int64)

# %% [markdown]
# # Transforming from One Hot Encoding

# %%
y_test =np.argmax(y_test, axis=1)
y_test[1]
# Out:
# 6

# %%
from sklearn.metrics import accuracy_score
accuracy = {accuracy_score(y_test, predictions)}
print(f"Accuracy is: {accuracy_score(y_test, predictions)* 100}")
# Out:
# Accuracy is: 97.37726967047747

# %% [markdown]
# # 4.3 Classification Report

# %%
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, classification_report
print('\033[1m' +'Classification report : '+ '\033[0m\n', classification_report(y_test, predictions))

cm = confusion_matrix(predictions, y_test)
print('\033[1m' +'Confusion Matrix : '+ '\033[0m')
sns.heatmap(cm, cmap = 'OrRd',annot = True, fmt='d')
plt.show()
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       354
#            1       0.98      0.99      0.98       336
#            2       0.99      0.99      0.99       425
#            3       0.96      0.98      0.97       386
#            4       0.96      0.98      0.97       384
#            5       0.98      0.94      0.96       335
#            6       0.95      0.96      0.95       429
#            7       0.98      0.95      0.97       325
#
#     accuracy                           0.97      2974
#    macro avg       0.97      0.97      0.97      2974
# weighted avg       0.97      0.97      0.97      2974
#
# Confusion Matrix :

# %% [markdown]
# # 4.4 Evaluation

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test,predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 0.0531271015467384
# MSE: 0.16274377942165433
# RMSE: 0.40341514525567124

# %%
from sklearn.metrics import precision_score
print("Precision Score : ",precision_score(y_test, predictions, average='weighted'))


from sklearn.metrics import recall_score
print("Recall Score : ",recall_score(y_test, predictions,average='weighted'))


from sklearn.metrics import f1_score
print("f1_score : ",f1_score(y_test, predictions,average='weighted'))
# Out:
# Precision Score :  0.9739551572598938
# Recall Score :  0.9737726967047747
# f1_score :  0.9737521137988248
