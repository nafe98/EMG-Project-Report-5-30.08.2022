# %% [markdown]
# # Importing Libraires

# %%
import pandas as pd
from scipy.io import loadmat

# %% [markdown]
# #  Loading Exercise 3

# %%
Exercise_3 = loadmat(r"S1_A1_E3.mat")

# %%
print(Exercise_3)
print("************************************************************************************************************")
print(Exercise_3.keys())
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Mon Jul 28 11:54:18 2014', '__version__': '1.0', '__globals__': [], 'emg': array([[0.0024, 0.0024, 0.0024, ..., 0.0732, 0.0024, 0.0903],
#        [0.0024, 0.0024, 0.0024, ..., 0.0757, 0.0024, 0.0928],
#        [0.0024, 0.0024, 0.0024, ..., 0.0879, 0.0024, 0.0903],
#        ...,
#        [0.0024, 0.0024, 0.0024, ..., 0.0513, 0.127 , 0.0024],
#        [0.0024, 0.0024, 0.0024, ..., 0.0488, 0.1294, 0.0024],
#        [0.0024, 0.0024, 0.0024, ..., 0.0439, 0.1294, 0.0024]]), 'stimulus': array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8), 'glove': array([[152., 137., 111., ..., 139., 134., 108.],
#        [152., 137., 111., ..., 139., 134., 108.],
#        [152., 137., 111., ..., 139., 134., 108.],
#        ...,
#        [152., 131., 114., ..., 124., 133., 120.],
#        [152., 131., 114., ..., 124., 133., 120.],
#        [152., 131., 114., ..., 124., 133., 120.]]), 'subject': array([[1]], dtype=uint8), 'exercise': array([[3]], dtype=uint8), 'repetition': array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8), 'restimulus': array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8), 'rerepetition': array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8)}
# ************************************************************************************************************
# dict_keys(['__header__', '__version__', '__globals__', 'emg', 'stimulus', 'glove', 'subject', 'exercise', 'repetition', 'restimulus', 'rerepetition'])

# %%
emg_3 = Exercise_3['emg']
stimulus_3 = Exercise_3['stimulus']
restimulus_3 = Exercise_3['restimulus']

# %% [markdown]
# # DataFramae

# %%
df_3= pd.DataFrame(emg_3, 
                  columns = ['Emg1','Emg2','Emg3','Emg4','Emg5','Emg6','Emg7','Emg8','Emg9','Emg10'])

# %%
df_3
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 0       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0317  0.0732
# 1       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366  0.0757
# 2       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0415  0.0879
# 3       0.0024  0.0024  0.0049  0.0024  0.0024  0.0024  0.0366  0.0952
# 4       0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0293  0.0952
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 227488  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0562
# 227489  0.0024  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0513
# 227490  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0513
# 227491  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0488
# 227492  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0439
#
#           Emg9   Emg10
# 0       0.0024  0.0903
# 1       0.0024  0.0928
# 2       0.0024  0.0903
# 3       0.0024  0.0830
# 4       0.0024  0.0708
# ...        ...     ...
# 227488  0.1221  0.0024
# 227489  0.1270  0.0024
# 227490  0.1270  0.0024
# 227491  0.1294  0.0024
# 227492  0.1294  0.0024
#
# [227493 rows x 10 columns]

# %%
stimulus_3 = pd.DataFrame(stimulus_3)
restimulus_3 = pd.DataFrame(restimulus_3)

# %% [markdown]
# # Adding new column to existing DataFrame

# %%
df_3['stimulus'] = stimulus_3
df_3['restimulus'] = restimulus_3

# %%
df_3.describe()
# Out:
#                 Emg1           Emg2           Emg3           Emg4  \
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.177020       0.125848       0.195590       0.060284
# std         0.332936       0.303522       0.430584       0.183509
# min         0.002400       0.000000       0.002400       0.000000
# 25%         0.002400       0.002400       0.002400       0.002400
# 50%         0.034200       0.002400       0.002400       0.002400
# 75%         0.195300       0.097700       0.180700       0.034200
# max         4.665500       4.660600       4.658200       4.619100
#
#                 Emg5           Emg6           Emg7           Emg8  \
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.018392       0.018891       0.218081       0.289072
# std         0.038278       0.043190       0.410667       0.346111
# min         0.002400       0.000000       0.002400       0.002400
# 25%         0.002400       0.002400       0.012200       0.087900
# 50%         0.002400       0.002400       0.048800       0.146500
# 75%         0.014600       0.009800       0.231900       0.351600
# max         0.876500       0.632300       4.663100       4.577600
#
#                 Emg9          Emg10       stimulus     restimulus
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.134195       0.057882       6.284220       4.962707
# std         0.248078       0.129270       7.679851       7.434667
# min         0.002400       0.002400       0.000000       0.000000
# 25%         0.002400       0.009800       0.000000       0.000000
# 50%         0.102500       0.036600       2.000000       0.000000
# 75%         0.148900       0.058600      13.000000      10.000000
# max         4.660600       4.628900      23.000000      23.000000

# %% [markdown]
# # Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, classification_report

# %%
raw_data = df_3
raw_data.sample(5)
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 226866  0.2075  0.2417  0.0854  0.0488  0.1099  0.0488  0.7446  0.9155
# 151859  0.1978  0.0366  0.3979  0.1880  0.0146  0.0024  0.0269  0.0317
# 193795  0.0146  0.0024  0.0024  0.0024  0.0024  0.0024  0.2539  0.3271
# 227237  0.1440  0.0024  0.0024  0.0024  0.0024  0.0024  0.0073  0.1074
# 33291   0.0293  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0415
#
#           Emg9   Emg10  stimulus  restimulus
# 226866  0.1343  0.0049        23          23
# 151859  0.1294  0.0024        16          16
# 193795  0.0146  0.0049         0           0
# 227237  0.1099  0.0024         0           0
# 33291   0.0024  0.0293         0           0

# %%
print("The Shape of the Dataset is : ",raw_data.shape)
print("************************************************************************************************************")
print("Column Names of the Dataset are : ",raw_data.columns)
print("************************************************************************************************************")
print(raw_data.info())
print("************************************************************************************************************")
raw_data.describe(include='all')
# Out:
# The Shape of the Dataset is :  (227493, 12)
# ************************************************************************************************************
# Column Names of the Dataset are :  Index(['Emg1', 'Emg2', 'Emg3', 'Emg4', 'Emg5', 'Emg6', 'Emg7', 'Emg8', 'Emg9',
#        'Emg10', 'stimulus', 'restimulus'],
#       dtype='object')
# ************************************************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227493 entries, 0 to 227492
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Emg1        227493 non-null  float64
#  1   Emg2        227493 non-null  float64
#  2   Emg3        227493 non-null  float64
#  3   Emg4        227493 non-null  float64
#  4   Emg5        227493 non-null  float64
#  5   Emg6        227493 non-null  float64
#  6   Emg7        227493 non-null  float64
#  7   Emg8        227493 non-null  float64
#  8   Emg9        227493 non-null  float64
#  9   Emg10       227493 non-null  float64
#  10  stimulus    227493 non-null  uint8
#  11  restimulus  227493 non-null  uint8
# dtypes: float64(10), uint8(2)
# memory usage: 17.8 MB
# None
# ************************************************************************************************************
#                 Emg1           Emg2           Emg3           Emg4  \
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.177020       0.125848       0.195590       0.060284
# std         0.332936       0.303522       0.430584       0.183509
# min         0.002400       0.000000       0.002400       0.000000
# 25%         0.002400       0.002400       0.002400       0.002400
# 50%         0.034200       0.002400       0.002400       0.002400
# 75%         0.195300       0.097700       0.180700       0.034200
# max         4.665500       4.660600       4.658200       4.619100
#
#                 Emg5           Emg6           Emg7           Emg8  \
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.018392       0.018891       0.218081       0.289072
# std         0.038278       0.043190       0.410667       0.346111
# min         0.002400       0.000000       0.002400       0.002400
# 25%         0.002400       0.002400       0.012200       0.087900
# 50%         0.002400       0.002400       0.048800       0.146500
# 75%         0.014600       0.009800       0.231900       0.351600
# max         0.876500       0.632300       4.663100       4.577600
#
#                 Emg9          Emg10       stimulus     restimulus
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.134195       0.057882       6.284220       4.962707
# std         0.248078       0.129270       7.679851       7.434667
# min         0.002400       0.002400       0.000000       0.000000
# 25%         0.002400       0.009800       0.000000       0.000000
# 50%         0.102500       0.036600       2.000000       0.000000
# 75%         0.148900       0.058600      13.000000      10.000000
# max         4.660600       4.628900      23.000000      23.000000

# %%
print("Unique Dependent values and their counts :")
print(raw_data["stimulus"].value_counts())
# Out:
# Unique Dependent values and their counts :
# 0     108449
# 18      5210
# 20      5202
# 14      5191
# 9       5190
# 19      5189
# 12      5189
# 2       5188
# 13      5186
# 21      5185
# 17      5184
# 10      5182
# 11      5182
# 8       5182
# 7       5177
# 4       5174
# 23      5166
# 16      5165
# 1       5162
# 22      5161
# 15      5161
# 5       5153
# 3       5133
# 6       5132
# Name: stimulus, dtype: int64

# %%
count_classes = pd.value_counts(raw_data['stimulus'], sort = True)

count_classes.plot(kind = 'bar', rot=0)

plt.title("stimulus Class Distribution")

plt.xlabel("Class")

plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
print(raw_data.isnull().any())
# Out:
# Emg1          False
# Emg2          False
# Emg3          False
# Emg4          False
# Emg5          False
# Emg6          False
# Emg7          False
# Emg8          False
# Emg9          False
# Emg10         False
# stimulus      False
# restimulus    False
# dtype: bool

# %% [markdown]
# # Custom Outlier Detection

# %%
index_names = raw_data[ (raw_data['stimulus'] != raw_data['restimulus'])].index
raw_data.drop(index_names, inplace = True)

# %%
raw_data.sample(5)
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 116745  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0024  0.0391
# 16355   0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0610
# 183008  1.1987  0.1514  0.1245  0.2051  0.0464  0.0220  0.3613  0.7764
# 142515  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366  0.1489
# 219304  0.4541  0.2808  0.4370  0.0146  0.0537  0.0195  0.7520  1.1890
#
#           Emg9   Emg10  stimulus  restimulus
# 116745  0.1001  0.0342         0           0
# 16355   0.0024  0.0488         0           0
# 183008  0.1367  0.0293        19          19
# 142515  0.1074  1.8555         0           0
# 219304  0.1416  0.0220        23          23

# %%
raw_data.shape
# Out:
# (195668, 12)

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195668 entries, 0 to 227492
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Emg1        195668 non-null  float64
#  1   Emg2        195668 non-null  float64
#  2   Emg3        195668 non-null  float64
#  3   Emg4        195668 non-null  float64
#  4   Emg5        195668 non-null  float64
#  5   Emg6        195668 non-null  float64
#  6   Emg7        195668 non-null  float64
#  7   Emg8        195668 non-null  float64
#  8   Emg9        195668 non-null  float64
#  9   Emg10       195668 non-null  float64
#  10  stimulus    195668 non-null  uint8
#  11  restimulus  195668 non-null  uint8
# dtypes: float64(10), uint8(2)
# memory usage: 16.8 MB

# %%
print(raw_data.isnull().any())
# Out:
# Emg1          False
# Emg2          False
# Emg3          False
# Emg4          False
# Emg5          False
# Emg6          False
# Emg7          False
# Emg8          False
# Emg9          False
# Emg10         False
# stimulus      False
# restimulus    False
# dtype: bool

# %% [markdown]
# # Filtering

# %%
index_names = raw_data[ (raw_data['stimulus'] <=15)].index
raw_data.drop(index_names, inplace = True)

# %%
raw_data['stimulus'] = raw_data['stimulus'].replace(
    to_replace=[16,17,18,19,20,21,22,23], 
    value=[0,1,2,3,4,5,6,7])
print(raw_data)
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 149935  0.0024  0.0024  0.0024  0.0024  0.0122  0.0024  0.0562  0.0732
# 149936  0.0024  0.0024  0.0024  0.0024  0.0293  0.0024  0.0586  0.0684
# 149937  0.0024  0.0024  0.0024  0.0024  0.0366  0.0073  0.0610  0.0659
# 149938  0.0024  0.0024  0.0024  0.0024  0.0439  0.0122  0.0684  0.0635
# 149939  0.0024  0.0024  0.0024  0.0024  0.0439  0.0122  0.0708  0.0635
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 227166  0.3320  0.0024  0.0024  0.0024  0.0024  0.0024  0.0854  0.2002
# 227167  0.2832  0.0024  0.0049  0.0024  0.0024  0.0024  0.0732  0.1855
# 227168  0.2319  0.0024  0.0024  0.0024  0.0024  0.0024  0.0562  0.1660
# 227169  0.1855  0.0024  0.0024  0.0049  0.0024  0.0024  0.0415  0.1465
# 227170  0.1587  0.0024  0.0024  0.0024  0.0024  0.0024  0.0317  0.1440
#
#           Emg9   Emg10  stimulus  restimulus
# 149935  0.0610  0.0073         0          16
# 149936  0.0635  0.0098         0          16
# 149937  0.0659  0.0098         0          16
# 149938  0.0684  0.0098         0          16
# 149939  0.0684  0.0098         0          16
# ...        ...     ...       ...         ...
# 227166  0.4492  0.0659         7          23
# 227167  0.4419  0.0610         7          23
# 227168  0.4248  0.0562         7          23
# 227169  0.3882  0.0562         7          23
# 227170  0.3491  0.0537         7          23
#
# [33178 rows x 12 columns]

# %%
print("The Shape of the Dataset is : ",raw_data.shape)
print("************************************************************************************************************")
print("Column Names of the Dataset are : ",raw_data.columns)
print("************************************************************************************************************")
print(raw_data.info())
print("************************************************************************************************************")
raw_data.describe(include='all')
# Out:
# The Shape of the Dataset is :  (33178, 12)
# ************************************************************************************************************
# Column Names of the Dataset are :  Index(['Emg1', 'Emg2', 'Emg3', 'Emg4', 'Emg5', 'Emg6', 'Emg7', 'Emg8', 'Emg9',
#        'Emg10', 'stimulus', 'restimulus'],
#       dtype='object')
# ************************************************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33178 entries, 149935 to 227170
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Emg1        33178 non-null  float64
#  1   Emg2        33178 non-null  float64
#  2   Emg3        33178 non-null  float64
#  3   Emg4        33178 non-null  float64
#  4   Emg5        33178 non-null  float64
#  5   Emg6        33178 non-null  float64
#  6   Emg7        33178 non-null  float64
#  7   Emg8        33178 non-null  float64
#  8   Emg9        33178 non-null  float64
#  9   Emg10       33178 non-null  float64
#  10  stimulus    33178 non-null  uint8
#  11  restimulus  33178 non-null  uint8
# dtypes: float64(10), uint8(2)
# memory usage: 2.8 MB
# None
# ************************************************************************************************************
#                Emg1          Emg2          Emg3          Emg4          Emg5  \
# count  33178.000000  33178.000000  33178.000000  33178.000000  33178.000000
# mean       0.387390      0.360067      0.623597      0.212163      0.053645
# std        0.381667      0.455501      0.771229      0.396664      0.067546
# min        0.002400      0.000000      0.002400      0.002400      0.002400
# 25%        0.139200      0.061000      0.056200      0.009800      0.007300
# 50%        0.278300      0.207500      0.351600      0.068400      0.029300
# 75%        0.527300      0.466300      0.898400      0.207500      0.073200
# max        4.665500      4.072300      4.658200      4.619100      0.876500
#
#                Emg6          Emg7          Emg8          Emg9         Emg10  \
# count  33178.000000  33178.000000  33178.000000  33178.000000  33178.000000
# mean       0.037726      0.486889      0.612211      0.219232      0.061816
# std        0.051747      0.530302      0.454338      0.337351      0.138919
# min        0.002400      0.002400      0.002400      0.002400      0.002400
# 25%        0.002400      0.146500      0.285600      0.136700      0.004900
# 50%        0.017100      0.339400      0.507800      0.151400      0.022000
# 75%        0.051300      0.639600      0.827600      0.173300      0.061000
# max        0.585900      4.663100      4.494600      4.660600      3.950200
#
#            stimulus    restimulus
# count  33178.000000  33178.000000
# mean       3.610163     19.610163
# std        2.320325      2.320325
# min        0.000000     16.000000
# 25%        2.000000     18.000000
# 50%        4.000000     20.000000
# 75%        6.000000     22.000000
# max        7.000000     23.000000

# %% [markdown]
# # Initializing Inputs and Outputs Variables

# %%
X = raw_data.iloc[:,0:10]
y = raw_data.stimulus

# %% [markdown]
# # One Hot Encoding

# %%
num_classes = 8

# %%
# One hot encoding for categorical labels
import keras
from keras import utils as np_utils

#y = keras.utils.to_categorical(y, num_classes)
y = keras.utils.np_utils.to_categorical(y, num_classes)

# %%
input_dim = X.shape[1]

# %% [markdown]
# # Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
standardscaler=StandardScaler()

# %%
sc = pd.DataFrame(standardscaler.fit_transform(X))

# %%
sc
# Out:
#               0         1         2         3         4         5         6  \
# 0     -1.008722 -0.785228 -0.805476 -0.528825 -0.613592 -0.682687 -0.812169
# 1     -1.008722 -0.785228 -0.805476 -0.528825 -0.360426 -0.682687 -0.807643
# 2     -1.008722 -0.785228 -0.805476 -0.528825 -0.252349 -0.587993 -0.803118
# 3     -1.008722 -0.785228 -0.805476 -0.528825 -0.144273 -0.493300 -0.789163
# 4     -1.008722 -0.785228 -0.805476 -0.528825 -0.144273 -0.493300 -0.784637
# ...         ...       ...       ...       ...       ...       ...       ...
# 33173 -0.145129 -0.785228 -0.805476 -0.528825 -0.758681 -0.682687 -0.757105
# 33174 -0.272991 -0.785228 -0.802235 -0.528825 -0.758681 -0.682687 -0.780112
# 33175 -0.407403 -0.785228 -0.805476 -0.528825 -0.758681 -0.682687 -0.812169
# 33176 -0.528977 -0.785228 -0.805476 -0.522523 -0.758681 -0.682687 -0.839890
# 33177 -0.599197 -0.785228 -0.805476 -0.528825 -0.758681 -0.682687 -0.858370
#
#               7         8         9
# 0     -1.186382 -0.469050 -0.392434
# 1     -1.196947 -0.461639 -0.374437
# 2     -1.202449 -0.454525 -0.374437
# 3     -1.207732 -0.447114 -0.374437
# 4     -1.207732 -0.447114 -0.374437
# ...         ...       ...       ...
# 33173 -0.906850  0.681697  0.029401
# 33174 -0.939205  0.660058 -0.005872
# 33175 -0.982126  0.609368 -0.040425
# 33176 -1.025046  0.500874 -0.040425
# 33177 -1.030548  0.384969 -0.058422
#
# [33178 rows x 10 columns]

# %% [markdown]
# # Splitting data for training and testing

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 39)

# %% [markdown]
# # Deep Learning Architecture

# %%
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adadelta, Adagrad, Adamax, Nadam, Ftrl

# %% [raw]
# from sklearn.preprocessing import MinMaxScaler
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Input
# from tensorflow.keras.layers import Dense
# from tensorflow.keras.layers import LeakyReLU,ELU
# from tensorflow.keras.layers import BatchNormalization
# from tensorflow.keras.utils import plot_model
# import tensorflow as tf
# from sklearn.model_selection import cross_val_score
# from keras.models import Sequential
# from keras.layers import Dense, BatchNormalization, Dropout
# from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adadelta, Adagrad, Adamax, Nadam, Ftrl
# from keras.callbacks import EarlyStopping, ModelCheckpoint
# from keras.wrappers.scikit_learn import KerasClassifier
# from sklearn.metrics import make_scorer, accuracy_score
# from sklearn.model_selection import StratifiedKFold

# %% [raw]
# from keras.layers import LeakyReLU
# LeakyReLU = LeakyReLU(alpha=0.1)
# from keras.models import Sequential
# from keras.layers import Dense, Flatten, Convolution1D, Dropout
# from keras.initializers import random_uniform

# %% [markdown]
# # 1. Define Network

# %%
num_classes = 8
input_dim = X.shape[1]

# %%
visible = Input(shape=(input_dim,))
hidden1 = Dense(3000, activation='relu')(visible)
hidden2 = Dense(1500, activation='relu')(hidden1)
hidden3 = Dropout(0.2)(hidden2)
hidden4 = Dense(750, activation='relu')(hidden3)
hidden5 = Dense(375, activation='relu')(hidden4)
hidden6 = Dense(48, activation='relu')(hidden5)
output = Dense(num_classes, activation='softmax')(hidden6)
model = Model(inputs=visible, outputs=output)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 10)]              0
#
#  dense (Dense)               (None, 3000)              33000
#
#  dense_1 (Dense)             (None, 1500)              4501500
#
#  dropout (Dropout)           (None, 1500)              0
#
#  dense_2 (Dense)             (None, 750)               1125750
#
#  dense_3 (Dense)             (None, 375)               281625
#
#  dense_4 (Dense)             (None, 48)                18048
#
#  dense_5 (Dense)             (None, 8)                 392
#
# =================================================================
# Total params: 5,960,315
# Trainable params: 5,960,315
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 2. Compile Network

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
plot_model(model, 'EMG_ANN.png', show_shapes = True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# # 3. Fit Network

# %%
import time
start_time = time.time()

history = model.fit(X_train, y_train, batch_size=9000, epochs=300, validation_data = (X_test, y_test))

print (time.time() - start_time, "seconds")
# Out:
# Epoch 1/300
# 4/4 [==============================] - 14s 3s/step - loss: 2.0072 - accuracy: 0.2022 - val_loss: 1.7819 - val_accuracy: 0.2715
# Epoch 2/300
# 4/4 [==============================] - 12s 3s/step - loss: 1.6957 - accuracy: 0.3045 - val_loss: 1.4894 - val_accuracy: 0.4045
# Epoch 3/300
# 4/4 [==============================] - 12s 3s/step - loss: 1.4499 - accuracy: 0.4457 - val_loss: 1.3303 - val_accuracy: 0.4961
# Epoch 4/300
# 4/4 [==============================] - 13s 3s/step - loss: 1.2717 - accuracy: 0.5384 - val_loss: 1.1823 - val_accuracy: 0.5555
# Epoch 5/300
# 4/4 [==============================] - 12s 3s/step - loss: 1.1602 - accuracy: 0.5701 - val_loss: 1.0880 - val_accuracy: 0.5989
# Epoch 6/300
# 4/4 [==============================] - 12s 3s/step - loss: 1.0663 - accuracy: 0.6089 - val_loss: 0.9979 - val_accuracy: 0.6323
# Epoch 7/300
# 4/4 [==============================] - 13s 3s/step - loss: 0.9752 - accuracy: 0.6479 - val_loss: 0.9217 - val_accuracy: 0.6775
# Epoch 8/300
# 4/4 [==============================] - 12s 3s/step - loss: 0.8940 - accuracy: 0.6862 - val_loss: 0.8453 - val_accuracy: 0.7161
# Epoch 9/300
# 4/4 [==============================] - 13s 3s/step - loss: 0.8346 - accuracy: 0.7081 - val_loss: 0.7688 - val_accuracy: 0.7306
# Epoch 10/300
# 4/4 [==============================] - 12s 3s/step - loss: 0.7781 - accuracy: 0.7256 - val_loss: 0.7331 - val_accuracy: 0.7514
# Epoch 11/300
# 4/4 [==============================] - 13s 3s/step - loss: 0.7347 - accuracy: 0.7403 - val_loss: 0.7069 - val_accuracy: 0.7565
# Epoch 12/300
# 4/4 [==============================] - 12s 3s/step - loss: 0.7099 - accuracy: 0.7503 - val_loss: 0.6853 - val_accuracy: 0.7631
# Epoch 13/300
# 4/4 [==============================] - 12s 3s/step - loss: 0.6872 - accuracy: 0.7562 - val_loss: 0.6514 - val_accuracy: 0.7734
# Epoch 14/300
# 4/4 [==============================] - 12s 3s/step - loss: 0.6560 - accuracy: 0.7670 - val_loss: 0.6202 - val_accuracy: 0.7875
# Epoch 15/300
# 4/4 [==============================] - 12s 3s/step - loss: 0.6286 - accuracy: 0.7766 - val_loss: 0.5921 - val_accuracy: 0.7905
# Epoch 16/300
# 4/4 [==============================] - 12s 3s/step - loss: 0.6071 - accuracy: 0.7856 - val_loss: 0.5835 - val_accuracy: 0.7893
# Epoch 17/300
# 4/4 [==============================] - 12s 3s/step - loss: 0.5880 - accuracy: 0.7895 - val_loss: 0.5641 - val_accuracy: 0.7966
# Epoch 18/300
# 4/4 [==============================] - 13s 3s/step - loss: 0.5699 - accuracy: 0.7973 - val_loss: 0.5453 - val_accuracy: 0.8131
# Epoch 19/300
# 4/4 [==============================] - 13s 3s/step - loss: 0.5547 - accuracy: 0.8015 - val_loss: 0.5288 - val_accuracy: 0.8216
# Epoch 20/300
# 4/4 [==============================] - 12s 3s/step - loss: 0.5492 - accuracy: 0.8051 - val_loss: 0.5188 - val_accuracy: 0.8207
# Epoch 21/300
# 4/4 [==============================] - 12s 3s/step - loss: 0
300
# 4/4 [==============================] - 13s 3s/step - loss: 0.0159 - accuracy: 0.9948 - val_loss: 0.0399 - val_accuracy: 0.9849
# Epoch 300/300
# 4/4 [==============================] - 13s 3s/step - loss: 0.0153 - accuracy: 0.9955 - val_loss: 0.0362 - val_accuracy: 0.9858
# 3794.9378101825714 seconds

# %% [markdown]
# # 4.Evaluate Network

# %% [markdown]
# # 4.1. Plotting Loss and Accuracy¶

# %%
#Loss Curve


plt.plot(figsize = [8,6])

plt.plot(history.history['loss'],'r',linewidth = 3.0)
plt.plot(history.history['val_loss'],'b',linewidth = 3.0)

plt.legend(['Training Loss', 'Validation Loss'], fontsize = 18)

plt.xlabel('Epochs', fontsize = 16)
plt.ylabel('Loss', fontsize = 16)

plt.title('Loss Curve of Deep Neural Netowork' , fontsize = 16 )
# Out:
# Text(0.5, 1.0, 'Loss Curve of Deep Neural Netowork')

# %%
#Accuracy Curve

plt.plot(figsize = [8,6])
plt.plot(history.history['accuracy'],'r',linewidth = 3.0)
plt.plot(history.history['val_accuracy'],'b',linewidth = 3.0)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize = 18)

plt.xlabel('Epochs', fontsize = 16)
plt.ylabel('Accuracy', fontsize = 16)


plt.title('Accuracy Curve of Deep Neural Netowork' , fontsize = 16 )
# Out:
# Text(0.5, 1.0, 'Accuracy Curve of Deep Neural Netowork')

# %% [markdown]
# # 4.2 Make Predictions

# %%
predictions = model.predict(X_test)
predictions = np.argmax(predictions, axis = 1)
# Out:
# 104/104 [==============================] - 2s 15ms/step

# %%
predictions
# Out:
# array([4, 6, 5, ..., 3, 4, 1], dtype=int64)

# %% [markdown]
# # Transforming from One Hot Encoding

# %%
y_test =np.argmax(y_test, axis=1)
y_test[1]
# Out:
# 6

# %%
from sklearn.metrics import accuracy_score
accuracy = {accuracy_score(y_test, predictions)}
print(f"Accuracy is: {accuracy_score(y_test, predictions)* 100}")
# Out:
# Accuracy is: 98.583484026522

# %% [markdown]
# # 4.3 Classification Report

# %%
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, classification_report
print('\033[1m' +'Classification report : '+ '\033[0m\n', classification_report(y_test, predictions))

cm = confusion_matrix(predictions, y_test)
print('\033[1m' +'Confusion Matrix : '+ '\033[0m')
sns.heatmap(cm, cmap = 'OrRd',annot = True, fmt='d')
plt.show()
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99       431
#            1       0.97      0.99      0.98       357
#            2       0.97      0.98      0.97       379
#            3       0.98      1.00      0.99       409
#            4       1.00      0.99      1.00       379
#            5       0.98      0.98      0.98       436
#            6       0.99      0.98      0.98       470
#            7       1.00      1.00      1.00       457
#
#     accuracy                           0.99      3318
#    macro avg       0.99      0.99      0.99      3318
# weighted avg       0.99      0.99      0.99      3318
#
# Confusion Matrix :

# %% [markdown]
# # 4.4 Evaluation

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test,predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 0.03285111512959614
# MSE: 0.11301989150090416
# RMSE: 0.3361843118006909

# %%
from sklearn.metrics import precision_score
print("Precision Score : ",precision_score(y_test, predictions, average='weighted'))


from sklearn.metrics import recall_score
print("Recall Score : ",recall_score(y_test, predictions,average='weighted'))


from sklearn.metrics import f1_score
print("f1_score : ",f1_score(y_test, predictions,average='weighted'))
# Out:
# Precision Score :  0.9859368871393852
# Recall Score :  0.9858348402652201
# f1_score :  0.9858469000045068
