# %% [markdown]
# # Importing Libraires

# %%
import pandas as pd
from scipy.io import loadmat

# %% [markdown]
# #  Loading Exercise 3

# %%
Exercise_3 = loadmat(r"S1_A1_E3.mat")

# %%
print(Exercise_3)
print("************************************************************************************************************")
print(Exercise_3.keys())
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Mon Jul 28 11:54:18 2014', '__version__': '1.0', '__globals__': [], 'emg': array([[0.0024, 0.0024, 0.0024, ..., 0.0732, 0.0024, 0.0903],
#        [0.0024, 0.0024, 0.0024, ..., 0.0757, 0.0024, 0.0928],
#        [0.0024, 0.0024, 0.0024, ..., 0.0879, 0.0024, 0.0903],
#        ...,
#        [0.0024, 0.0024, 0.0024, ..., 0.0513, 0.127 , 0.0024],
#        [0.0024, 0.0024, 0.0024, ..., 0.0488, 0.1294, 0.0024],
#        [0.0024, 0.0024, 0.0024, ..., 0.0439, 0.1294, 0.0024]]), 'stimulus': array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8), 'glove': array([[152., 137., 111., ..., 139., 134., 108.],
#        [152., 137., 111., ..., 139., 134., 108.],
#        [152., 137., 111., ..., 139., 134., 108.],
#        ...,
#        [152., 131., 114., ..., 124., 133., 120.],
#        [152., 131., 114., ..., 124., 133., 120.],
#        [152., 131., 114., ..., 124., 133., 120.]]), 'subject': array([[1]], dtype=uint8), 'exercise': array([[3]], dtype=uint8), 'repetition': array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8), 'restimulus': array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8), 'rerepetition': array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8)}
# ************************************************************************************************************
# dict_keys(['__header__', '__version__', '__globals__', 'emg', 'stimulus', 'glove', 'subject', 'exercise', 'repetition', 'restimulus', 'rerepetition'])

# %%
emg_3 = Exercise_3['emg']
stimulus_3 = Exercise_3['stimulus']
restimulus_3 = Exercise_3['restimulus']

# %% [markdown]
# # DataFramae

# %%
df_3= pd.DataFrame(emg_3, 
                  columns = ['Emg1','Emg2','Emg3','Emg4','Emg5','Emg6','Emg7','Emg8','Emg9','Emg10'])

# %%
df_3
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 0       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0317  0.0732
# 1       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366  0.0757
# 2       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0415  0.0879
# 3       0.0024  0.0024  0.0049  0.0024  0.0024  0.0024  0.0366  0.0952
# 4       0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0293  0.0952
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 227488  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0562
# 227489  0.0024  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0513
# 227490  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0513
# 227491  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0488
# 227492  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0439
#
#           Emg9   Emg10
# 0       0.0024  0.0903
# 1       0.0024  0.0928
# 2       0.0024  0.0903
# 3       0.0024  0.0830
# 4       0.0024  0.0708
# ...        ...     ...
# 227488  0.1221  0.0024
# 227489  0.1270  0.0024
# 227490  0.1270  0.0024
# 227491  0.1294  0.0024
# 227492  0.1294  0.0024
#
# [227493 rows x 10 columns]

# %%
stimulus_3 = pd.DataFrame(stimulus_3)
restimulus_3 = pd.DataFrame(restimulus_3)

# %% [markdown]
# # Adding new column to existing DataFrame

# %%
df_3['stimulus'] = stimulus_3
df_3['restimulus'] = restimulus_3

# %%
df_3.describe()
# Out:
#                 Emg1           Emg2           Emg3           Emg4  \
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.177020       0.125848       0.195590       0.060284
# std         0.332936       0.303522       0.430584       0.183509
# min         0.002400       0.000000       0.002400       0.000000
# 25%         0.002400       0.002400       0.002400       0.002400
# 50%         0.034200       0.002400       0.002400       0.002400
# 75%         0.195300       0.097700       0.180700       0.034200
# max         4.665500       4.660600       4.658200       4.619100
#
#                 Emg5           Emg6           Emg7           Emg8  \
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.018392       0.018891       0.218081       0.289072
# std         0.038278       0.043190       0.410667       0.346111
# min         0.002400       0.000000       0.002400       0.002400
# 25%         0.002400       0.002400       0.012200       0.087900
# 50%         0.002400       0.002400       0.048800       0.146500
# 75%         0.014600       0.009800       0.231900       0.351600
# max         0.876500       0.632300       4.663100       4.577600
#
#                 Emg9          Emg10       stimulus     restimulus
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.134195       0.057882       6.284220       4.962707
# std         0.248078       0.129270       7.679851       7.434667
# min         0.002400       0.002400       0.000000       0.000000
# 25%         0.002400       0.009800       0.000000       0.000000
# 50%         0.102500       0.036600       2.000000       0.000000
# 75%         0.148900       0.058600      13.000000      10.000000
# max         4.660600       4.628900      23.000000      23.000000

# %% [markdown]
# # Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, classification_report

# %%
raw_data = df_3
raw_data.sample(5)
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 170752  0.0024  0.0024  0.2930  0.0562  0.0024  0.0024  0.0024  0.1465
# 46383   0.0464  0.3687  0.4248  0.0146  0.1025  0.0684  0.1318  0.0977
# 155088  0.1025  0.1587  0.5957  0.2808  0.0488  0.0049  0.2368  0.0830
# 75517   0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0391  0.1074
# 199952  0.0903  0.0220  0.0293  0.1660  0.0024  0.0073  0.2368  0.2832
#
#           Emg9   Emg10  stimulus  restimulus
# 170752  0.1001  0.0024         0           0
# 46383   0.2148  0.0830         5           5
# 155088  0.1563  0.0024        16          16
# 75517   0.0024  0.0146         8           0
# 199952  0.1465  0.0488         0           0

# %%
print("The Shape of the Dataset is : ",raw_data.shape)
print("************************************************************************************************************")
print("Column Names of the Dataset are : ",raw_data.columns)
print("************************************************************************************************************")
print(raw_data.info())
print("************************************************************************************************************")
raw_data.describe(include='all')
# Out:
# The Shape of the Dataset is :  (227493, 12)
# ************************************************************************************************************
# Column Names of the Dataset are :  Index(['Emg1', 'Emg2', 'Emg3', 'Emg4', 'Emg5', 'Emg6', 'Emg7', 'Emg8', 'Emg9',
#        'Emg10', 'stimulus', 'restimulus'],
#       dtype='object')
# ************************************************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227493 entries, 0 to 227492
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Emg1        227493 non-null  float64
#  1   Emg2        227493 non-null  float64
#  2   Emg3        227493 non-null  float64
#  3   Emg4        227493 non-null  float64
#  4   Emg5        227493 non-null  float64
#  5   Emg6        227493 non-null  float64
#  6   Emg7        227493 non-null  float64
#  7   Emg8        227493 non-null  float64
#  8   Emg9        227493 non-null  float64
#  9   Emg10       227493 non-null  float64
#  10  stimulus    227493 non-null  uint8
#  11  restimulus  227493 non-null  uint8
# dtypes: float64(10), uint8(2)
# memory usage: 17.8 MB
# None
# ************************************************************************************************************
#                 Emg1           Emg2           Emg3           Emg4  \
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.177020       0.125848       0.195590       0.060284
# std         0.332936       0.303522       0.430584       0.183509
# min         0.002400       0.000000       0.002400       0.000000
# 25%         0.002400       0.002400       0.002400       0.002400
# 50%         0.034200       0.002400       0.002400       0.002400
# 75%         0.195300       0.097700       0.180700       0.034200
# max         4.665500       4.660600       4.658200       4.619100
#
#                 Emg5           Emg6           Emg7           Emg8  \
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.018392       0.018891       0.218081       0.289072
# std         0.038278       0.043190       0.410667       0.346111
# min         0.002400       0.000000       0.002400       0.002400
# 25%         0.002400       0.002400       0.012200       0.087900
# 50%         0.002400       0.002400       0.048800       0.146500
# 75%         0.014600       0.009800       0.231900       0.351600
# max         0.876500       0.632300       4.663100       4.577600
#
#                 Emg9          Emg10       stimulus     restimulus
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.134195       0.057882       6.284220       4.962707
# std         0.248078       0.129270       7.679851       7.434667
# min         0.002400       0.002400       0.000000       0.000000
# 25%         0.002400       0.009800       0.000000       0.000000
# 50%         0.102500       0.036600       2.000000       0.000000
# 75%         0.148900       0.058600      13.000000      10.000000
# max         4.660600       4.628900      23.000000      23.000000

# %%
print("Unique Dependent values and their counts :")
print(raw_data["stimulus"].value_counts())
# Out:
# Unique Dependent values and their counts :
# 0     108449
# 18      5210
# 20      5202
# 14      5191
# 9       5190
# 19      5189
# 12      5189
# 2       5188
# 13      5186
# 21      5185
# 17      5184
# 10      5182
# 11      5182
# 8       5182
# 7       5177
# 4       5174
# 23      5166
# 16      5165
# 1       5162
# 22      5161
# 15      5161
# 5       5153
# 3       5133
# 6       5132
# Name: stimulus, dtype: int64

# %%
count_classes = pd.value_counts(raw_data['stimulus'], sort = True)

count_classes.plot(kind = 'bar', rot=0)

plt.title("stimulus Class Distribution")

plt.xlabel("Class")

plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
print(raw_data.isnull().any())
# Out:
# Emg1          False
# Emg2          False
# Emg3          False
# Emg4          False
# Emg5          False
# Emg6          False
# Emg7          False
# Emg8          False
# Emg9          False
# Emg10         False
# stimulus      False
# restimulus    False
# dtype: bool

# %% [markdown]
# # Custom Outlier Detection

# %%
index_names = raw_data[ (raw_data['stimulus'] != raw_data['restimulus'])].index
raw_data.drop(index_names, inplace = True)

# %%
raw_data.sample(5)
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 60380   0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0073  0.0586
# 150504  0.0781  0.0024  0.0024  0.0024  0.0024  0.0024  0.0562  0.2319
# 98076   0.0049  0.0024  0.0049  0.0024  0.0024  0.0024  0.0122  0.0732
# 115852  0.0122  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0952
# 164335  0.0098  0.0024  0.0024  0.0024  0.0024  0.0024  0.0049  0.0977
#
#           Emg9   Emg10  stimulus  restimulus
# 60380   0.0024  0.0513         0           0
# 150504  0.7056  0.0024         0           0
# 98076   0.0024  0.0537         0           0
# 115852  0.1392  0.0464         0           0
# 164335  0.0171  0.1147         0           0

# %%
raw_data.shape
# Out:
# (195668, 12)

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195668 entries, 0 to 227492
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Emg1        195668 non-null  float64
#  1   Emg2        195668 non-null  float64
#  2   Emg3        195668 non-null  float64
#  3   Emg4        195668 non-null  float64
#  4   Emg5        195668 non-null  float64
#  5   Emg6        195668 non-null  float64
#  6   Emg7        195668 non-null  float64
#  7   Emg8        195668 non-null  float64
#  8   Emg9        195668 non-null  float64
#  9   Emg10       195668 non-null  float64
#  10  stimulus    195668 non-null  uint8
#  11  restimulus  195668 non-null  uint8
# dtypes: float64(10), uint8(2)
# memory usage: 16.8 MB

# %%
print(raw_data.isnull().any())
# Out:
# Emg1          False
# Emg2          False
# Emg3          False
# Emg4          False
# Emg5          False
# Emg6          False
# Emg7          False
# Emg8          False
# Emg9          False
# Emg10         False
# stimulus      False
# restimulus    False
# dtype: bool

# %% [markdown]
# # Filtering

# %%
index_names = raw_data[ (raw_data['stimulus'] >=8)].index
raw_data.drop(index_names, inplace = True)

# %%
print("The Shape of the Dataset is : ",raw_data.shape)
print("************************************************************************************************************")
print("Column Names of the Dataset are : ",raw_data.columns)
print("************************************************************************************************************")
print(raw_data.info())
print("************************************************************************************************************")
raw_data.describe(include='all')
# Out:
# The Shape of the Dataset is :  (132757, 12)
# ************************************************************************************************************
# Column Names of the Dataset are :  Index(['Emg1', 'Emg2', 'Emg3', 'Emg4', 'Emg5', 'Emg6', 'Emg7', 'Emg8', 'Emg9',
#        'Emg10', 'stimulus', 'restimulus'],
#       dtype='object')
# ************************************************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 132757 entries, 0 to 227492
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Emg1        132757 non-null  float64
#  1   Emg2        132757 non-null  float64
#  2   Emg3        132757 non-null  float64
#  3   Emg4        132757 non-null  float64
#  4   Emg5        132757 non-null  float64
#  5   Emg6        132757 non-null  float64
#  6   Emg7        132757 non-null  float64
#  7   Emg8        132757 non-null  float64
#  8   Emg9        132757 non-null  float64
#  9   Emg10       132757 non-null  float64
#  10  stimulus    132757 non-null  uint8
#  11  restimulus  132757 non-null  uint8
# dtypes: float64(10), uint8(2)
# memory usage: 11.4 MB
# None
# ************************************************************************************************************
#                 Emg1           Emg2           Emg3           Emg4  \
# count  132757.000000  132757.000000  132757.000000  132757.000000
# mean        0.113758       0.068330       0.094655       0.030999
# std         0.283599       0.218214       0.248163       0.080806
# min         0.002400       0.000000       0.002400       0.002400
# 25%         0.002400       0.002400       0.002400       0.002400
# 50%         0.014600       0.002400       0.002400       0.002400
# 75%         0.085400       0.002400       0.004900       0.002400
# max         3.979500       3.557100       3.078600       1.684600
#
#                 Emg5           Emg6           Emg7           Emg8  \
# count  132757.000000  132757.000000  132757.000000  132757.000000
# mean        0.009457       0.012295       0.140228       0.205725
# std         0.022586       0.034471       0.345399       0.280495
# min         0.002400       0.000000       0.002400       0.002400
# 25%         0.002400       0.002400       0.004900       0.078100
# 50%         0.002400       0.002400       0.026900       0.117200
# 75%         0.002400       0.002400       0.075700       0.197800
# max         0.461400       0.603000       4.663100       4.577600
#
#                 Emg9          Emg10       stimulus     restimulus
# count  132757.000000  132757.000000  132757.000000  132757.000000
# mean        0.112879       0.050857       0.784825       0.784825
# std         0.220445       0.111772       1.812565       1.812565
# min         0.002400       0.002400       0.000000       0.000000
# 25%         0.002400       0.009800       0.000000       0.000000
# 50%         0.070800       0.036600       0.000000       0.000000
# 75%         0.124500       0.053700       0.000000       0.000000
# max         4.658200       4.231000       7.000000       7.000000

# %% [markdown]
# # Initializing Inputs and Outputs Variables

# %%
X = raw_data.iloc[:,0:10]
y = raw_data.stimulus

# %% [markdown]
# # One Hot Encoding

# %%
num_classes = 8

# %%
# One hot encoding for categorical labels
import keras
from keras import utils as np_utils

#y = keras.utils.to_categorical(y, num_classes)
y = keras.utils.np_utils.to_categorical(y, num_classes)

# %%
input_dim = X.shape[1]

# %% [markdown]
# # Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
standardscaler=StandardScaler()

# %%
sc = pd.DataFrame(standardscaler.fit_transform(X))

# %%
sc
# Out:
#               0         1         2         3         4         5         6  \
# 0      -0.39266 -0.302134 -0.371755 -0.353917 -0.312441 -0.287070 -0.314211
# 1      -0.39266 -0.302134 -0.371755 -0.353917 -0.312441 -0.287070 -0.300024
# 2      -0.39266 -0.302134 -0.371755 -0.353917 -0.312441 -0.287070 -0.285838
# 3      -0.39266 -0.302134 -0.361681 -0.353917 -0.312441 -0.287070 -0.300024
# 4      -0.39266 -0.302134 -0.371755 -0.353917 -0.201753 -0.287070 -0.321159
# ...         ...       ...       ...       ...       ...       ...       ...
# 132752 -0.39266 -0.302134 -0.371755 -0.353917 -0.312441 -0.287070 -0.399041
# 132753 -0.39266 -0.302134 -0.371755 -0.353917 -0.312441 -0.214545 -0.399041
# 132754 -0.39266 -0.302134 -0.371755 -0.353917 -0.312441 -0.287070 -0.399041
# 132755 -0.39266 -0.302134 -0.371755 -0.353917 -0.312441 -0.287070 -0.399041
# 132756 -0.39266 -0.302134 -0.371755 -0.353917 -0.312441 -0.287070 -0.399041
#
#                7         8         9
# 0      -0.472469 -0.501168  0.352891
# 1      -0.463556 -0.501168  0.375258
# 2      -0.420062 -0.501168  0.352891
# 3      -0.394036 -0.501168  0.287579
# 4      -0.394036 -0.501168  0.178429
# ...          ...       ...       ...
# 132752 -0.533076  0.041828 -0.433531
# 132753 -0.550546  0.064056 -0.433531
# 132754 -0.550546  0.064056 -0.433531
# 132755 -0.559459  0.074943 -0.433531
# 132756 -0.576928  0.074943 -0.433531
#
# [132757 rows x 10 columns]

# %% [markdown]
# # Splitting data for training and testing

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 39)

# %% [markdown]
# # Deep Learning Architecture

# %%
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adadelta, Adagrad, Adamax, Nadam, Ftrl

# %% [raw]
# from sklearn.preprocessing import MinMaxScaler
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Input
# from tensorflow.keras.layers import Dense
# from tensorflow.keras.layers import LeakyReLU,ELU
# from tensorflow.keras.layers import BatchNormalization
# from tensorflow.keras.utils import plot_model
# import tensorflow as tf
# from sklearn.model_selection import cross_val_score
# from keras.models import Sequential
# from keras.layers import Dense, BatchNormalization, Dropout
# from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adadelta, Adagrad, Adamax, Nadam, Ftrl
# from keras.callbacks import EarlyStopping, ModelCheckpoint
# from keras.wrappers.scikit_learn import KerasClassifier
# from sklearn.metrics import make_scorer, accuracy_score
# from sklearn.model_selection import StratifiedKFold

# %% [raw]
# from keras.layers import LeakyReLU
# LeakyReLU = LeakyReLU(alpha=0.1)
# from keras.models import Sequential
# from keras.layers import Dense, Flatten, Convolution1D, Dropout
# from keras.initializers import random_uniform

# %% [markdown]
# # 1. Define Network

# %%
num_classes = 8
input_dim = X.shape[1]

# %%
visible = Input(shape=(input_dim,))
hidden1 = Dense(3000, activation='relu')(visible)
hidden2 = Dense(1500, activation='relu')(hidden1)
hidden3 = Dropout(0.2)(hidden2)
hidden4 = Dense(750, activation='relu')(hidden3)
hidden5 = Dense(375, activation='relu')(hidden4)
hidden6 = Dense(48, activation='relu')(hidden5)
output = Dense(num_classes, activation='softmax')(hidden6)
model = Model(inputs=visible, outputs=output)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 10)]              0
#
#  dense (Dense)               (None, 3000)              33000
#
#  dense_1 (Dense)             (None, 1500)              4501500
#
#  dropout (Dropout)           (None, 1500)              0
#
#  dense_2 (Dense)             (None, 750)               1125750
#
#  dense_3 (Dense)             (None, 375)               281625
#
#  dense_4 (Dense)             (None, 48)                18048
#
#  dense_5 (Dense)             (None, 8)                 392
#
# =================================================================
# Total params: 5,960,315
# Trainable params: 5,960,315
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 2. Compile Network

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
plot_model(model, 'EMG_ANN.png', show_shapes = True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# # 3. Fit Network

# %%
import time
start_time = time.time()

history = model.fit(X_train, y_train, batch_size=9000, epochs=300, validation_data = (X_test, y_test))

print (time.time() - start_time, "seconds")
# Out:
# Epoch 1/300
# 14/14 [==============================] - 53s 4s/step - loss: 1.1329 - accuracy: 0.7632 - val_loss: 0.5480 - val_accuracy: 0.8265
# Epoch 2/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.5137 - accuracy: 0.8214 - val_loss: 0.4608 - val_accuracy: 0.8415
# Epoch 3/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.4468 - accuracy: 0.8459 - val_loss: 0.4183 - val_accuracy: 0.8564
# Epoch 4/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.4031 - accuracy: 0.8641 - val_loss: 0.3736 - val_accuracy: 0.8735
# Epoch 5/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.3591 - accuracy: 0.8785 - val_loss: 0.3386 - val_accuracy: 0.8839
# Epoch 6/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.3246 - accuracy: 0.8929 - val_loss: 0.3009 - val_accuracy: 0.8993
# Epoch 7/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.2944 - accuracy: 0.9029 - val_loss: 0.2724 - val_accuracy: 0.9102
# Epoch 8/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.2723 - accuracy: 0.9107 - val_loss: 0.2596 - val_accuracy: 0.9176
# Epoch 9/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.2519 - accuracy: 0.9181 - val_loss: 0.2354 - val_accuracy: 0.9225
# Epoch 10/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.2441 - accuracy: 0.9215 - val_loss: 0.2234 - val_accuracy: 0.9255
# Epoch 11/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.2293 - accuracy: 0.9259 - val_loss: 0.2184 - val_accuracy: 0.9283
# Epoch 12/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.2151 - accuracy: 0.9304 - val_loss: 0.2039 - val_accuracy: 0.9328
# Epoch 13/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.2098 - accuracy: 0.9328 - val_loss: 0.2180 - val_accuracy: 0.9313
# Epoch 14/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.2080 - accuracy: 0.9334 - val_loss: 0.2044 - val_accuracy: 0.9357
# Epoch 15/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.1953 - accuracy: 0.9381 - val_loss: 0.1839 - val_accuracy: 0.9424
# Epoch 16/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.1858 - accuracy: 0.9409 - val_loss: 0.1848 - val_accuracy: 0.9425
# Epoch 17/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.1823 - accuracy: 0.9417 - val_loss: 0.1745 - val_accuracy: 0.9446
# Epoch 18/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.1742 - accuracy: 0.9450 - val_loss: 0.1758 - val_accuracy: 0.9454
# Epoch 19/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.1762 - accuracy: 0.9451 - val_loss: 0.1907 - val_accuracy: 0.9449
# Epoch 20/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.1807 - accuracy: 0.9445 - val_loss: 0.1731 - val_accuracy: 0.9451
# Epoch 21/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.1630 - accuracy: 0.9484 - val_loss: 0.1541 - val_accuracy: 0.9509
# Epoch 22/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.1574 - accuracy: 0.9498 - val_loss: 0.1534 - val_accuracy: 0.9528
# Epoch 23/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.1514 - accuracy: 0.9514 - val_loss: 0.1470 - val_accuracy: 0.9531
# Epoch 24/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.1457 - accuracy: 0.9539 - val_loss: 0.1437 - val_accuracy: 0.9531
# Epoch 25/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.1451 - accuracy: 0.9543 - val_loss: 0.1597 - val_accuracy: 0.9522
# Epoch 26/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.1627 - accuracy: 0.9507 - val_loss: 0.1548 - val_accuracy: 0.9507
# Epoch 27/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.1507 - accuracy: 0.9520 - val_loss: 0.1423 - val_accuracy: 0.9553
# Epoch 28/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.1366 - accuracy: 0.9572 - val_loss: 0.1308 - val_accuracy: 0.9586
# Epoch 29/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.1294 - accuracy: 0.9594 - val_loss: 0.1302 - val_accuracy: 0.9593
# Epoch 30/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.1273 - accuracy: 0.9599 - val_loss: 0.1261 - val_accuracy: 0.9605
# Epoch 31/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.1241 - accuracy: 0.9613 - val_loss: 0.1251 - val_accuracy: 0.9599
# Epoch 32/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.1228 - accuracy: 0.9609 - val_loss: 0.1220 - val_accuracy: 0.9623
# Epoch 33/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.1189 - accuracy: 0.9630 - val_loss: 0.1219 - val_accuracy: 0.9615
# Epoch 34/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.1186 - accuracy: 0.9629 - val_loss: 0.1212 - val_accuracy: 0.9626
# Epoch 35/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.1143 - accuracy: 0.9644 - val_loss: 0.1145 - val_accuracy: 0.9632
# Epoch 36/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.1095 - accuracy: 0.9657 - val_loss: 0.1134 - val_accuracy: 0.9641
# Epoch 37/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.1071 - accuracy: 0.9666 - val_loss: 0.1102 - val_accuracy: 0.9665
# Epoch 38/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.1057 - accuracy: 0.9670 - val_loss: 0.1061 - val_accuracy: 0.9675
# Epoch 39/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.1046 - accuracy: 0.9675 - val_loss: 0.1057 - val_accuracy: 0.9678
# Epoch 40/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.1027 - accuracy: 0.9687 - val_loss: 0.1041 - val_accuracy: 0.9678
# Epoch 41/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.1005 - accuracy: 0.9689 - val_loss: 0.1056 - val_accuracy: 0.9660
# Epoch 42/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0987 - accuracy: 0.9692 - val_loss: 0.1032 - val_accuracy: 0.9698
# Epoch 43/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0964 - accuracy: 0.9709 - val_loss: 0.1012 - val_accuracy: 0.9672
# Epoch 44/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0934 - accuracy: 0.9710 - val_loss: 0.1002 - val_accuracy: 0.9679
# Epoch 45/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0933 - accuracy: 0.9712 - val_loss: 0.0945 - val_accuracy: 0.9708
# Epoch 46/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0909 - accuracy: 0.9717 - val_loss: 0.0965 - val_accuracy: 0.9697
# Epoch 47/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0906 - accuracy: 0.9717 - val_loss: 0.0951 - val_accuracy: 0.9715
# Epoch 48/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0879 - accuracy: 0.9733 - val_loss: 0.0904 - val_accuracy: 0.9715
# Epoch 49/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0863 - accuracy: 0.9736 - val_loss: 0.0881 - val_accuracy: 0.9726
# Epoch 50/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0846 - accuracy: 0.9739 - val_loss: 0.0974 - val_accuracy: 0.9706
# Epoch 51/300
# 14/14 [==============================] - 51s 4s/step - loss: 0.0948 - accuracy: 0.9722 - val_loss: 0.0953 - val_accuracy: 0.9705
# Epoch 52/300
# 14/14 [==============================] - 52s 4s/step - loss: 0.0902 - accuracy: 0.9728 - val_loss: 0.0907 - val_accuracy: 0.9714
# Epoch 53/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0816 - accuracy: 0.9749 - val_loss: 0.0889 - val_accuracy: 0.9719
# Epoch 54/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0795 - accuracy: 0.9759 - val_loss: 0.0803 - val_accuracy: 0.9751
# Epoch 55/300
# 14/14 [==============================] - 52s 4s/step - loss: 0.0768 - accuracy: 0.9766 - val_loss: 0.0802 - val_accuracy: 0.9751
# Epoch 56/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0737 - accuracy: 0.9782 - val_loss: 0.0754 - val_accuracy: 0.9763
# Epoch 57/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0714 - accuracy: 0.9783 - val_loss: 0.0782 - val_accuracy: 0.9754
# Epoch 58/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0728 - accuracy: 0.9777 - val_loss: 0.0788 - val_accuracy: 0.9754
# Epoch 59/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0713 - accuracy: 0.9785 - val_loss: 0.0733 - val_accuracy: 0.9778
# Epoch 60/300
# 14/14 [==============================] - 68s 5s/step - loss: 0.0695 - accuracy: 0.9792 - val_loss: 0.0785 - val_accuracy: 0.9757
# Epoch 61/300
# 14/14 [==============================] - 52s 4s/step - loss: 0.0726 - accuracy: 0.9782 - val_loss: 0.0725 - val_accuracy: 0.9774
# Epoch 62/300
# 14/14 [==============================] - 51s 4s/step - loss: 0.0666 - accuracy: 0.9799 - val_loss: 0.0722 - val_accuracy: 0.9773
# Epoch 63/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0650 - accuracy: 0.9806 - val_loss: 0.0695 - val_accuracy: 0.9778
# Epoch 64/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0637 - accuracy: 0.9809 - val_loss: 0.0690 - val_accuracy: 0.9783
# Epoch 65/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0626 - accuracy: 0.9814 - val_loss: 0.0682 - val_accuracy: 0.9789
# Epoch 66/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0622 - accuracy: 0.9815 - val_loss: 0.0700 - val_accuracy: 0.9777
# Epoch 67/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0651 - accuracy: 0.9808 - val_loss: 0.0816 - val_accuracy: 0.9769
# Epoch 68/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0656 - accuracy: 0.9806 - val_loss: 0.0647 - val_accuracy: 0.9799
# Epoch 69/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0596 - accuracy: 0.9822 - val_loss: 0.0640 - val_accuracy: 0.9801
# Epoch 70/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0569 - accuracy: 0.9832 - val_loss: 0.0624 - val_accuracy: 0.9807
# Epoch 71/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0571 - accuracy: 0.9828 - val_loss: 0.0623 - val_accuracy: 0.9811
# Epoch 72/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0551 - accuracy: 0.9838 - val_loss: 0.0616 - val_accuracy: 0.9809
# Epoch 73/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0554 - accuracy: 0.9839 - val_loss: 0.0584 - val_accuracy: 0.9817
# Epoch 74/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0536 - accuracy: 0.9839 - val_loss: 0.0558 - val_accuracy: 0.9834
# Epoch 75/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0524 - accuracy: 0.9845 - val_loss: 0.0594 - val_accuracy: 0.9825
# Epoch 76/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0532 - accuracy: 0.9843 - val_loss: 0.0603 - val_accuracy: 0.9813
# Epoch 77/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0545 - accuracy: 0.9840 - val_loss: 0.0632 - val_accuracy: 0.9804
# Epoch 78/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0534 - accuracy: 0.9843 - val_loss: 0.0582 - val_accuracy: 0.9818
# Epoch 79/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0511 - accuracy: 0.9852 - val_loss: 0.0564 - val_accuracy: 0.9821
# Epoch 80/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0511 - accuracy: 0.9851 - val_loss: 0.0550 - val_accuracy: 0.9837
# Epoch 81/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0507 - accuracy: 0.9849 - val_loss: 0.0613 - val_accuracy: 0.9803
# Epoch 82/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0510 - accuracy: 0.9851 - val_loss: 0.0552 - val_accuracy: 0.9831
# Epoch 83/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0479 - accuracy: 0.9859 - val_loss: 0.0522 - val_accuracy: 0.9843
# Epoch 84/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0474 - accuracy: 0.9862 - val_loss: 0.0566 - val_accuracy: 0.9828
# Epoch 85/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0482 - accuracy: 0.9862 - val_loss: 0.0516 - val_accuracy: 0.9840
# Epoch 86/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0486 - accuracy: 0.9860 - val_loss: 0.0547 - val_accuracy: 0.9829
# Epoch 87/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0488 - accuracy: 0.9862 - val_loss: 0.0532 - val_accuracy: 0.9848
# Epoch 88/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0455 - accuracy: 0.9872 - val_loss: 0.0524 - val_accuracy: 0.9832
# Epoch 89/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0436 - accuracy: 0.9876 - val_loss: 0.0569 - val_accuracy: 0.9817
# Epoch 90/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0450 - accuracy: 0.9872 - val_loss: 0.0545 - val_accuracy: 0.9846
# Epoch 91/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0449 - accuracy: 0.9874 - val_loss: 0.0528 - val_accuracy: 0.9829
# Epoch 92/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0420 - accuracy: 0.9878 - val_loss: 0.0491 - val_accuracy: 0.9849
# Epoch 93/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0406 - accuracy: 0.9884 - val_loss: 0.0487 - val_accuracy: 0.9857
# Epoch 94/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0405 - accuracy: 0.9883 - val_loss: 0.0510 - val_accuracy: 0.9837
# Epoch 95/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0426 - accuracy: 0.9876 - val_loss: 0.0526 - val_accuracy: 0.9845
# Epoch 96/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0421 - accuracy: 0.9880 - val_loss: 0.0500 - val_accuracy: 0.9849
# Epoch 97/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0430 - accuracy: 0.9877 - val_loss: 0.0514 - val_accuracy: 0.9846
# Epoch 98/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0419 - accuracy: 0.9880 - val_loss: 0.0504 - val_accuracy: 0.9848
# Epoch 99/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0400 - accuracy: 0.9889 - val_loss: 0.0476 - val_accuracy: 0.9853
# Epoch 100/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0393 - accuracy: 0.9888 - val_loss: 0.0497 - val_accuracy: 0.9844
# Epoch 101/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0388 - accuracy: 0.9890 - val_loss: 0.0458 - val_accuracy: 0.9862
# Epoch 102/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0386 - accuracy: 0.9889 - val_loss: 0.0437 - val_accuracy: 0.9873
# Epoch 103/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0382 - accuracy: 0.9889 - val_loss: 0.0430 - val_accuracy: 0.9871
# Epoch 104/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0377 - accuracy: 0.9892 - val_loss: 0.0449 - val_accuracy: 0.9866
# Epoch 105/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0374 - accuracy: 0.9896 - val_loss: 0.0451 - val_accuracy: 0.9867
# Epoch 106/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0376 - accuracy: 0.9893 - val_loss: 0.0430 - val_accuracy: 0.9875
# Epoch 107/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0344 - accuracy: 0.9903 - val_loss: 0.0405 - val_accuracy: 0.9872
# Epoch 108/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0358 - accuracy: 0.9898 - val_loss: 0.0491 - val_accuracy: 0.9852
# Epoch 109/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0380 - accuracy: 0.9888 - val_loss: 0.0413 - val_accuracy: 0.9870
# Epoch 110/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0353 - accuracy: 0.9899 - val_loss: 0.0432 - val_accuracy: 0.9866
# Epoch 111/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0360 - accuracy: 0.9899 - val_loss: 0.0442 - val_accuracy: 0.9864
# Epoch 112/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0366 - accuracy: 0.9894 - val_loss: 0.0451 - val_accuracy: 0.9867
# Epoch 113/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0376 - accuracy: 0.9892 - val_loss: 0.0425 - val_accuracy: 0.9874
# Epoch 114/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0364 - accuracy: 0.9894 - val_loss: 0.0427 - val_accuracy: 0.9872
# Epoch 115/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0339 - accuracy: 0.9905 - val_loss: 0.0407 - val_accuracy: 0.9879
# Epoch 116/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0323 - accuracy: 0.9910 - val_loss: 0.0451 - val_accuracy: 0.9868
# Epoch 117/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0325 - accuracy: 0.9908 - val_loss: 0.0398 - val_accuracy: 0.9882
# Epoch 118/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0312 - accuracy: 0.9913 - val_loss: 0.0403 - val_accuracy: 0.9878
# Epoch 119/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0312 - accuracy: 0.9911 - val_loss: 0.0396 - val_accuracy: 0.9876
# Epoch 120/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0303 - accuracy: 0.9914 - val_loss: 0.0383 - val_accuracy: 0.9886
# Epoch 121/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0305 - accuracy: 0.9916 - val_loss: 0.0426 - val_accuracy: 0.9879
# Epoch 122/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0321 - accuracy: 0.9910 - val_loss: 0.0372 - val_accuracy: 0.9878
# Epoch 123/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0345 - accuracy: 0.9902 - val_loss: 0.0432 - val_accuracy: 0.9864
# Epoch 124/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0342 - accuracy: 0.9903 - val_loss: 0.0419 - val_accuracy: 0.9879
# Epoch 125/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0313 - accuracy: 0.9911 - val_loss: 0.0382 - val_accuracy: 0.9883
# Epoch 126/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0295 - accuracy: 0.9917 - val_loss: 0.0364 - val_accuracy: 0.9893
# Epoch 127/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0284 - accuracy: 0.9923 - val_loss: 0.0374 - val_accuracy: 0.9893
# Epoch 128/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0285 - accuracy: 0.9921 - val_loss: 0.0381 - val_accuracy: 0.9889
# Epoch 129/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0289 - accuracy: 0.9920 - val_loss: 0.0361 - val_accuracy: 0.9893
# Epoch 130/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0283 - accuracy: 0.9920 - val_loss: 0.0342 - val_accuracy: 0.9901
# Epoch 131/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0291 - accuracy: 0.9919 - val_loss: 0.0465 - val_accuracy: 0.9863
# Epoch 132/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0319 - accuracy: 0.9907 - val_loss: 0.0385 - val_accuracy: 0.9881
# Epoch 133/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0297 - accuracy: 0.9916 - val_loss: 0.0360 - val_accuracy: 0.9893
# Epoch 134/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0293 - accuracy: 0.9920 - val_loss: 0.0397 - val_accuracy: 0.9882
# Epoch 135/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0303 - accuracy: 0.9912 - val_loss: 0.0408 - val_accuracy: 0.9882
# Epoch 136/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0282 - accuracy: 0.9920 - val_loss: 0.0384 - val_accuracy: 0.9890
# Epoch 137/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0279 - accuracy: 0.9921 - val_loss: 0.0343 - val_accuracy: 0.9898
# Epoch 138/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0272 - accuracy: 0.9924 - val_loss: 0.0365 - val_accuracy: 0.9891
# Epoch 139/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0273 - accuracy: 0.9922 - val_loss: 0.0393 - val_accuracy: 0.9884
# Epoch 140/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0265 - accuracy: 0.9925 - val_loss: 0.0325 - val_accuracy: 0.9909
# Epoch 141/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0265 - accuracy: 0.9925 - val_loss: 0.0429 - val_accuracy: 0.9873
# Epoch 142/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0333 - accuracy: 0.9909 - val_loss: 0.0384 - val_accuracy: 0.9882
# Epoch 143/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0281 - accuracy: 0.9920 - val_loss: 0.0345 - val_accuracy: 0.9904
# Epoch 144/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0258 - accuracy: 0.9930 - val_loss: 0.0348 - val_accuracy: 0.9903
# Epoch 145/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0259 - accuracy: 0.9927 - val_loss: 0.0370 - val_accuracy: 0.9896
# Epoch 146/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0255 - accuracy: 0.9929 - val_loss: 0.0363 - val_accuracy: 0.9901
# Epoch 147/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0253 - accuracy: 0.9929 - val_loss: 0.0342 - val_accuracy: 0.9904
# Epoch 148/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0241 - accuracy: 0.9935 - val_loss: 0.0388 - val_accuracy: 0.9885
# Epoch 149/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0300 - accuracy: 0.9912 - val_loss: 0.0426 - val_accuracy: 0.9886
# Epoch 150/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0270 - accuracy: 0.9923 - val_loss: 0.0382 - val_accuracy: 0.9890
# Epoch 151/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0278 - accuracy: 0.9922 - val_loss: 0.0349 - val_accuracy: 0.9900
# Epoch 152/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0264 - accuracy: 0.9925 - val_loss: 0.0379 - val_accuracy: 0.9900
# Epoch 153/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0242 - accuracy: 0.9932 - val_loss: 0.0338 - val_accuracy: 0.9906
# Epoch 154/300
# 14/14 [==============================] - 52s 4s/step - loss: 0.0239 - accuracy: 0.9934 - val_loss: 0.0319 - val_accuracy: 0.9899
# Epoch 155/300
# 14/14 [==============================] - 53s 4s/step - loss: 0.0241 - accuracy: 0.9932 - val_loss: 0.0348 - val_accuracy: 0.9898
# Epoch 156/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0241 - accuracy: 0.9932 - val_loss: 0.0363 - val_accuracy: 0.9889
# Epoch 157/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0238 - accuracy: 0.9932 - val_loss: 0.0330 - val_accuracy: 0.9912
# Epoch 158/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0241 - accuracy: 0.9930 - val_loss: 0.0350 - val_accuracy: 0.9908
# Epoch 159/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0239 - accuracy: 0.9932 - val_loss: 0.0338 - val_accuracy: 0.9905
# Epoch 160/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0238 - accuracy: 0.9931 - val_loss: 0.0356 - val_accuracy: 0.9893
# Epoch 161/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0225 - accuracy: 0.9937 - val_loss: 0.0304 - val_accuracy: 0.9919
# Epoch 162/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0215 - accuracy: 0.9941 - val_loss: 0.0311 - val_accuracy: 0.9913
# Epoch 163/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0222 - accuracy: 0.9941 - val_loss: 0.0322 - val_accuracy: 0.9904
# Epoch 164/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0218 - accuracy: 0.9939 - val_loss: 0.0340 - val_accuracy: 0.9898
# Epoch 165/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0227 - accuracy: 0.9939 - val_loss: 0.0334 - val_accuracy: 0.9904
# Epoch 166/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0232 - accuracy: 0.9933 - val_loss: 0.0334 - val_accuracy: 0.9906
# Epoch 167/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0231 - accuracy: 0.9936 - val_loss: 0.0374 - val_accuracy: 0.9880
# Epoch 168/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0233 - accuracy: 0.9935 - val_loss: 0.0323 - val_accuracy: 0.9907
# Epoch 169/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0221 - accuracy: 0.9936 - val_loss: 0.0314 - val_accuracy: 0.9912
# Epoch 170/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0218 - accuracy: 0.9937 - val_loss: 0.0357 - val_accuracy: 0.9894
# Epoch 171/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0220 - accuracy: 0.9939 - val_loss: 0.0325 - val_accuracy: 0.9908
# Epoch 172/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0206 - accuracy: 0.9944 - val_loss: 0.0314 - val_accuracy: 0.9914
# Epoch 173/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0221 - accuracy: 0.9937 - val_loss: 0.0348 - val_accuracy: 0.9901
# Epoch 174/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0204 - accuracy: 0.9943 - val_loss: 0.0327 - val_accuracy: 0.9902
# Epoch 175/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0211 - accuracy: 0.9941 - val_loss: 0.0328 - val_accuracy: 0.9901
# Epoch 176/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0212 - accuracy: 0.9941 - val_loss: 0.0356 - val_accuracy: 0.9895
# Epoch 177/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0212 - accuracy: 0.9943 - val_loss: 0.0303 - val_accuracy: 0.9912
# Epoch 178/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0203 - accuracy: 0.9942 - val_loss: 0.0326 - val_accuracy: 0.9913
# Epoch 179/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0200 - accuracy: 0.9943 - val_loss: 0.0332 - val_accuracy: 0.9905
# Epoch 180/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0202 - accuracy: 0.9944 - val_loss: 0.0286 - val_accuracy: 0.9918
# Epoch 181/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0205 - accuracy: 0.9943 - val_loss: 0.0373 - val_accuracy: 0.9898
# Epoch 182/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0213 - accuracy: 0.9941 - val_loss: 0.0318 - val_accuracy: 0.9907
# Epoch 183/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0221 - accuracy: 0.9940 - val_loss: 0.0347 - val_accuracy: 0.9902
# Epoch 184/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0210 - accuracy: 0.9941 - val_loss: 0.0329 - val_accuracy: 0.9910
# Epoch 185/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0200 - accuracy: 0.9942 - val_loss: 0.0357 - val_accuracy: 0.9897
# Epoch 186/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0203 - accuracy: 0.9942 - val_loss: 0.0303 - val_accuracy: 0.9915
# Epoch 187/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0217 - accuracy: 0.9939 - val_loss: 0.0326 - val_accuracy: 0.9901
# Epoch 188/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0195 - accuracy: 0.9944 - val_loss: 0.0305 - val_accuracy: 0.9912
# Epoch 189/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0204 - accuracy: 0.9943 - val_loss: 0.0297 - val_accuracy: 0.9908
# Epoch 190/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0206 - accuracy: 0.9942 - val_loss: 0.0355 - val_accuracy: 0.9895
# Epoch 191/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0226 - accuracy: 0.9938 - val_loss: 0.0323 - val_accuracy: 0.9903
# Epoch 192/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0191 - accuracy: 0.9945 - val_loss: 0.0334 - val_accuracy: 0.9907
# Epoch 193/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0186 - accuracy: 0.9948 - val_loss: 0.0307 - val_accuracy: 0.9910
# Epoch 194/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0182 - accuracy: 0.9948 - val_loss: 0.0305 - val_accuracy: 0.9911
# Epoch 195/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0190 - accuracy: 0.9947 - val_loss: 0.0327 - val_accuracy: 0.9907
# Epoch 196/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0185 - accuracy: 0.9948 - val_loss: 0.0301 - val_accuracy: 0.9911
# Epoch 197/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0185 - accuracy: 0.9949 - val_loss: 0.0301 - val_accuracy: 0.9909
# Epoch 198/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0190 - accuracy: 0.9945 - val_loss: 0.0319 - val_accuracy: 0.9908
# Epoch 199/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0180 - accuracy: 0.9948 - val_loss: 0.0328 - val_accuracy: 0.9913
# Epoch 200/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0178 - accuracy: 0.9950 - val_loss: 0.0328 - val_accuracy: 0.9907
# Epoch 201/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0183 - accuracy: 0.9948 - val_loss: 0.0295 - val_accuracy: 0.9914
# Epoch 202/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0179 - accuracy: 0.9949 - val_loss: 0.0333 - val_accuracy: 0.9908
# Epoch 203/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0172 - accuracy: 0.9952 - val_loss: 0.0281 - val_accuracy: 0.9920
# Epoch 204/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0176 - accuracy: 0.9953 - val_loss: 0.0328 - val_accuracy: 0.9914
# Epoch 205/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0181 - accuracy: 0.9951 - val_loss: 0.0307 - val_accuracy: 0.9913
# Epoch 206/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0179 - accuracy: 0.9951 - val_loss: 0.0299 - val_accuracy: 0.9918
# Epoch 207/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0184 - accuracy: 0.9947 - val_loss: 0.0303 - val_accuracy: 0.9915
# Epoch 208/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0181 - accuracy: 0.9948 - val_loss: 0.0323 - val_accuracy: 0.9912
# Epoch 209/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0190 - accuracy: 0.9946 - val_loss: 0.0313 - val_accuracy: 0.9914
# Epoch 210/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0199 - accuracy: 0.9944 - val_loss: 0.0307 - val_accuracy: 0.9916
# Epoch 211/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0203 - accuracy: 0.9941 - val_loss: 0.0343 - val_accuracy: 0.9907
# Epoch 212/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0208 - accuracy: 0.9941 - val_loss: 0.0318 - val_accuracy: 0.9910
# Epoch 213/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0195 - accuracy: 0.9944 - val_loss: 0.0302 - val_accuracy: 0.9904
# Epoch 214/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0183 - accuracy: 0.9950 - val_loss: 0.0344 - val_accuracy: 0.9907
# Epoch 215/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0177 - accuracy: 0.9950 - val_loss: 0.0293 - val_accuracy: 0.9904
# Epoch 216/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0170 - accuracy: 0.9953 - val_loss: 0.0300 - val_accuracy: 0.9915
# Epoch 217/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0155 - accuracy: 0.9955 - val_loss: 0.0305 - val_accuracy: 0.9922
# Epoch 218/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0162 - accuracy: 0.9956 - val_loss: 0.0273 - val_accuracy: 0.9921
# Epoch 219/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0162 - accuracy: 0.9955 - val_loss: 0.0288 - val_accuracy: 0.9928
# Epoch 220/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0166 - accuracy: 0.9952 - val_loss: 0.0286 - val_accuracy: 0.9916
# Epoch 221/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0172 - accuracy: 0.9952 - val_loss: 0.0296 - val_accuracy: 0.9915
# Epoch 222/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0173 - accuracy: 0.9954 - val_loss: 0.0307 - val_accuracy: 0.9918
# Epoch 223/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0168 - accuracy: 0.9954 - val_loss: 0.0306 - val_accuracy: 0.9906
# Epoch 224/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0188 - accuracy: 0.9947 - val_loss: 0.0321 - val_accuracy: 0.9910
# Epoch 225/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0171 - accuracy: 0.9952 - val_loss: 0.0304 - val_accuracy: 0.9912
# Epoch 226/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0176 - accuracy: 0.9950 - val_loss: 0.0318 - val_accuracy: 0.9907
# Epoch 227/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0166 - accuracy: 0.9953 - val_loss: 0.0298 - val_accuracy: 0.9919
# Epoch 228/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0159 - accuracy: 0.9955 - val_loss: 0.0286 - val_accuracy: 0.9916
# Epoch 229/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0163 - accuracy: 0.9954 - val_loss: 0.0304 - val_accuracy: 0.9907
# Epoch 230/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0179 - accuracy: 0.9951 - val_loss: 0.0320 - val_accuracy: 0.9913
# Epoch 231/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0195 - accuracy: 0.9945 - val_loss: 0.0352 - val_accuracy: 0.9907
# Epoch 232/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0192 - accuracy: 0.9945 - val_loss: 0.0323 - val_accuracy: 0.9911
# Epoch 233/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0197 - accuracy: 0.9943 - val_loss: 0.0328 - val_accuracy: 0.9913
# Epoch 234/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0186 - accuracy: 0.9945 - val_loss: 0.0314 - val_accuracy: 0.9908
# Epoch 235/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0175 - accuracy: 0.9951 - val_loss: 0.0276 - val_accuracy: 0.9920
# Epoch 236/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0165 - accuracy: 0.9955 - val_loss: 0.0288 - val_accuracy: 0.9924
# Epoch 237/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0168 - accuracy: 0.9951 - val_loss: 0.0312 - val_accuracy: 0.9911
# Epoch 238/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0165 - accuracy: 0.9956 - val_loss: 0.0311 - val_accuracy: 0.9904
# Epoch 239/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0171 - accuracy: 0.9951 - val_loss: 0.0333 - val_accuracy: 0.9915
# Epoch 240/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0176 - accuracy: 0.9949 - val_loss: 0.0312 - val_accuracy: 0.9915
# Epoch 241/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0170 - accuracy: 0.9952 - val_loss: 0.0300 - val_accuracy: 0.9922
# Epoch 242/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0153 - accuracy: 0.9957 - val_loss: 0.0290 - val_accuracy: 0.9917
# Epoch 243/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0160 - accuracy: 0.9956 - val_loss: 0.0305 - val_accuracy: 0.9918
# Epoch 244/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0165 - accuracy: 0.9954 - val_loss: 0.0319 - val_accuracy: 0.9907
# Epoch 245/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0163 - accuracy: 0.9955 - val_loss: 0.0304 - val_accuracy: 0.9914
# Epoch 246/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0156 - accuracy: 0.9956 - val_loss: 0.0300 - val_accuracy: 0.9916
# Epoch 247/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0154 - accuracy: 0.9956 - val_loss: 0.0285 - val_accuracy: 0.9924
# Epoch 248/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0164 - accuracy: 0.9953 - val_loss: 0.0313 - val_accuracy: 0.9913
# Epoch 249/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0165 - accuracy: 0.9953 - val_loss: 0.0312 - val_accuracy: 0.9916
# Epoch 250/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0155 - accuracy: 0.9955 - val_loss: 0.0292 - val_accuracy: 0.9927
# Epoch 251/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0174 - accuracy: 0.9949 - val_loss: 0.0315 - val_accuracy: 0.9916
# Epoch 252/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0171 - accuracy: 0.9952 - val_loss: 0.0331 - val_accuracy: 0.9913
# Epoch 253/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0161 - accuracy: 0.9954 - val_loss: 0.0295 - val_accuracy: 0.9922
# Epoch 254/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0166 - accuracy: 0.9954 - val_loss: 0.0304 - val_accuracy: 0.9907
# Epoch 255/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0158 - accuracy: 0.9952 - val_loss: 0.0250 - val_accuracy: 0.9927
# Epoch 256/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0139 - accuracy: 0.9961 - val_loss: 0.0282 - val_accuracy: 0.9925
# Epoch 257/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0148 - accuracy: 0.9958 - val_loss: 0.0304 - val_accuracy: 0.9910
# Epoch 258/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0151 - accuracy: 0.9957 - val_loss: 0.0288 - val_accuracy: 0.9919
# Epoch 259/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0142 - accuracy: 0.9958 - val_loss: 0.0309 - val_accuracy: 0.9922
# Epoch 260/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0138 - accuracy: 0.9962 - val_loss: 0.0299 - val_accuracy: 0.9925
# Epoch 261/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0136 - accuracy: 0.9962 - val_loss: 0.0309 - val_accuracy: 0.9921
# Epoch 262/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0154 - accuracy: 0.9959 - val_loss: 0.0300 - val_accuracy: 0.9924
# Epoch 263/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0157 - accuracy: 0.9957 - val_loss: 0.0292 - val_accuracy: 0.9919
# Epoch 264/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0147 - accuracy: 0.9959 - val_loss: 0.0305 - val_accuracy: 0.9919
# Epoch 265/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0137 - accuracy: 0.9961 - val_loss: 0.0267 - val_accuracy: 0.9931
# Epoch 266/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0147 - accuracy: 0.9960 - val_loss: 0.0330 - val_accuracy: 0.9909
# Epoch 267/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0142 - accuracy: 0.9959 - val_loss: 0.0324 - val_accuracy: 0.9910
# Epoch 268/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0144 - accuracy: 0.9960 - val_loss: 0.0299 - val_accuracy: 0.9921
# Epoch 269/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0134 - accuracy: 0.9963 - val_loss: 0.0298 - val_accuracy: 0.9923
# Epoch 270/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0138 - accuracy: 0.9960 - val_loss: 0.0314 - val_accuracy: 0.9918
# Epoch 271/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0145 - accuracy: 0.9958 - val_loss: 0.0269 - val_accuracy: 0.9926
# Epoch 272/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0141 - accuracy: 0.9960 - val_loss: 0.0331 - val_accuracy: 0.9908
# Epoch 273/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0144 - accuracy: 0.9959 - val_loss: 0.0279 - val_accuracy: 0.9919
# Epoch 274/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0138 - accuracy: 0.9961 - val_loss: 0.0303 - val_accuracy: 0.9915
# Epoch 275/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0142 - accuracy: 0.9960 - val_loss: 0.0275 - val_accuracy: 0.9921
# Epoch 276/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0132 - accuracy: 0.9963 - val_loss: 0.0277 - val_accuracy: 0.9929
# Epoch 277/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0127 - accuracy: 0.9965 - val_loss: 0.0309 - val_accuracy: 0.9921
# Epoch 278/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0134 - accuracy: 0.9964 - val_loss: 0.0283 - val_accuracy: 0.9928
# Epoch 279/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0135 - accuracy: 0.9961 - val_loss: 0.0277 - val_accuracy: 0.9928
# Epoch 280/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0135 - accuracy: 0.9962 - val_loss: 0.0294 - val_accuracy: 0.9922
# Epoch 281/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0135 - accuracy: 0.9963 - val_loss: 0.0314 - val_accuracy: 0.9918
# Epoch 282/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0140 - accuracy: 0.9960 - val_loss: 0.0315 - val_accuracy: 0.9919
# Epoch 283/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0135 - accuracy: 0.9961 - val_loss: 0.0329 - val_accuracy: 0.9913
# Epoch 284/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0129 - accuracy: 0.9964 - val_loss: 0.0292 - val_accuracy: 0.9926
# Epoch 285/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0125 - accuracy: 0.9964 - val_loss: 0.0336 - val_accuracy: 0.9911
# Epoch 286/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0136 - accuracy: 0.9963 - val_loss: 0.0299 - val_accuracy: 0.9919
# Epoch 287/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0136 - accuracy: 0.9960 - val_loss: 0.0294 - val_accuracy: 0.9928
# Epoch 288/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0123 - accuracy: 0.9965 - val_loss: 0.0282 - val_accuracy: 0.9931
# Epoch 289/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0122 - accuracy: 0.9966 - val_loss: 0.0295 - val_accuracy: 0.9920
# Epoch 290/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0129 - accuracy: 0.9964 - val_loss: 0.0323 - val_accuracy: 0.9919
# Epoch 291/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0140 - accuracy: 0.9960 - val_loss: 0.0300 - val_accuracy: 0.9926
# Epoch 292/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0144 - accuracy: 0.9959 - val_loss: 0.0328 - val_accuracy: 0.9913
# Epoch 293/300
# 14/14 [==============================] - 50s 4s/step - loss: 0.0141 - accuracy: 0.9959 - val_loss: 0.0287 - val_accuracy: 0.9922
# Epoch 294/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0153 - accuracy: 0.9956 - val_loss: 0.0335 - val_accuracy: 0.9916
# Epoch 295/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0200 - accuracy: 0.9949 - val_loss: 0.0321 - val_accuracy: 0.9913
# Epoch 296/300
# 14/14 [==============================] - 49s 3s/step - loss: 0.0195 - accuracy: 0.9944 - val_loss: 0.0292 - val_accuracy: 0.9919
# Epoch 297/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0155 - accuracy: 0.9953 - val_loss: 0.0286 - val_accuracy: 0.9925
# Epoch 298/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0174 - accuracy: 0.9951 - val_loss: 0.0307 - val_accuracy: 0.9919
# Epoch 299/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0147 - accuracy: 0.9958 - val_loss: 0.0276 - val_accuracy: 0.9922
# Epoch 300/300
# 14/14 [==============================] - 49s 4s/step - loss: 0.0138 - accuracy: 0.9960 - val_loss: 0.0277 - val_accuracy: 0.9937
# 14835.722799062729 seconds

# %% [markdown]
# # 4.Evaluate Network

# %% [markdown]
# # 4.1. Plotting Loss and Accuracy¶

# %%
#Loss Curve


plt.plot(figsize = [8,6])

plt.plot(history.history['loss'],'r',linewidth = 3.0)
plt.plot(history.history['val_loss'],'b',linewidth = 3.0)

plt.legend(['Training Loss', 'Validation Loss'], fontsize = 18)

plt.xlabel('Epochs', fontsize = 16)
plt.ylabel('Loss', fontsize = 16)

plt.title('Loss Curve of Deep Neural Netowork' , fontsize = 16 )
# Out:
# Text(0.5, 1.0, 'Loss Curve of Deep Neural Netowork')

# %%
#Accuracy Curve

plt.plot(figsize = [8,6])
plt.plot(history.history['accuracy'],'r',linewidth = 3.0)
plt.plot(history.history['val_accuracy'],'b',linewidth = 3.0)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize = 18)

plt.xlabel('Epochs', fontsize = 16)
plt.ylabel('Accuracy', fontsize = 16)


plt.title('Accuracy Curve of Deep Neural Netowork' , fontsize = 16 )
# Out:
# Text(0.5, 1.0, 'Accuracy Curve of Deep Neural Netowork')

# %% [markdown]
# # 4.2 Make Predictions

# %%
predictions = model.predict(X_test)
predictions = np.argmax(predictions, axis = 1)
# Out:
# 415/415 [==============================] - 6s 14ms/step

# %%
predictions
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# # Transforming from One Hot Encoding

# %%
y_test =np.argmax(y_test, axis=1)
y_test[1]
# Out:
# 0

# %%
from sklearn.metrics import accuracy_score
accuracy = {accuracy_score(y_test, predictions)}
print(f"Accuracy is: {accuracy_score(y_test, predictions)* 100}")
# Out:
# Accuracy is: 99.36727930099427

# %% [markdown]
# # 4.3 Classification Report

# %%
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, classification_report
print('\033[1m' +'Classification report : '+ '\033[0m\n', classification_report(y_test, predictions))

cm = confusion_matrix(predictions, y_test)
print('\033[1m' +'Confusion Matrix : '+ '\033[0m')
sns.heatmap(cm, cmap = 'OrRd',annot = True, fmt='d')
plt.show()
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     10695
#            1       0.99      0.98      0.98       379
#            2       0.98      0.98      0.98       361
#            3       0.99      0.95      0.97       377
#            4       0.99      0.98      0.98       377
#            5       0.99      0.94      0.97       367
#            6       1.00      0.99      0.99       404
#            7       0.97      0.97      0.97       316
#
#     accuracy                           0.99     13276
#    macro avg       0.99      0.97      0.98     13276
# weighted avg       0.99      0.99      0.99     13276
#
# Confusion Matrix :

# %% [markdown]
# # 4.4 Evaluation

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test,predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 0.023124435070804458
# MSE: 0.10884302500753239
# RMSE: 0.3299136629597695

# %%
from sklearn.metrics import precision_score
print("Precision Score : ",precision_score(y_test, predictions, average='weighted'))


from sklearn.metrics import recall_score
print("Recall Score : ",recall_score(y_test, predictions,average='weighted'))


from sklearn.metrics import f1_score
print("f1_score : ",f1_score(y_test, predictions,average='weighted'))
# Out:
# Precision Score :  0.9936628982795784
# Recall Score :  0.9936727930099427
# f1_score :  0.9936338726639955
