# %% [markdown]
# # Importing Libraires

# %%
import pandas as pd
from scipy.io import loadmat

# %% [markdown]
# #  Loading Exercise 3

# %%
Exercise_3 = loadmat(r"S1_A1_E3.mat")

# %%
print(Exercise_3)
print("************************************************************************************************************")
print(Exercise_3.keys())
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Mon Jul 28 11:54:18 2014', '__version__': '1.0', '__globals__': [], 'emg': array([[0.0024, 0.0024, 0.0024, ..., 0.0732, 0.0024, 0.0903],
#        [0.0024, 0.0024, 0.0024, ..., 0.0757, 0.0024, 0.0928],
#        [0.0024, 0.0024, 0.0024, ..., 0.0879, 0.0024, 0.0903],
#        ...,
#        [0.0024, 0.0024, 0.0024, ..., 0.0513, 0.127 , 0.0024],
#        [0.0024, 0.0024, 0.0024, ..., 0.0488, 0.1294, 0.0024],
#        [0.0024, 0.0024, 0.0024, ..., 0.0439, 0.1294, 0.0024]]), 'stimulus': array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8), 'glove': array([[152., 137., 111., ..., 139., 134., 108.],
#        [152., 137., 111., ..., 139., 134., 108.],
#        [152., 137., 111., ..., 139., 134., 108.],
#        ...,
#        [152., 131., 114., ..., 124., 133., 120.],
#        [152., 131., 114., ..., 124., 133., 120.],
#        [152., 131., 114., ..., 124., 133., 120.]]), 'subject': array([[1]], dtype=uint8), 'exercise': array([[3]], dtype=uint8), 'repetition': array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8), 'restimulus': array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8), 'rerepetition': array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8)}
# ************************************************************************************************************
# dict_keys(['__header__', '__version__', '__globals__', 'emg', 'stimulus', 'glove', 'subject', 'exercise', 'repetition', 'restimulus', 'rerepetition'])

# %%
emg_3 = Exercise_3['emg']
stimulus_3 = Exercise_3['stimulus']
restimulus_3 = Exercise_3['restimulus']

# %% [markdown]
# # DataFramae

# %%
df_3= pd.DataFrame(emg_3, 
                  columns = ['Emg1','Emg2','Emg3','Emg4','Emg5','Emg6','Emg7','Emg8','Emg9','Emg10'])

# %%
df_3
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 0       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0317  0.0732
# 1       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366  0.0757
# 2       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0415  0.0879
# 3       0.0024  0.0024  0.0049  0.0024  0.0024  0.0024  0.0366  0.0952
# 4       0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0293  0.0952
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 227488  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0562
# 227489  0.0024  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0513
# 227490  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0513
# 227491  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0488
# 227492  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0439
#
#           Emg9   Emg10
# 0       0.0024  0.0903
# 1       0.0024  0.0928
# 2       0.0024  0.0903
# 3       0.0024  0.0830
# 4       0.0024  0.0708
# ...        ...     ...
# 227488  0.1221  0.0024
# 227489  0.1270  0.0024
# 227490  0.1270  0.0024
# 227491  0.1294  0.0024
# 227492  0.1294  0.0024
#
# [227493 rows x 10 columns]

# %%
stimulus_3 = pd.DataFrame(stimulus_3)
restimulus_3 = pd.DataFrame(restimulus_3)

# %% [markdown]
# # Adding new column to existing DataFrame

# %%
df_3['stimulus'] = stimulus_3
df_3['restimulus'] = restimulus_3

# %%
df_3.describe()
# Out:
#                 Emg1           Emg2           Emg3           Emg4  \
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.177020       0.125848       0.195590       0.060284
# std         0.332936       0.303522       0.430584       0.183509
# min         0.002400       0.000000       0.002400       0.000000
# 25%         0.002400       0.002400       0.002400       0.002400
# 50%         0.034200       0.002400       0.002400       0.002400
# 75%         0.195300       0.097700       0.180700       0.034200
# max         4.665500       4.660600       4.658200       4.619100
#
#                 Emg5           Emg6           Emg7           Emg8  \
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.018392       0.018891       0.218081       0.289072
# std         0.038278       0.043190       0.410667       0.346111
# min         0.002400       0.000000       0.002400       0.002400
# 25%         0.002400       0.002400       0.012200       0.087900
# 50%         0.002400       0.002400       0.048800       0.146500
# 75%         0.014600       0.009800       0.231900       0.351600
# max         0.876500       0.632300       4.663100       4.577600
#
#                 Emg9          Emg10       stimulus     restimulus
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.134195       0.057882       6.284220       4.962707
# std         0.248078       0.129270       7.679851       7.434667
# min         0.002400       0.002400       0.000000       0.000000
# 25%         0.002400       0.009800       0.000000       0.000000
# 50%         0.102500       0.036600       2.000000       0.000000
# 75%         0.148900       0.058600      13.000000      10.000000
# max         4.660600       4.628900      23.000000      23.000000

# %% [markdown]
# # Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, classification_report

# %%
raw_data = df_3
raw_data.sample(5)
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 208769  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0635  0.1294
# 101524  0.0049  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0537
# 187567  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366  0.0854
# 73764   0.0317  0.0024  0.0317  0.0024  0.0024  0.0024  0.1416  0.1025
# 163506  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0757
#
#           Emg9   Emg10  stimulus  restimulus
# 208769  0.3003  0.1294         0           0
# 101524  0.0781  0.0464         0           0
# 187567  0.1270  0.0391         0           0
# 73764   0.2612  0.0342         8           8
# 163506  0.0562  0.0024         0           0

# %%
print("The Shape of the Dataset is : ",raw_data.shape)
print("************************************************************************************************************")
print("Column Names of the Dataset are : ",raw_data.columns)
print("************************************************************************************************************")
print(raw_data.info())
print("************************************************************************************************************")
raw_data.describe(include='all')
# Out:
# The Shape of the Dataset is :  (227493, 12)
# ************************************************************************************************************
# Column Names of the Dataset are :  Index(['Emg1', 'Emg2', 'Emg3', 'Emg4', 'Emg5', 'Emg6', 'Emg7', 'Emg8', 'Emg9',
#        'Emg10', 'stimulus', 'restimulus'],
#       dtype='object')
# ************************************************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227493 entries, 0 to 227492
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Emg1        227493 non-null  float64
#  1   Emg2        227493 non-null  float64
#  2   Emg3        227493 non-null  float64
#  3   Emg4        227493 non-null  float64
#  4   Emg5        227493 non-null  float64
#  5   Emg6        227493 non-null  float64
#  6   Emg7        227493 non-null  float64
#  7   Emg8        227493 non-null  float64
#  8   Emg9        227493 non-null  float64
#  9   Emg10       227493 non-null  float64
#  10  stimulus    227493 non-null  uint8
#  11  restimulus  227493 non-null  uint8
# dtypes: float64(10), uint8(2)
# memory usage: 17.8 MB
# None
# ************************************************************************************************************
#                 Emg1           Emg2           Emg3           Emg4  \
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.177020       0.125848       0.195590       0.060284
# std         0.332936       0.303522       0.430584       0.183509
# min         0.002400       0.000000       0.002400       0.000000
# 25%         0.002400       0.002400       0.002400       0.002400
# 50%         0.034200       0.002400       0.002400       0.002400
# 75%         0.195300       0.097700       0.180700       0.034200
# max         4.665500       4.660600       4.658200       4.619100
#
#                 Emg5           Emg6           Emg7           Emg8  \
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.018392       0.018891       0.218081       0.289072
# std         0.038278       0.043190       0.410667       0.346111
# min         0.002400       0.000000       0.002400       0.002400
# 25%         0.002400       0.002400       0.012200       0.087900
# 50%         0.002400       0.002400       0.048800       0.146500
# 75%         0.014600       0.009800       0.231900       0.351600
# max         0.876500       0.632300       4.663100       4.577600
#
#                 Emg9          Emg10       stimulus     restimulus
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.134195       0.057882       6.284220       4.962707
# std         0.248078       0.129270       7.679851       7.434667
# min         0.002400       0.002400       0.000000       0.000000
# 25%         0.002400       0.009800       0.000000       0.000000
# 50%         0.102500       0.036600       2.000000       0.000000
# 75%         0.148900       0.058600      13.000000      10.000000
# max         4.660600       4.628900      23.000000      23.000000

# %%
print("Unique Dependent values and their counts :")
print(raw_data["stimulus"].value_counts())
# Out:
# Unique Dependent values and their counts :
# 0     108449
# 18      5210
# 20      5202
# 14      5191
# 9       5190
# 19      5189
# 12      5189
# 2       5188
# 13      5186
# 21      5185
# 17      5184
# 10      5182
# 11      5182
# 8       5182
# 7       5177
# 4       5174
# 23      5166
# 16      5165
# 1       5162
# 22      5161
# 15      5161
# 5       5153
# 3       5133
# 6       5132
# Name: stimulus, dtype: int64

# %%
count_classes = pd.value_counts(raw_data['stimulus'], sort = True)

count_classes.plot(kind = 'bar', rot=0)

plt.title("stimulus Class Distribution")

plt.xlabel("Class")

plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
print(raw_data.isnull().any())
# Out:
# Emg1          False
# Emg2          False
# Emg3          False
# Emg4          False
# Emg5          False
# Emg6          False
# Emg7          False
# Emg8          False
# Emg9          False
# Emg10         False
# stimulus      False
# restimulus    False
# dtype: bool

# %% [markdown]
# # Custom Outlier Detection

# %%
index_names = raw_data[ (raw_data['stimulus'] != raw_data['restimulus'])].index
raw_data.drop(index_names, inplace = True)

# %%
raw_data.sample(5)
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 71693   0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0293  0.1074
# 71964   0.8472  0.4785  1.0449  0.5786  0.0830  0.1611  2.0532  1.0425
# 49653   0.1172  0.4028  1.1426  0.6543  0.0513  0.0195  0.5225  0.6006
# 89233   0.3101  0.0024  0.1001  0.0024  0.0049  0.0024  0.0635  0.3027
# 197894  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0122  0.1611
#
#           Emg9   Emg10  stimulus  restimulus
# 71693   0.0024  0.0513         0           0
# 71964   0.5396  0.2466         8           8
# 49653   0.2954  0.0586         6           6
# 89233   0.8887  0.4395        10          10
# 197894  0.0049  0.0024         0           0

# %%
raw_data.shape
# Out:
# (195668, 12)

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195668 entries, 0 to 227492
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Emg1        195668 non-null  float64
#  1   Emg2        195668 non-null  float64
#  2   Emg3        195668 non-null  float64
#  3   Emg4        195668 non-null  float64
#  4   Emg5        195668 non-null  float64
#  5   Emg6        195668 non-null  float64
#  6   Emg7        195668 non-null  float64
#  7   Emg8        195668 non-null  float64
#  8   Emg9        195668 non-null  float64
#  9   Emg10       195668 non-null  float64
#  10  stimulus    195668 non-null  uint8
#  11  restimulus  195668 non-null  uint8
# dtypes: float64(10), uint8(2)
# memory usage: 16.8 MB

# %%
print(raw_data.isnull().any())
# Out:
# Emg1          False
# Emg2          False
# Emg3          False
# Emg4          False
# Emg5          False
# Emg6          False
# Emg7          False
# Emg8          False
# Emg9          False
# Emg10         False
# stimulus      False
# restimulus    False
# dtype: bool

# %% [markdown]
# # Filtering

# %%
index_names = raw_data[ (raw_data['stimulus'] >=16)].index
raw_data.drop(index_names, inplace = True)

# %%
print("The Shape of the Dataset is : ",raw_data.shape)
print("************************************************************************************************************")
print("Column Names of the Dataset are : ",raw_data.columns)
print("************************************************************************************************************")
print(raw_data.info())
print("************************************************************************************************************")
raw_data.describe(include='all')
# Out:
# The Shape of the Dataset is :  (162490, 12)
# ************************************************************************************************************
# Column Names of the Dataset are :  Index(['Emg1', 'Emg2', 'Emg3', 'Emg4', 'Emg5', 'Emg6', 'Emg7', 'Emg8', 'Emg9',
#        'Emg10', 'stimulus', 'restimulus'],
#       dtype='object')
# ************************************************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 162490 entries, 0 to 227492
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Emg1        162490 non-null  float64
#  1   Emg2        162490 non-null  float64
#  2   Emg3        162490 non-null  float64
#  3   Emg4        162490 non-null  float64
#  4   Emg5        162490 non-null  float64
#  5   Emg6        162490 non-null  float64
#  6   Emg7        162490 non-null  float64
#  7   Emg8        162490 non-null  float64
#  8   Emg9        162490 non-null  float64
#  9   Emg10       162490 non-null  float64
#  10  stimulus    162490 non-null  uint8
#  11  restimulus  162490 non-null  uint8
# dtypes: float64(10), uint8(2)
# memory usage: 13.9 MB
# None
# ************************************************************************************************************
#                 Emg1           Emg2           Emg3           Emg4  \
# count  162490.000000  162490.000000  162490.000000  162490.000000
# mean        0.158731       0.099909       0.141161       0.038706
# std         0.332702       0.266460       0.296029       0.092014
# min         0.002400       0.000000       0.002400       0.002400
# 25%         0.002400       0.002400       0.002400       0.002400
# 50%         0.024400       0.002400       0.002400       0.002400
# 75%         0.144000       0.029300       0.124500       0.017100
# max         4.663100       4.660600       3.078600       1.684600
#
#                 Emg5           Emg6           Emg7           Emg8  \
# count  162490.000000  162490.000000  162490.000000  162490.000000
# mean        0.013822       0.017741       0.191917       0.251381
# std         0.027728       0.043612       0.389865       0.307862
# min         0.002400       0.000000       0.002400       0.002400
# 25%         0.002400       0.002400       0.009800       0.085400
# 50%         0.002400       0.002400       0.039100       0.134300
# 75%         0.007300       0.004900       0.175800       0.285600
# max         0.461400       0.632300       4.663100       4.577600
#
#                 Emg9          Emg10       stimulus     restimulus
# count  162490.000000  162490.000000  162490.000000  162490.000000
# mean        0.122461       0.057591       2.756964       2.756964
# std         0.215078       0.115781       4.576928       4.576928
# min         0.002400       0.002400       0.000000       0.000000
# 25%         0.002400       0.012200       0.000000       0.000000
# 50%         0.092800       0.039100       0.000000       0.000000
# 75%         0.141600       0.058600       5.000000       5.000000
# max         4.658200       4.231000      15.000000      15.000000

# %% [markdown]
# # Initializing Inputs and Outputs Variables

# %%
X = raw_data.iloc[:,0:10]
y = raw_data.stimulus

# %% [markdown]
# # One Hot Encoding

# %%
num_classes = 16

# %%
# One hot encoding for categorical labels
import keras
from keras import utils as np_utils

#y = keras.utils.to_categorical(y, num_classes)
y = keras.utils.np_utils.to_categorical(y, num_classes)

# %%
input_dim = X.shape[1]

# %% [markdown]
# # Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
standardscaler=StandardScaler()

# %%
sc = pd.DataFrame(standardscaler.fit_transform(X))

# %%
sc
# Out:
#                0         1         2         3         4         5         6  \
# 0      -0.469886 -0.365942 -0.468742 -0.394572 -0.411930 -0.351776 -0.410955
# 1      -0.469886 -0.365942 -0.468742 -0.394572 -0.411930 -0.351776 -0.398387
# 2      -0.469886 -0.365942 -0.468742 -0.394572 -0.411930 -0.351776 -0.385818
# 3      -0.469886 -0.365942 -0.460297 -0.394572 -0.411930 -0.351776 -0.398387
# 4      -0.469886 -0.365942 -0.468742 -0.394572 -0.321767 -0.351776 -0.417111
# ...          ...       ...       ...       ...       ...       ...       ...
# 162485 -0.469886 -0.365942 -0.468742 -0.394572 -0.411930 -0.351776 -0.486110
# 162486 -0.469886 -0.365942 -0.468742 -0.394572 -0.411930 -0.294452 -0.486110
# 162487 -0.469886 -0.365942 -0.468742 -0.394572 -0.411930 -0.351776 -0.486110
# 162488 -0.469886 -0.365942 -0.468742 -0.394572 -0.411930 -0.351776 -0.486110
# 162489 -0.469886 -0.365942 -0.468742 -0.394572 -0.411930 -0.351776 -0.486110
#
#                7         8         9
# 0      -0.578771 -0.558222  0.282513
# 1      -0.570651 -0.558222  0.304105
# 2      -0.531022 -0.558222  0.282513
# 3      -0.507310 -0.558222  0.219462
# 4      -0.507310 -0.558222  0.114090
# ...          ...       ...       ...
# 162485 -0.633991 -0.001679 -0.476684
# 162486 -0.649907  0.021104 -0.476684
# 162487 -0.649907  0.021104 -0.476684
# 162488 -0.658028  0.032262 -0.476684
# 162489 -0.673944  0.032262 -0.476684
#
# [162490 rows x 10 columns]

# %% [markdown]
# # Splitting data for training and testing

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 39)

# %% [markdown]
# # Deep Learning Architecture

# %%
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adadelta, Adagrad, Adamax, Nadam, Ftrl

# %% [raw]
# from sklearn.preprocessing import MinMaxScaler
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Input
# from tensorflow.keras.layers import Dense
# from tensorflow.keras.layers import LeakyReLU,ELU
# from tensorflow.keras.layers import BatchNormalization
# from tensorflow.keras.utils import plot_model
# import tensorflow as tf
# from sklearn.model_selection import cross_val_score
# from keras.models import Sequential
# from keras.layers import Dense, BatchNormalization, Dropout
# from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adadelta, Adagrad, Adamax, Nadam, Ftrl
# from keras.callbacks import EarlyStopping, ModelCheckpoint
# from keras.wrappers.scikit_learn import KerasClassifier
# from sklearn.metrics import make_scorer, accuracy_score
# from sklearn.model_selection import StratifiedKFold

# %% [raw]
# from keras.layers import LeakyReLU
# LeakyReLU = LeakyReLU(alpha=0.1)
# from keras.models import Sequential
# from keras.layers import Dense, Flatten, Convolution1D, Dropout
# from keras.initializers import random_uniform

# %% [markdown]
# # 1. Define Network

# %%
num_classes = 16
input_dim = X.shape[1]

# %%
visible = Input(shape=(input_dim,))
hidden1 = Dense(3000, activation='relu')(visible)
hidden2 = Dense(1500, activation='relu')(hidden1)
hidden3 = Dropout(0.2)(hidden2)
hidden4 = Dense(750, activation='relu')(hidden3)
hidden5 = Dense(375, activation='relu')(hidden4)
hidden6 = Dense(48, activation='relu')(hidden5)
output = Dense(num_classes, activation='softmax')(hidden6)
model = Model(inputs=visible, outputs=output)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 10)]              0
#
#  dense (Dense)               (None, 3000)              33000
#
#  dense_1 (Dense)             (None, 1500)              4501500
#
#  dropout (Dropout)           (None, 1500)              0
#
#  dense_2 (Dense)             (None, 750)               1125750
#
#  dense_3 (Dense)             (None, 375)               281625
#
#  dense_4 (Dense)             (None, 48)                18048
#
#  dense_5 (Dense)             (None, 16)                784
#
# =================================================================
# Total params: 5,960,707
# Trainable params: 5,960,707
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 2. Compile Network

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
plot_model(model, 'EMG_ANN.png', show_shapes = True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# # 3. Fit Network

# %%
import time
start_time = time.time()

history = model.fit(X_train, y_train, batch_size=9000, epochs=300, validation_data = (X_test, y_test))

print (time.time() - start_time, "seconds")
# Out:
# Epoch 1/300
# 17/17 [==============================] - 59s 3s/step - loss: 1.6947 - accuracy: 0.6213 - val_loss: 1.0961 - val_accuracy: 0.6719
# Epoch 2/300
# 17/17 [==============================] - 62s 4s/step - loss: 1.0272 - accuracy: 0.6884 - val_loss: 0.9410 - val_accuracy: 0.7083
# Epoch 3/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.9095 - accuracy: 0.7209 - val_loss: 0.8483 - val_accuracy: 0.7448
# Epoch 4/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.8168 - accuracy: 0.7520 - val_loss: 0.7533 - val_accuracy: 0.7758
# Epoch 5/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.7427 - accuracy: 0.7753 - val_loss: 0.7113 - val_accuracy: 0.7871
# Epoch 6/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.6796 - accuracy: 0.7908 - val_loss: 0.6264 - val_accuracy: 0.8090
# Epoch 7/300
# 17/17 [==============================] - 63s 4s/step - loss: 0.6206 - accuracy: 0.8090 - val_loss: 0.5867 - val_accuracy: 0.8176
# Epoch 8/300
# 17/17 [==============================] - 66s 4s/step - loss: 0.5777 - accuracy: 0.8204 - val_loss: 0.5427 - val_accuracy: 0.8331
# Epoch 9/300
# 17/17 [==============================] - 60s 3s/step - loss: 0.5399 - accuracy: 0.8316 - val_loss: 0.5071 - val_accuracy: 0.8443
# Epoch 10/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.5188 - accuracy: 0.8395 - val_loss: 0.4852 - val_accuracy: 0.8526
# Epoch 11/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.4966 - accuracy: 0.8450 - val_loss: 0.4639 - val_accuracy: 0.8564
# Epoch 12/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.4642 - accuracy: 0.8547 - val_loss: 0.4344 - val_accuracy: 0.8653
# Epoch 13/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.4445 - accuracy: 0.8587 - val_loss: 0.4167 - val_accuracy: 0.8697
# Epoch 14/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.4238 - accuracy: 0.8658 - val_loss: 0.4007 - val_accuracy: 0.8738
# Epoch 15/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.4127 - accuracy: 0.8694 - val_loss: 0.4028 - val_accuracy: 0.8740
# Epoch 16/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.3987 - accuracy: 0.8727 - val_loss: 0.3729 - val_accuracy: 0.8821
# Epoch 17/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.3854 - accuracy: 0.8773 - val_loss: 0.3608 - val_accuracy: 0.8865
# Epoch 18/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.3705 - accuracy: 0.8816 - val_loss: 0.3577 - val_accuracy: 0.8855
# Epoch 19/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.3624 - accuracy: 0.8844 - val_loss: 0.3396 - val_accuracy: 0.8918
# Epoch 20/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.3551 - accuracy: 0.8864 - val_loss: 0.3333 - val_accuracy: 0.8961
# Epoch 21/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.3383 - accuracy: 0.8915 - val_loss: 0.3296 - val_accuracy: 0.8951
# Epoch 22/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.3299 - accuracy: 0.8938 - val_loss: 0.3260 - val_accuracy: 0.8937
# Epoch 23/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.3225 - accuracy: 0.8959 - val_loss: 0.3031 - val_accuracy: 0.9024
# Epoch 24/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.3100 - accuracy: 0.8995 - val_loss: 0.3019 - val_accuracy: 0.9031
# Epoch 25/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.3045 - accuracy: 0.9017 - val_loss: 0.3111 - val_accuracy: 0.9001
# Epoch 26/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.3111 - accuracy: 0.9000 - val_loss: 0.2917 - val_accuracy: 0.9078
# Epoch 27/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.2927 - accuracy: 0.9057 - val_loss: 0.2824 - val_accuracy: 0.9117
# Epoch 28/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.2852 - accuracy: 0.9075 - val_loss: 0.2742 - val_accuracy: 0.9137
# Epoch 29/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.2922 - accuracy: 0.9072 - val_loss: 0.2975 - val_accuracy: 0.9113
# Epoch 30/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.2797 - accuracy: 0.9098 - val_loss: 0.2689 - val_accuracy: 0.9144
# Epoch 31/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.2694 - accuracy: 0.9132 - val_loss: 0.2580 - val_accuracy: 0.9181
# Epoch 32/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.2593 - accuracy: 0.9155 - val_loss: 0.2544 - val_accuracy: 0.9192
# Epoch 33/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.2551 - accuracy: 0.9176 - val_loss: 0.2468 - val_accuracy: 0.9210
# Epoch 34/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.2492 - accuracy: 0.9189 - val_loss: 0.2442 - val_accuracy: 0.9234
# Epoch 35/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.2430 - accuracy: 0.9206 - val_loss: 0.2349 - val_accuracy: 0.9252
# Epoch 36/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.2377 - accuracy: 0.9232 - val_loss: 0.2370 - val_accuracy: 0.9248
# Epoch 37/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.2358 - accuracy: 0.9232 - val_loss: 0.2426 - val_accuracy: 0.9254
# Epoch 38/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.2453 - accuracy: 0.9219 - val_loss: 0.2314 - val_accuracy: 0.9266
# Epoch 39/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.2321 - accuracy: 0.9252 - val_loss: 0.2250 - val_accuracy: 0.9288
# Epoch 40/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.2229 - accuracy: 0.9274 - val_loss: 0.2167 - val_accuracy: 0.9309
# Epoch 41/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.2177 - accuracy: 0.9292 - val_loss: 0.2193 - val_accuracy: 0.9297
# Epoch 42/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.2183 - accuracy: 0.9288 - val_loss: 0.2137 - val_accuracy: 0.9311
# Epoch 43/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.2113 - accuracy: 0.9316 - val_loss: 0.2058 - val_accuracy: 0.9338
# Epoch 44/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.2037 - accuracy: 0.9338 - val_loss: 0.2138 - val_accuracy: 0.9295
# Epoch 45/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.2044 - accuracy: 0.9337 - val_loss: 0.2005 - val_accuracy: 0.9368
# Epoch 46/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1981 - accuracy: 0.9354 - val_loss: 0.2011 - val_accuracy: 0.9377
# Epoch 47/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1981 - accuracy: 0.9358 - val_loss: 0.2169 - val_accuracy: 0.9335
# Epoch 48/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.2091 - accuracy: 0.9334 - val_loss: 0.2025 - val_accuracy: 0.9360
# Epoch 49/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1918 - accuracy: 0.9376 - val_loss: 0.1942 - val_accuracy: 0.9398
# Epoch 50/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1869 - accuracy: 0.9393 - val_loss: 0.2019 - val_accuracy: 0.9367
# Epoch 51/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1928 - accuracy: 0.9384 - val_loss: 0.1892 - val_accuracy: 0.9388
# Epoch 52/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.1809 - accuracy: 0.9418 - val_loss: 0.1918 - val_accuracy: 0.9385
# Epoch 53/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1792 - accuracy: 0.9416 - val_loss: 0.1808 - val_accuracy: 0.9420
# Epoch 54/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1728 - accuracy: 0.9439 - val_loss: 0.1792 - val_accuracy: 0.9452
# Epoch 55/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1705 - accuracy: 0.9444 - val_loss: 0.1838 - val_accuracy: 0.9416
# Epoch 56/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1695 - accuracy: 0.9448 - val_loss: 0.1712 - val_accuracy: 0.9451
# Epoch 57/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.1665 - accuracy: 0.9463 - val_loss: 0.1777 - val_accuracy: 0.9450
# Epoch 58/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1646 - accuracy: 0.9466 - val_loss: 0.1672 - val_accuracy: 0.9468
# Epoch 59/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1605 - accuracy: 0.9487 - val_loss: 0.1732 - val_accuracy: 0.9461
# Epoch 60/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1601 - accuracy: 0.9482 - val_loss: 0.1707 - val_accuracy: 0.9441
# Epoch 61/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.1571 - accuracy: 0.9495 - val_loss: 0.1573 - val_accuracy: 0.9510
# Epoch 62/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.1536 - accuracy: 0.9511 - val_loss: 0.1662 - val_accuracy: 0.9485
# Epoch 63/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.1573 - accuracy: 0.9498 - val_loss: 0.1788 - val_accuracy: 0.9439
# Epoch 64/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1583 - accuracy: 0.9494 - val_loss: 0.1613 - val_accuracy: 0.9475
# Epoch 65/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.1479 - accuracy: 0.9523 - val_loss: 0.1526 - val_accuracy: 0.9517
# Epoch 66/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1440 - accuracy: 0.9540 - val_loss: 0.1522 - val_accuracy: 0.9522
# Epoch 67/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1418 - accuracy: 0.9543 - val_loss: 0.1507 - val_accuracy: 0.9527
# Epoch 68/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1403 - accuracy: 0.9550 - val_loss: 0.1485 - val_accuracy: 0.9543
# Epoch 69/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1381 - accuracy: 0.9558 - val_loss: 0.1466 - val_accuracy: 0.9532
# Epoch 70/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1361 - accuracy: 0.9564 - val_loss: 0.1467 - val_accuracy: 0.9544
# Epoch 71/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.1337 - accuracy: 0.9575 - val_loss: 0.1427 - val_accuracy: 0.9550
# Epoch 72/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.1325 - accuracy: 0.9576 - val_loss: 0.1432 - val_accuracy: 0.9555
# Epoch 73/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.1305 - accuracy: 0.9581 - val_loss: 0.1474 - val_accuracy: 0.9514
# Epoch 74/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1312 - accuracy: 0.9577 - val_loss: 0.1473 - val_accuracy: 0.9529
# Epoch 75/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1302 - accuracy: 0.9581 - val_loss: 0.1388 - val_accuracy: 0.9545
# Epoch 76/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1249 - accuracy: 0.9602 - val_loss: 0.1386 - val_accuracy: 0.9568
# Epoch 77/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1249 - accuracy: 0.9601 - val_loss: 0.1344 - val_accuracy: 0.9578
# Epoch 78/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1213 - accuracy: 0.9616 - val_loss: 0.1499 - val_accuracy: 0.9524
# Epoch 79/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1227 - accuracy: 0.9606 - val_loss: 0.1341 - val_accuracy: 0.9577
# Epoch 80/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1179 - accuracy: 0.9624 - val_loss: 0.1387 - val_accuracy: 0.9574
# Epoch 81/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1200 - accuracy: 0.9616 - val_loss: 0.1339 - val_accuracy: 0.9575
# Epoch 82/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1161 - accuracy: 0.9629 - val_loss: 0.1302 - val_accuracy: 0.9582
# Epoch 83/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1147 - accuracy: 0.9634 - val_loss: 0.1223 - val_accuracy: 0.9612
# Epoch 84/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1133 - accuracy: 0.9639 - val_loss: 0.1218 - val_accuracy: 0.9612
# Epoch 85/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1112 - accuracy: 0.9649 - val_loss: 0.1203 - val_accuracy: 0.9636
# Epoch 86/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1099 - accuracy: 0.9649 - val_loss: 0.1306 - val_accuracy: 0.9604
# Epoch 87/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1087 - accuracy: 0.9656 - val_loss: 0.1288 - val_accuracy: 0.9618
# Epoch 88/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1071 - accuracy: 0.9660 - val_loss: 0.1269 - val_accuracy: 0.9599
# Epoch 89/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1067 - accuracy: 0.9659 - val_loss: 0.1253 - val_accuracy: 0.9626
# Epoch 90/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1084 - accuracy: 0.9655 - val_loss: 0.1214 - val_accuracy: 0.9617
# Epoch 91/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1058 - accuracy: 0.9662 - val_loss: 0.1204 - val_accuracy: 0.9634
# Epoch 92/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1056 - accuracy: 0.9663 - val_loss: 0.1172 - val_accuracy: 0.9635
# Epoch 93/300
# 17/17 [==============================] - 60s 3s/step - loss: 0.1030 - accuracy: 0.9675 - val_loss: 0.1212 - val_accuracy: 0.9622
# Epoch 94/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1019 - accuracy: 0.9676 - val_loss: 0.1168 - val_accuracy: 0.9654
# Epoch 95/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0993 - accuracy: 0.9686 - val_loss: 0.1154 - val_accuracy: 0.9629
# Epoch 96/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0977 - accuracy: 0.9690 - val_loss: 0.1182 - val_accuracy: 0.9618
# Epoch 97/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.1008 - accuracy: 0.9683 - val_loss: 0.1152 - val_accuracy: 0.9638
# Epoch 98/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0961 - accuracy: 0.9693 - val_loss: 0.1121 - val_accuracy: 0.9660
# Epoch 99/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0915 - accuracy: 0.9713 - val_loss: 0.1061 - val_accuracy: 0.9669
# Epoch 100/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0912 - accuracy: 0.9713 - val_loss: 0.1052 - val_accuracy: 0.9676
# Epoch 101/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0929 - accuracy: 0.9704 - val_loss: 0.1132 - val_accuracy: 0.9650
# Epoch 102/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0913 - accuracy: 0.9708 - val_loss: 0.1054 - val_accuracy: 0.9676
# Epoch 103/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0885 - accuracy: 0.9722 - val_loss: 0.1048 - val_accuracy: 0.9682
# Epoch 104/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0863 - accuracy: 0.9732 - val_loss: 0.1008 - val_accuracy: 0.9693
# Epoch 105/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0859 - accuracy: 0.9731 - val_loss: 0.1067 - val_accuracy: 0.9669
# Epoch 106/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0855 - accuracy: 0.9729 - val_loss: 0.1045 - val_accuracy: 0.9682
# Epoch 107/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0861 - accuracy: 0.9727 - val_loss: 0.0972 - val_accuracy: 0.9705
# Epoch 108/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0845 - accuracy: 0.9733 - val_loss: 0.0998 - val_accuracy: 0.9702
# Epoch 109/300
# 17/17 [==============================] - 61s 4s/step - loss: 0.0825 - accuracy: 0.9740 - val_loss: 0.0999 - val_accuracy: 0.9699
# Epoch 110/300
# 17/17 [==============================] - 61s 4s/step - loss: 0.0798 - accuracy: 0.9753 - val_loss: 0.0998 - val_accuracy: 0.9693
# Epoch 111/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0789 - accuracy: 0.9754 - val_loss: 0.0932 - val_accuracy: 0.9709
# Epoch 112/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0797 - accuracy: 0.9752 - val_loss: 0.0973 - val_accuracy: 0.9710
# Epoch 113/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0823 - accuracy: 0.9736 - val_loss: 0.1022 - val_accuracy: 0.9691
# Epoch 114/300
# 17/17 [==============================] - 62s 4s/step - loss: 0.0806 - accuracy: 0.9743 - val_loss: 0.1041 - val_accuracy: 0.9669
# Epoch 115/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0806 - accuracy: 0.9750 - val_loss: 0.0916 - val_accuracy: 0.9719
# Epoch 116/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0751 - accuracy: 0.9770 - val_loss: 0.0930 - val_accuracy: 0.9716
# Epoch 117/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0761 - accuracy: 0.9763 - val_loss: 0.0967 - val_accuracy: 0.9707
# Epoch 118/300
# 17/17 [==============================] - 60s 3s/step - loss: 0.0749 - accuracy: 0.9760 - val_loss: 0.0978 - val_accuracy: 0.9712
# Epoch 119/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0785 - accuracy: 0.9754 - val_loss: 0.0966 - val_accuracy: 0.9712
# Epoch 120/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0786 - accuracy: 0.9753 - val_loss: 0.0938 - val_accuracy: 0.9709
# Epoch 121/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0755 - accuracy: 0.9761 - val_loss: 0.0899 - val_accuracy: 0.9722
# Epoch 122/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0719 - accuracy: 0.9776 - val_loss: 0.0881 - val_accuracy: 0.9738
# Epoch 123/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0702 - accuracy: 0.9780 - val_loss: 0.0884 - val_accuracy: 0.9730
# Epoch 124/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0720 - accuracy: 0.9774 - val_loss: 0.0880 - val_accuracy: 0.9732
# Epoch 125/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0690 - accuracy: 0.9789 - val_loss: 0.0874 - val_accuracy: 0.9742
# Epoch 126/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0691 - accuracy: 0.9782 - val_loss: 0.0866 - val_accuracy: 0.9753
# Epoch 127/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0691 - accuracy: 0.9785 - val_loss: 0.0884 - val_accuracy: 0.9743
# Epoch 128/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0715 - accuracy: 0.9778 - val_loss: 0.0907 - val_accuracy: 0.9740
# Epoch 129/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0684 - accuracy: 0.9788 - val_loss: 0.0864 - val_accuracy: 0.9750
# Epoch 130/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0670 - accuracy: 0.9786 - val_loss: 0.0876 - val_accuracy: 0.9742
# Epoch 131/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0661 - accuracy: 0.9795 - val_loss: 0.0846 - val_accuracy: 0.9738
# Epoch 132/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0682 - accuracy: 0.9784 - val_loss: 0.0850 - val_accuracy: 0.9752
# Epoch 133/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0658 - accuracy: 0.9798 - val_loss: 0.0881 - val_accuracy: 0.9748
# Epoch 134/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0654 - accuracy: 0.9793 - val_loss: 0.0850 - val_accuracy: 0.9756
# Epoch 135/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0653 - accuracy: 0.9796 - val_loss: 0.0866 - val_accuracy: 0.9742
# Epoch 136/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0642 - accuracy: 0.9798 - val_loss: 0.0853 - val_accuracy: 0.9753
# Epoch 137/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0633 - accuracy: 0.9803 - val_loss: 0.0866 - val_accuracy: 0.9742
# Epoch 138/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0643 - accuracy: 0.9797 - val_loss: 0.0840 - val_accuracy: 0.9743
# Epoch 139/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0616 - accuracy: 0.9806 - val_loss: 0.0857 - val_accuracy: 0.9748
# Epoch 140/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0629 - accuracy: 0.9804 - val_loss: 0.0811 - val_accuracy: 0.9759
# Epoch 141/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0616 - accuracy: 0.9808 - val_loss: 0.0842 - val_accuracy: 0.9752
# Epoch 142/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0609 - accuracy: 0.9812 - val_loss: 0.0808 - val_accuracy: 0.9762
# Epoch 143/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0604 - accuracy: 0.9813 - val_loss: 0.0781 - val_accuracy: 0.9785
# Epoch 144/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0591 - accuracy: 0.9816 - val_loss: 0.0819 - val_accuracy: 0.9759
# Epoch 145/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0590 - accuracy: 0.9815 - val_loss: 0.0864 - val_accuracy: 0.9743
# Epoch 146/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0613 - accuracy: 0.9808 - val_loss: 0.0872 - val_accuracy: 0.9753
# Epoch 147/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0620 - accuracy: 0.9803 - val_loss: 0.0781 - val_accuracy: 0.9772
# Epoch 148/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0560 - accuracy: 0.9825 - val_loss: 0.0798 - val_accuracy: 0.9769
# Epoch 149/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0579 - accuracy: 0.9817 - val_loss: 0.0846 - val_accuracy: 0.9760
# Epoch 150/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0603 - accuracy: 0.9811 - val_loss: 0.0821 - val_accuracy: 0.9759
# Epoch 151/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0607 - accuracy: 0.9810 - val_loss: 0.0843 - val_accuracy: 0.9754
# Epoch 152/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0595 - accuracy: 0.9809 - val_loss: 0.0868 - val_accuracy: 0.9749
# Epoch 153/300
# 17/17 [==============================] - 61s 4s/step - loss: 0.0573 - accuracy: 0.9821 - val_loss: 0.0765 - val_accuracy: 0.9782
# Epoch 154/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0542 - accuracy: 0.9831 - val_loss: 0.0783 - val_accuracy: 0.9774
# Epoch 155/300
# 17/17 [==============================] - 62s 4s/step - loss: 0.0530 - accuracy: 0.9838 - val_loss: 0.0734 - val_accuracy: 0.9794
# Epoch 156/300
# 17/17 [==============================] - 61s 4s/step - loss: 0.0532 - accuracy: 0.9834 - val_loss: 0.0771 - val_accuracy: 0.9780
# Epoch 157/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0525 - accuracy: 0.9836 - val_loss: 0.0784 - val_accuracy: 0.9775
# Epoch 158/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0526 - accuracy: 0.9839 - val_loss: 0.0752 - val_accuracy: 0.9788
# Epoch 159/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0529 - accuracy: 0.9838 - val_loss: 0.0758 - val_accuracy: 0.9777
# Epoch 160/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0559 - accuracy: 0.9823 - val_loss: 0.0804 - val_accuracy: 0.9768
# Epoch 161/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0559 - accuracy: 0.9825 - val_loss: 0.0795 - val_accuracy: 0.9761
# Epoch 162/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0536 - accuracy: 0.9833 - val_loss: 0.0742 - val_accuracy: 0.9786
# Epoch 163/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0500 - accuracy: 0.9845 - val_loss: 0.0741 - val_accuracy: 0.9785
# Epoch 164/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0510 - accuracy: 0.9841 - val_loss: 0.0745 - val_accuracy: 0.9786
# Epoch 165/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0497 - accuracy: 0.9845 - val_loss: 0.0742 - val_accuracy: 0.9768
# Epoch 166/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0508 - accuracy: 0.9843 - val_loss: 0.0713 - val_accuracy: 0.9792
# Epoch 167/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0492 - accuracy: 0.9845 - val_loss: 0.0737 - val_accuracy: 0.9788
# Epoch 168/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0523 - accuracy: 0.9842 - val_loss: 0.0728 - val_accuracy: 0.9786
# Epoch 169/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0479 - accuracy: 0.9856 - val_loss: 0.0733 - val_accuracy: 0.9788
# Epoch 170/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0481 - accuracy: 0.9848 - val_loss: 0.0752 - val_accuracy: 0.9776
# Epoch 171/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0507 - accuracy: 0.9842 - val_loss: 0.0727 - val_accuracy: 0.9794
# Epoch 172/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0492 - accuracy: 0.9846 - val_loss: 0.0752 - val_accuracy: 0.9789
# Epoch 173/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0484 - accuracy: 0.9850 - val_loss: 0.0727 - val_accuracy: 0.9792
# Epoch 174/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0485 - accuracy: 0.9848 - val_loss: 0.0727 - val_accuracy: 0.9795
# Epoch 175/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0456 - accuracy: 0.9860 - val_loss: 0.0743 - val_accuracy: 0.9790
# Epoch 176/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0462 - accuracy: 0.9856 - val_loss: 0.0741 - val_accuracy: 0.9786
# Epoch 177/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0475 - accuracy: 0.9854 - val_loss: 0.0692 - val_accuracy: 0.9810
# Epoch 178/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0473 - accuracy: 0.9850 - val_loss: 0.0751 - val_accuracy: 0.9785
# Epoch 179/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0486 - accuracy: 0.9849 - val_loss: 0.0745 - val_accuracy: 0.9788
# Epoch 180/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0469 - accuracy: 0.9852 - val_loss: 0.0758 - val_accuracy: 0.9781
# Epoch 181/300
# 17/17 [==============================] - 58s 3s/step - loss: 0.0504 - accuracy: 0.9843 - val_loss: 0.0811 - val_accuracy: 0.9770
# Epoch 182/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0491 - accuracy: 0.9846 - val_loss: 0.0749 - val_accuracy: 0.9794
# Epoch 183/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0467 - accuracy: 0.9858 - val_loss: 0.0735 - val_accuracy: 0.9794
# Epoch 184/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0440 - accuracy: 0.9862 - val_loss: 0.0706 - val_accuracy: 0.9793
# Epoch 185/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0449 - accuracy: 0.9862 - val_loss: 0.0699 - val_accuracy: 0.9810
# Epoch 186/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0436 - accuracy: 0.9865 - val_loss: 0.0693 - val_accuracy: 0.9803
# Epoch 187/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0427 - accuracy: 0.9871 - val_loss: 0.0701 - val_accuracy: 0.9800
# Epoch 188/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0432 - accuracy: 0.9866 - val_loss: 0.0696 - val_accuracy: 0.9806
# Epoch 189/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0431 - accuracy: 0.9867 - val_loss: 0.0668 - val_accuracy: 0.9810
# Epoch 190/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0435 - accuracy: 0.9865 - val_loss: 0.0669 - val_accuracy: 0.9804
# Epoch 191/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0441 - accuracy: 0.9861 - val_loss: 0.0701 - val_accuracy: 0.9797
# Epoch 192/300
# 17/17 [==============================] - 61s 4s/step - loss: 0.0430 - accuracy: 0.9866 - val_loss: 0.0681 - val_accuracy: 0.9808
# Epoch 193/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0430 - accuracy: 0.9867 - val_loss: 0.0735 - val_accuracy: 0.9794
# Epoch 194/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0407 - accuracy: 0.9874 - val_loss: 0.0645 - val_accuracy: 0.9807
# Epoch 195/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0398 - accuracy: 0.9878 - val_loss: 0.0705 - val_accuracy: 0.9804
# Epoch 196/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0424 - accuracy: 0.9868 - val_loss: 0.0767 - val_accuracy: 0.9801
# Epoch 197/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0453 - accuracy: 0.9858 - val_loss: 0.0750 - val_accuracy: 0.9779
# Epoch 198/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0432 - accuracy: 0.9864 - val_loss: 0.0674 - val_accuracy: 0.9807
# Epoch 199/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0412 - accuracy: 0.9873 - val_loss: 0.0670 - val_accuracy: 0.9823
# Epoch 200/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0408 - accuracy: 0.9869 - val_loss: 0.0659 - val_accuracy: 0.9824
# Epoch 201/300
# 17/17 [==============================] - 58s 3s/step - loss: 0.0399 - accuracy: 0.9874 - val_loss: 0.0658 - val_accuracy: 0.9814
# Epoch 202/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0407 - accuracy: 0.9873 - val_loss: 0.0677 - val_accuracy: 0.9799
# Epoch 203/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0422 - accuracy: 0.9870 - val_loss: 0.0718 - val_accuracy: 0.9799
# Epoch 204/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0460 - accuracy: 0.9852 - val_loss: 0.0738 - val_accuracy: 0.9785
# Epoch 205/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0429 - accuracy: 0.9861 - val_loss: 0.0663 - val_accuracy: 0.9812
# Epoch 206/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0392 - accuracy: 0.9877 - val_loss: 0.0675 - val_accuracy: 0.9812
# Epoch 207/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0398 - accuracy: 0.9876 - val_loss: 0.0726 - val_accuracy: 0.9804
# Epoch 208/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0396 - accuracy: 0.9876 - val_loss: 0.0682 - val_accuracy: 0.9804
# Epoch 209/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0392 - accuracy: 0.9881 - val_loss: 0.0716 - val_accuracy: 0.9806
# Epoch 210/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0389 - accuracy: 0.9876 - val_loss: 0.0732 - val_accuracy: 0.9802
# Epoch 211/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0409 - accuracy: 0.9873 - val_loss: 0.0700 - val_accuracy: 0.9805
# Epoch 212/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0411 - accuracy: 0.9871 - val_loss: 0.0656 - val_accuracy: 0.9812
# Epoch 213/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0402 - accuracy: 0.9876 - val_loss: 0.0685 - val_accuracy: 0.9804
# Epoch 214/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0398 - accuracy: 0.9873 - val_loss: 0.0682 - val_accuracy: 0.9811
# Epoch 215/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0388 - accuracy: 0.9878 - val_loss: 0.0644 - val_accuracy: 0.9819
# Epoch 216/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0380 - accuracy: 0.9882 - val_loss: 0.0647 - val_accuracy: 0.9817
# Epoch 217/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0398 - accuracy: 0.9875 - val_loss: 0.0636 - val_accuracy: 0.9820
# Epoch 218/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0381 - accuracy: 0.9881 - val_loss: 0.0713 - val_accuracy: 0.9801
# Epoch 219/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0388 - accuracy: 0.9880 - val_loss: 0.0653 - val_accuracy: 0.9810
# Epoch 220/300
# 17/17 [==============================] - 61s 4s/step - loss: 0.0393 - accuracy: 0.9876 - val_loss: 0.0691 - val_accuracy: 0.9815
# Epoch 221/300
# 17/17 [==============================] - 61s 4s/step - loss: 0.0373 - accuracy: 0.9885 - val_loss: 0.0662 - val_accuracy: 0.9817
# Epoch 222/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0374 - accuracy: 0.9881 - val_loss: 0.0698 - val_accuracy: 0.9790
# Epoch 223/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0384 - accuracy: 0.9879 - val_loss: 0.0655 - val_accuracy: 0.9823
# Epoch 224/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0363 - accuracy: 0.9889 - val_loss: 0.0626 - val_accuracy: 0.9826
# Epoch 225/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0362 - accuracy: 0.9890 - val_loss: 0.0631 - val_accuracy: 0.9829
# Epoch 226/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0355 - accuracy: 0.9891 - val_loss: 0.0680 - val_accuracy: 0.9821
# Epoch 227/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0368 - accuracy: 0.9887 - val_loss: 0.0604 - val_accuracy: 0.9836
# Epoch 228/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0345 - accuracy: 0.9893 - val_loss: 0.0636 - val_accuracy: 0.9833
# Epoch 229/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0363 - accuracy: 0.9889 - val_loss: 0.0663 - val_accuracy: 0.9807
# Epoch 230/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0358 - accuracy: 0.9891 - val_loss: 0.0629 - val_accuracy: 0.9832
# Epoch 231/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0354 - accuracy: 0.9889 - val_loss: 0.0687 - val_accuracy: 0.9809
# Epoch 232/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0349 - accuracy: 0.9887 - val_loss: 0.0646 - val_accuracy: 0.9822
# Epoch 233/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0354 - accuracy: 0.9891 - val_loss: 0.0635 - val_accuracy: 0.9817
# Epoch 234/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0347 - accuracy: 0.9892 - val_loss: 0.0622 - val_accuracy: 0.9833
# Epoch 235/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0357 - accuracy: 0.9890 - val_loss: 0.0607 - val_accuracy: 0.9831
# Epoch 236/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0355 - accuracy: 0.9889 - val_loss: 0.0643 - val_accuracy: 0.9815
# Epoch 237/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0351 - accuracy: 0.9892 - val_loss: 0.0620 - val_accuracy: 0.9827
# Epoch 238/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0361 - accuracy: 0.9889 - val_loss: 0.0646 - val_accuracy: 0.9823
# Epoch 239/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0361 - accuracy: 0.9888 - val_loss: 0.0633 - val_accuracy: 0.9828
# Epoch 240/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0327 - accuracy: 0.9901 - val_loss: 0.0623 - val_accuracy: 0.9842
# Epoch 241/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0320 - accuracy: 0.9900 - val_loss: 0.0611 - val_accuracy: 0.9841
# Epoch 242/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0325 - accuracy: 0.9899 - val_loss: 0.0634 - val_accuracy: 0.9825
# Epoch 243/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0337 - accuracy: 0.9897 - val_loss: 0.0625 - val_accuracy: 0.9828
# Epoch 244/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0319 - accuracy: 0.9902 - val_loss: 0.0656 - val_accuracy: 0.9834
# Epoch 245/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0326 - accuracy: 0.9901 - val_loss: 0.0672 - val_accuracy: 0.9817
# Epoch 246/300
# 17/17 [==============================] - 58s 3s/step - loss: 0.0324 - accuracy: 0.9899 - val_loss: 0.0595 - val_accuracy: 0.9843
# Epoch 247/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0314 - accuracy: 0.9904 - val_loss: 0.0593 - val_accuracy: 0.9836
# Epoch 248/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0328 - accuracy: 0.9899 - val_loss: 0.0645 - val_accuracy: 0.9823
# Epoch 249/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0346 - accuracy: 0.9894 - val_loss: 0.0659 - val_accuracy: 0.9817
# Epoch 250/300
# 17/17 [==============================] - 58s 3s/step - loss: 0.0341 - accuracy: 0.9892 - val_loss: 0.0615 - val_accuracy: 0.9836
# Epoch 251/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0336 - accuracy: 0.9897 - val_loss: 0.0653 - val_accuracy: 0.9822
# Epoch 252/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0320 - accuracy: 0.9900 - val_loss: 0.0614 - val_accuracy: 0.9831
# Epoch 253/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0304 - accuracy: 0.9907 - val_loss: 0.0702 - val_accuracy: 0.9789
# Epoch 254/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0343 - accuracy: 0.9893 - val_loss: 0.0608 - val_accuracy: 0.9836
# Epoch 255/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0318 - accuracy: 0.9901 - val_loss: 0.0657 - val_accuracy: 0.9823
# Epoch 256/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0325 - accuracy: 0.9901 - val_loss: 0.0614 - val_accuracy: 0.9839
# Epoch 257/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0298 - accuracy: 0.9908 - val_loss: 0.0588 - val_accuracy: 0.9841
# Epoch 258/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0292 - accuracy: 0.9910 - val_loss: 0.0599 - val_accuracy: 0.9834
# Epoch 259/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0292 - accuracy: 0.9910 - val_loss: 0.0608 - val_accuracy: 0.9837
# Epoch 260/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0290 - accuracy: 0.9910 - val_loss: 0.0573 - val_accuracy: 0.9841
# Epoch 261/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0277 - accuracy: 0.9916 - val_loss: 0.0583 - val_accuracy: 0.9847
# Epoch 262/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0288 - accuracy: 0.9912 - val_loss: 0.0614 - val_accuracy: 0.9824
# Epoch 263/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0320 - accuracy: 0.9899 - val_loss: 0.0629 - val_accuracy: 0.9822
# Epoch 264/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0316 - accuracy: 0.9899 - val_loss: 0.0594 - val_accuracy: 0.9838
# Epoch 265/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0285 - accuracy: 0.9915 - val_loss: 0.0610 - val_accuracy: 0.9834
# Epoch 266/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0297 - accuracy: 0.9909 - val_loss: 0.0610 - val_accuracy: 0.9839
# Epoch 267/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0306 - accuracy: 0.9904 - val_loss: 0.0621 - val_accuracy: 0.9830
# Epoch 268/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0305 - accuracy: 0.9906 - val_loss: 0.0614 - val_accuracy: 0.9839
# Epoch 269/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0307 - accuracy: 0.9902 - val_loss: 0.0628 - val_accuracy: 0.9839
# Epoch 270/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0318 - accuracy: 0.9903 - val_loss: 0.0662 - val_accuracy: 0.9802
# Epoch 271/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0315 - accuracy: 0.9900 - val_loss: 0.0646 - val_accuracy: 0.9831
# Epoch 272/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0309 - accuracy: 0.9904 - val_loss: 0.0582 - val_accuracy: 0.9849
# Epoch 273/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0313 - accuracy: 0.9904 - val_loss: 0.0667 - val_accuracy: 0.9830
# Epoch 274/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0319 - accuracy: 0.9902 - val_loss: 0.0618 - val_accuracy: 0.9828
# Epoch 275/300
# 17/17 [==============================] - 60s 3s/step - loss: 0.0323 - accuracy: 0.9901 - val_loss: 0.0621 - val_accuracy: 0.9836
# Epoch 276/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0306 - accuracy: 0.9905 - val_loss: 0.0627 - val_accuracy: 0.9836
# Epoch 277/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0307 - accuracy: 0.9904 - val_loss: 0.0594 - val_accuracy: 0.9837
# Epoch 278/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0303 - accuracy: 0.9906 - val_loss: 0.0637 - val_accuracy: 0.9843
# Epoch 279/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0305 - accuracy: 0.9906 - val_loss: 0.0613 - val_accuracy: 0.9830
# Epoch 280/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0287 - accuracy: 0.9911 - val_loss: 0.0587 - val_accuracy: 0.9846
# Epoch 281/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0287 - accuracy: 0.9912 - val_loss: 0.0611 - val_accuracy: 0.9841
# Epoch 282/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0314 - accuracy: 0.9902 - val_loss: 0.0603 - val_accuracy: 0.9843
# Epoch 283/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0289 - accuracy: 0.9909 - val_loss: 0.0632 - val_accuracy: 0.9831
# Epoch 284/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0282 - accuracy: 0.9912 - val_loss: 0.0643 - val_accuracy: 0.9827
# Epoch 285/300
# 17/17 [==============================] - 61s 4s/step - loss: 0.0285 - accuracy: 0.9913 - val_loss: 0.0625 - val_accuracy: 0.9831
# Epoch 286/300
# 17/17 [==============================] - 63s 4s/step - loss: 0.0276 - accuracy: 0.9915 - val_loss: 0.0571 - val_accuracy: 0.9845
# Epoch 287/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0268 - accuracy: 0.9917 - val_loss: 0.0578 - val_accuracy: 0.9844
# Epoch 288/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0284 - accuracy: 0.9913 - val_loss: 0.0633 - val_accuracy: 0.9832
# Epoch 289/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0292 - accuracy: 0.9911 - val_loss: 0.0582 - val_accuracy: 0.9844
# Epoch 290/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0281 - accuracy: 0.9912 - val_loss: 0.0637 - val_accuracy: 0.9833
# Epoch 291/300
# 17/17 [==============================] - 62s 4s/step - loss: 0.0278 - accuracy: 0.9915 - val_loss: 0.0622 - val_accuracy: 0.9839
# Epoch 292/300
# 17/17 [==============================] - 60s 3s/step - loss: 0.0290 - accuracy: 0.9909 - val_loss: 0.0611 - val_accuracy: 0.9844
# Epoch 293/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0283 - accuracy: 0.9910 - val_loss: 0.0637 - val_accuracy: 0.9831
# Epoch 294/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0271 - accuracy: 0.9914 - val_loss: 0.0630 - val_accuracy: 0.9841
# Epoch 295/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0289 - accuracy: 0.9910 - val_loss: 0.0698 - val_accuracy: 0.9825
# Epoch 296/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0299 - accuracy: 0.9909 - val_loss: 0.0652 - val_accuracy: 0.9826
# Epoch 297/300
# 17/17 [==============================] - 60s 4s/step - loss: 0.0332 - accuracy: 0.9895 - val_loss: 0.0676 - val_accuracy: 0.9829
# Epoch 298/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0307 - accuracy: 0.9903 - val_loss: 0.0600 - val_accuracy: 0.9839
# Epoch 299/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0280 - accuracy: 0.9913 - val_loss: 0.0629 - val_accuracy: 0.9835
# Epoch 300/300
# 17/17 [==============================] - 59s 3s/step - loss: 0.0270 - accuracy: 0.9915 - val_loss: 0.0586 - val_accuracy: 0.9846
# 17799.559818029404 seconds

# %% [markdown]
# # 4.Evaluate Network

# %% [markdown]
# # 4.1. Plotting Loss and Accuracy¶

# %%
#Loss Curve


plt.plot(figsize = [8,6])

plt.plot(history.history['loss'],'r',linewidth = 3.0)
plt.plot(history.history['val_loss'],'b',linewidth = 3.0)

plt.legend(['Training Loss', 'Validation Loss'], fontsize = 18)

plt.xlabel('Epochs', fontsize = 16)
plt.ylabel('Loss', fontsize = 16)

plt.title('Loss Curve of Deep Neural Netowork' , fontsize = 16 )
# Out:
# Text(0.5, 1.0, 'Loss Curve of Deep Neural Netowork')

# %%
#Accuracy Curve

plt.plot(figsize = [8,6])
plt.plot(history.history['accuracy'],'r',linewidth = 3.0)
plt.plot(history.history['val_accuracy'],'b',linewidth = 3.0)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize = 18)

plt.xlabel('Epochs', fontsize = 16)
plt.ylabel('Accuracy', fontsize = 16)


plt.title('Accuracy Curve of Deep Neural Netowork' , fontsize = 16 )
# Out:
# Text(0.5, 1.0, 'Accuracy Curve of Deep Neural Netowork')

# %% [markdown]
# # 4.2 Make Predictions

# %%
predictions = model.predict(X_test)
predictions = np.argmax(predictions, axis = 1)
# Out:
# 508/508 [==============================] - 8s 14ms/step

# %%
predictions
# Out:
# array([0, 1, 5, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# # Transforming from One Hot Encoding

# %%
y_test =np.argmax(y_test, axis=1)
y_test[1]
# Out:
# 1

# %%
from sklearn.metrics import accuracy_score
accuracy = {accuracy_score(y_test, predictions)}
print(f"Accuracy is: {accuracy_score(y_test, predictions)* 100}")
# Out:
# Accuracy is: 98.46144378115577

# %% [markdown]
# # 4.3 Classification Report

# %%
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, classification_report
print('\033[1m' +'Classification report : '+ '\033[0m\n', classification_report(y_test, predictions))

cm = confusion_matrix(predictions, y_test)
print('\033[1m' +'Confusion Matrix : '+ '\033[0m')
sns.heatmap(cm, cmap = 'OrRd',annot = True, fmt='d')
plt.show()
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     10705
#            1       0.98      0.97      0.98       357
#            2       0.97      0.97      0.97       367
#            3       0.96      0.96      0.96       362
#            4       0.98      0.94      0.96       357
#            5       0.97      0.96      0.97       388
#            6       0.99      0.97      0.98       416
#            7       0.93      0.97      0.95       324
#            8       0.97      0.97      0.97       333
#            9       0.99      0.96      0.98       350
#           10       0.97      0.96      0.96       376
#           11       0.98      0.99      0.98       408
#           12       0.98      0.97      0.97       363
#           13       0.97      0.98      0.98       366
#           14       0.97      0.95      0.96       463
#           15       0.98      0.91      0.94       314
#
#     accuracy                           0.98     16249
#    macro avg       0.97      0.96      0.97     16249
# weighted avg       0.98      0.98      0.98     16249
#
# Confusion Matrix :

# %% [markdown]
# # 4.4 Evaluation

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test,predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 0.09772909102098591
# MSE: 0.9599359960612961
# RMSE: 0.9797632346956565

# %%
from sklearn.metrics import precision_score
print("Precision Score : ",precision_score(y_test, predictions, average='weighted'))


from sklearn.metrics import recall_score
print("Recall Score : ",recall_score(y_test, predictions,average='weighted'))


from sklearn.metrics import f1_score
print("f1_score : ",f1_score(y_test, predictions,average='weighted'))
# Out:
# Precision Score :  0.9846166087442294
# Recall Score :  0.9846144378115577
# f1_score :  0.9845613258105844
