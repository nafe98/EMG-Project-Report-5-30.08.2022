# %% [markdown]
# # Importing Libraires

# %%
import pandas as pd
from scipy.io import loadmat

# %% [markdown]
# #  Loading Exercise 3

# %%
Exercise_3 = loadmat(r"S1_A1_E3.mat")

# %%
print(Exercise_3)
print("************************************************************************************************************")
print(Exercise_3.keys())
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Mon Jul 28 11:54:18 2014', '__version__': '1.0', '__globals__': [], 'emg': array([[0.0024, 0.0024, 0.0024, ..., 0.0732, 0.0024, 0.0903],
#        [0.0024, 0.0024, 0.0024, ..., 0.0757, 0.0024, 0.0928],
#        [0.0024, 0.0024, 0.0024, ..., 0.0879, 0.0024, 0.0903],
#        ...,
#        [0.0024, 0.0024, 0.0024, ..., 0.0513, 0.127 , 0.0024],
#        [0.0024, 0.0024, 0.0024, ..., 0.0488, 0.1294, 0.0024],
#        [0.0024, 0.0024, 0.0024, ..., 0.0439, 0.1294, 0.0024]]), 'stimulus': array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8), 'glove': array([[152., 137., 111., ..., 139., 134., 108.],
#        [152., 137., 111., ..., 139., 134., 108.],
#        [152., 137., 111., ..., 139., 134., 108.],
#        ...,
#        [152., 131., 114., ..., 124., 133., 120.],
#        [152., 131., 114., ..., 124., 133., 120.],
#        [152., 131., 114., ..., 124., 133., 120.]]), 'subject': array([[1]], dtype=uint8), 'exercise': array([[3]], dtype=uint8), 'repetition': array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8), 'restimulus': array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8), 'rerepetition': array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8)}
# ************************************************************************************************************
# dict_keys(['__header__', '__version__', '__globals__', 'emg', 'stimulus', 'glove', 'subject', 'exercise', 'repetition', 'restimulus', 'rerepetition'])

# %%
emg_3 = Exercise_3['emg']
stimulus_3 = Exercise_3['stimulus']
restimulus_3 = Exercise_3['restimulus']

# %% [markdown]
# # DataFramae

# %%
df_3= pd.DataFrame(emg_3, 
                  columns = ['Emg1','Emg2','Emg3','Emg4','Emg5','Emg6','Emg7','Emg8','Emg9','Emg10'])

# %%
df_3
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 0       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0317  0.0732
# 1       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366  0.0757
# 2       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0415  0.0879
# 3       0.0024  0.0024  0.0049  0.0024  0.0024  0.0024  0.0366  0.0952
# 4       0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0293  0.0952
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 227488  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0562
# 227489  0.0024  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0513
# 227490  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0513
# 227491  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0488
# 227492  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0439
#
#           Emg9   Emg10
# 0       0.0024  0.0903
# 1       0.0024  0.0928
# 2       0.0024  0.0903
# 3       0.0024  0.0830
# 4       0.0024  0.0708
# ...        ...     ...
# 227488  0.1221  0.0024
# 227489  0.1270  0.0024
# 227490  0.1270  0.0024
# 227491  0.1294  0.0024
# 227492  0.1294  0.0024
#
# [227493 rows x 10 columns]

# %%
stimulus_3 = pd.DataFrame(stimulus_3)
restimulus_3 = pd.DataFrame(restimulus_3)

# %% [markdown]
# # Adding new column to existing DataFrame

# %%
df_3['stimulus'] = stimulus_3
df_3['restimulus'] = restimulus_3

# %%
df_3.describe()
# Out:
#                 Emg1           Emg2           Emg3           Emg4  \
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.177020       0.125848       0.195590       0.060284
# std         0.332936       0.303522       0.430584       0.183509
# min         0.002400       0.000000       0.002400       0.000000
# 25%         0.002400       0.002400       0.002400       0.002400
# 50%         0.034200       0.002400       0.002400       0.002400
# 75%         0.195300       0.097700       0.180700       0.034200
# max         4.665500       4.660600       4.658200       4.619100
#
#                 Emg5           Emg6           Emg7           Emg8  \
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.018392       0.018891       0.218081       0.289072
# std         0.038278       0.043190       0.410667       0.346111
# min         0.002400       0.000000       0.002400       0.002400
# 25%         0.002400       0.002400       0.012200       0.087900
# 50%         0.002400       0.002400       0.048800       0.146500
# 75%         0.014600       0.009800       0.231900       0.351600
# max         0.876500       0.632300       4.663100       4.577600
#
#                 Emg9          Emg10       stimulus     restimulus
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.134195       0.057882       6.284220       4.962707
# std         0.248078       0.129270       7.679851       7.434667
# min         0.002400       0.002400       0.000000       0.000000
# 25%         0.002400       0.009800       0.000000       0.000000
# 50%         0.102500       0.036600       2.000000       0.000000
# 75%         0.148900       0.058600      13.000000      10.000000
# max         4.660600       4.628900      23.000000      23.000000

# %% [markdown]
# # Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, classification_report

# %%
raw_data = df_3
raw_data.sample(5)
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 202340  0.4590  0.0024  0.1318  0.1978  0.0146  0.0073  0.1831  0.3271
# 161136  0.0049  0.0024  0.0024  0.0024  0.0024  0.0024  0.0073  0.0757
# 134026  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0146  0.0928
# 135873  0.0024  0.0024  0.0024  0.0024  0.0122  0.0024  0.0171  0.0269
# 154515  0.0293  0.0024  0.0098  0.0024  0.0366  0.0073  0.1514  0.2002
#
#           Emg9   Emg10  stimulus  restimulus
# 202340  0.2002  0.0049        21          21
# 161136  0.0464  0.0024        17           0
# 134026  0.1318  0.0024         0           0
# 135873  0.1221  0.0024        14          14
# 154515  0.1196  0.0269        16          16

# %%
print("The Shape of the Dataset is : ",raw_data.shape)
print("************************************************************************************************************")
print("Column Names of the Dataset are : ",raw_data.columns)
print("************************************************************************************************************")
print(raw_data.info())
print("************************************************************************************************************")
raw_data.describe(include='all')
# Out:
# The Shape of the Dataset is :  (227493, 12)
# ************************************************************************************************************
# Column Names of the Dataset are :  Index(['Emg1', 'Emg2', 'Emg3', 'Emg4', 'Emg5', 'Emg6', 'Emg7', 'Emg8', 'Emg9',
#        'Emg10', 'stimulus', 'restimulus'],
#       dtype='object')
# ************************************************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227493 entries, 0 to 227492
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Emg1        227493 non-null  float64
#  1   Emg2        227493 non-null  float64
#  2   Emg3        227493 non-null  float64
#  3   Emg4        227493 non-null  float64
#  4   Emg5        227493 non-null  float64
#  5   Emg6        227493 non-null  float64
#  6   Emg7        227493 non-null  float64
#  7   Emg8        227493 non-null  float64
#  8   Emg9        227493 non-null  float64
#  9   Emg10       227493 non-null  float64
#  10  stimulus    227493 non-null  uint8
#  11  restimulus  227493 non-null  uint8
# dtypes: float64(10), uint8(2)
# memory usage: 17.8 MB
# None
# ************************************************************************************************************
#                 Emg1           Emg2           Emg3           Emg4  \
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.177020       0.125848       0.195590       0.060284
# std         0.332936       0.303522       0.430584       0.183509
# min         0.002400       0.000000       0.002400       0.000000
# 25%         0.002400       0.002400       0.002400       0.002400
# 50%         0.034200       0.002400       0.002400       0.002400
# 75%         0.195300       0.097700       0.180700       0.034200
# max         4.665500       4.660600       4.658200       4.619100
#
#                 Emg5           Emg6           Emg7           Emg8  \
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.018392       0.018891       0.218081       0.289072
# std         0.038278       0.043190       0.410667       0.346111
# min         0.002400       0.000000       0.002400       0.002400
# 25%         0.002400       0.002400       0.012200       0.087900
# 50%         0.002400       0.002400       0.048800       0.146500
# 75%         0.014600       0.009800       0.231900       0.351600
# max         0.876500       0.632300       4.663100       4.577600
#
#                 Emg9          Emg10       stimulus     restimulus
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.134195       0.057882       6.284220       4.962707
# std         0.248078       0.129270       7.679851       7.434667
# min         0.002400       0.002400       0.000000       0.000000
# 25%         0.002400       0.009800       0.000000       0.000000
# 50%         0.102500       0.036600       2.000000       0.000000
# 75%         0.148900       0.058600      13.000000      10.000000
# max         4.660600       4.628900      23.000000      23.000000

# %%
print("Unique Dependent values and their counts :")
print(raw_data["stimulus"].value_counts())
# Out:
# Unique Dependent values and their counts :
# 0     108449
# 18      5210
# 20      5202
# 14      5191
# 9       5190
# 19      5189
# 12      5189
# 2       5188
# 13      5186
# 21      5185
# 17      5184
# 10      5182
# 11      5182
# 8       5182
# 7       5177
# 4       5174
# 23      5166
# 16      5165
# 1       5162
# 22      5161
# 15      5161
# 5       5153
# 3       5133
# 6       5132
# Name: stimulus, dtype: int64

# %%
count_classes = pd.value_counts(raw_data['stimulus'], sort = True)

count_classes.plot(kind = 'bar', rot=0)

plt.title("stimulus Class Distribution")

plt.xlabel("Class")

plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
print(raw_data.isnull().any())
# Out:
# Emg1          False
# Emg2          False
# Emg3          False
# Emg4          False
# Emg5          False
# Emg6          False
# Emg7          False
# Emg8          False
# Emg9          False
# Emg10         False
# stimulus      False
# restimulus    False
# dtype: bool

# %% [markdown]
# # Custom Outlier Detection

# %%
index_names = raw_data[ (raw_data['stimulus'] != raw_data['restimulus'])].index
raw_data.drop(index_names, inplace = True)

# %%
raw_data.sample(5)
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 145880  0.0049  0.0024  0.0049  0.0024  0.0024  0.0024  0.0439  0.1147
# 76979   0.4810  0.4858  0.5591  0.2686  0.0708  0.0879  1.7505  1.0474
# 37116   1.3696  0.6787  0.2710  0.0684  0.0317  0.0537  1.2451  1.5356
# 148728  0.0342  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.2002
# 215049  0.2930  0.0610  0.0366  0.0464  0.0073  0.0684  0.5078  0.7373
#
#           Emg9   Emg10  stimulus  restimulus
# 145880  0.0171  0.0024         0           0
# 76979   0.5713  0.2393         8           8
# 37116   0.2734  0.0659         4           4
# 148728  0.0024  0.0024         0           0
# 215049  0.1367  0.0757        22          22

# %%
raw_data.shape
# Out:
# (195668, 12)

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195668 entries, 0 to 227492
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Emg1        195668 non-null  float64
#  1   Emg2        195668 non-null  float64
#  2   Emg3        195668 non-null  float64
#  3   Emg4        195668 non-null  float64
#  4   Emg5        195668 non-null  float64
#  5   Emg6        195668 non-null  float64
#  6   Emg7        195668 non-null  float64
#  7   Emg8        195668 non-null  float64
#  8   Emg9        195668 non-null  float64
#  9   Emg10       195668 non-null  float64
#  10  stimulus    195668 non-null  uint8
#  11  restimulus  195668 non-null  uint8
# dtypes: float64(10), uint8(2)
# memory usage: 16.8 MB

# %%
print(raw_data.isnull().any())
# Out:
# Emg1          False
# Emg2          False
# Emg3          False
# Emg4          False
# Emg5          False
# Emg6          False
# Emg7          False
# Emg8          False
# Emg9          False
# Emg10         False
# stimulus      False
# restimulus    False
# dtype: bool

# %% [markdown]
# # Initializing Inputs and Outputs Variables

# %%
X = raw_data.iloc[:,0:10]
y = raw_data.stimulus

# %% [markdown]
# # One Hot Encoding

# %%
num_classes = 24

# %%
# One hot encoding for categorical labels
import keras
from keras import utils as np_utils

#y = keras.utils.to_categorical(y, num_classes)
y = keras.utils.np_utils.to_categorical(y, num_classes)

# %%
input_dim = X.shape[1]

# %% [markdown]
# # Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
standardscaler=StandardScaler()

# %%
sc = pd.DataFrame(standardscaler.fit_transform(X))

# %%
sc
# Out:
#                0         1         2         3         4         5         6  \
# 0      -0.554095 -0.439845 -0.485491 -0.337365 -0.449420 -0.409729 -0.487261
# 1      -0.554095 -0.439845 -0.485491 -0.337365 -0.449420 -0.409729 -0.475904
# 2      -0.554095 -0.439845 -0.485491 -0.337365 -0.449420 -0.409729 -0.464548
# 3      -0.554095 -0.439845 -0.479988 -0.337365 -0.449420 -0.409729 -0.475904
# 4      -0.554095 -0.439845 -0.485491 -0.337365 -0.387599 -0.409729 -0.492824
# ...          ...       ...       ...       ...       ...       ...       ...
# 195663 -0.554095 -0.439845 -0.485491 -0.337365 -0.449420 -0.409729 -0.555171
# 195664 -0.554095 -0.439845 -0.485491 -0.337365 -0.449420 -0.355040 -0.555171
# 195665 -0.554095 -0.439845 -0.485491 -0.337365 -0.449420 -0.409729 -0.555171
# 195666 -0.554095 -0.439845 -0.485491 -0.337365 -0.449420 -0.409729 -0.555171
# 195667 -0.554095 -0.439845 -0.485491 -0.337365 -0.449420 -0.409729 -0.555171
#
#                7         8         9
# 0      -0.658725 -0.561695  0.266545
# 1      -0.651845 -0.561695  0.287374
# 2      -0.618271 -0.561695  0.266545
# 3      -0.598182 -0.561695  0.205726
# 4      -0.598182 -0.561695  0.104084
# ...          ...       ...       ...
# 195663 -0.705509 -0.069023 -0.465782
# 195664 -0.718993 -0.048855 -0.465782
# 195665 -0.718993 -0.048855 -0.465782
# 195666 -0.725873 -0.038977 -0.465782
# 195667 -0.739358 -0.038977 -0.465782
#
# [195668 rows x 10 columns]

# %% [markdown]
# # Splitting data for training and testing

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 39)

# %% [markdown]
# # Deep Learning Architecture

# %%
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adadelta, Adagrad, Adamax, Nadam, Ftrl

# %% [raw]
# from sklearn.preprocessing import MinMaxScaler
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Input
# from tensorflow.keras.layers import Dense
# from tensorflow.keras.layers import LeakyReLU,ELU
# from tensorflow.keras.layers import BatchNormalization
# from tensorflow.keras.utils import plot_model
# import tensorflow as tf
# from sklearn.model_selection import cross_val_score
# from keras.models import Sequential
# from keras.layers import Dense, BatchNormalization, Dropout
# from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adadelta, Adagrad, Adamax, Nadam, Ftrl
# from keras.callbacks import EarlyStopping, ModelCheckpoint
# from keras.wrappers.scikit_learn import KerasClassifier
# from sklearn.metrics import make_scorer, accuracy_score
# from sklearn.model_selection import StratifiedKFold

# %% [raw]
# from keras.layers import LeakyReLU
# LeakyReLU = LeakyReLU(alpha=0.1)
# from keras.models import Sequential
# from keras.layers import Dense, Flatten, Convolution1D, Dropout
# from keras.initializers import random_uniform

# %% [markdown]
# # 1. Define Network

# %%
num_classes = 24
input_dim = X.shape[1]

# %%
visible = Input(shape=(input_dim,))
hidden1 = Dense(3000, activation='relu')(visible)
hidden2 = Dense(1500, activation='relu')(hidden1)
hidden3 = Dropout(0.2)(hidden2)
hidden4 = Dense(750, activation='relu')(hidden3)
hidden5 = Dense(375, activation='relu')(hidden4)
hidden6 = Dense(48, activation='relu')(hidden5)
output = Dense(num_classes, activation='softmax')(hidden6)
model = Model(inputs=visible, outputs=output)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 10)]              0
#
#  dense (Dense)               (None, 3000)              33000
#
#  dense_1 (Dense)             (None, 1500)              4501500
#
#  dropout (Dropout)           (None, 1500)              0
#
#  dense_2 (Dense)             (None, 750)               1125750
#
#  dense_3 (Dense)             (None, 375)               281625
#
#  dense_4 (Dense)             (None, 48)                18048
#
#  dense_5 (Dense)             (None, 24)                1176
#
# =================================================================
# Total params: 5,961,099
# Trainable params: 5,961,099
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 2. Compile Network

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
plot_model(model, 'EMG_ANN.png', show_shapes = True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# # 3. Fit Network

# %%
import time
start_time = time.time()

history = model.fit(X_train, y_train, batch_size=9000, epochs=300, validation_data = (X_test, y_test))

print (time.time() - start_time, "seconds")
# Out:
# Epoch 1/300
# 20/20 [==============================] - 73s 4s/step - loss: 2.0733 - accuracy: 0.5369 - val_loss: 1.4542 - val_accuracy: 0.5816
# Epoch 2/300
# 20/20 [==============================] - 72s 4s/step - loss: 1.3580 - accuracy: 0.6142 - val_loss: 1.2340 - val_accuracy: 0.6496
# Epoch 3/300
# 20/20 [==============================] - 73s 4s/step - loss: 1.1702 - accuracy: 0.6706 - val_loss: 1.0860 - val_accuracy: 0.6947
# Epoch 4/300
# 20/20 [==============================] - 85s 4s/step - loss: 1.0425 - accuracy: 0.7076 - val_loss: 0.9718 - val_accuracy: 0.7293
# Epoch 5/300
# 20/20 [==============================] - 79s 4s/step - loss: 0.9337 - accuracy: 0.7368 - val_loss: 0.8672 - val_accuracy: 0.7516
# Epoch 6/300
# 20/20 [==============================] - 80s 4s/step - loss: 0.8429 - accuracy: 0.7583 - val_loss: 0.8002 - val_accuracy: 0.7685
# Epoch 7/300
# 20/20 [==============================] - 83s 4s/step - loss: 0.7933 - accuracy: 0.7708 - val_loss: 0.7392 - val_accuracy: 0.7818
# Epoch 8/300
# 20/20 [==============================] - 76s 4s/step - loss: 0.7203 - accuracy: 0.7860 - val_loss: 0.6784 - val_accuracy: 0.7995
# Epoch 9/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.6746 - accuracy: 0.7976 - val_loss: 0.6493 - val_accuracy: 0.8040
# Epoch 10/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.6350 - accuracy: 0.8082 - val_loss: 0.6047 - val_accuracy: 0.8158
# Epoch 11/300
# 20/20 [==============================] - 74s 4s/step - loss: 0.6017 - accuracy: 0.8163 - val_loss: 0.5839 - val_accuracy: 0.8227
# Epoch 12/300
# 20/20 [==============================] - 75s 4s/step - loss: 0.5839 - accuracy: 0.8211 - val_loss: 0.5561 - val_accuracy: 0.8298
# Epoch 13/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.5585 - accuracy: 0.8273 - val_loss: 0.5363 - val_accuracy: 0.8351
# Epoch 14/300
# 20/20 [==============================] - 74s 4s/step - loss: 0.5365 - accuracy: 0.8323 - val_loss: 0.5165 - val_accuracy: 0.8403
# Epoch 15/300
# 20/20 [==============================] - 76s 4s/step - loss: 0.5180 - accuracy: 0.8388 - val_loss: 0.5001 - val_accuracy: 0.8460
# Epoch 16/300
# 20/20 [==============================] - 74s 4s/step - loss: 0.4995 - accuracy: 0.8433 - val_loss: 0.4878 - val_accuracy: 0.8495
# Epoch 17/300
# 20/20 [==============================] - 76s 4s/step - loss: 0.4843 - accuracy: 0.8485 - val_loss: 0.4630 - val_accuracy: 0.8562
# Epoch 18/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.4674 - accuracy: 0.8532 - val_loss: 0.4573 - val_accuracy: 0.8592
# Epoch 19/300
# 20/20 [==============================] - 72s 4s/step - loss: 0
300
# 20/20 [==============================] - 73s 4s/step - loss: 0.0803 - accuracy: 0.9747 - val_loss: 0.0978 - val_accuracy: 0.9702
# Epoch 141/300
# 20/20 [==============================] - 75s 4s/step - loss: 0.0788 - accuracy: 0.9748 - val_loss: 0.0969 - val_accuracy: 0.9703
# Epoch 142/300
# 20/20 [==============================] - 78s 4s/step - loss: 0.0790 - accuracy: 0.9749 - val_loss: 0.0975 - val_accuracy: 0.9696
# Epoch 143/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0772 - accuracy: 0.9755 - val_loss: 0.1013 - val_accuracy: 0.9691
# Epoch 144/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0763 - accuracy: 0.9759 - val_loss: 0.1014 - val_accuracy: 0.9687
# Epoch 145/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0759 - accuracy: 0.9757 - val_loss: 0.0955 - val_accuracy: 0.9700
# Epoch 146/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0762 - accuracy: 0.9763 - val_loss: 0.0965 - val_accuracy: 0.9700
# Epoch 147/300
# 20/20 [==============================] - 79s 4s/step - loss: 0.0762 - accuracy: 0.9758 - val_loss: 0.0960 - val_accuracy: 0.9716
# Epoch 148/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0775 - accuracy: 0.9753 - val_loss: 0.0962 - val_accuracy: 0.9699
# Epoch 149/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0770 - accuracy: 0.9756 - val_loss: 0.0974 - val_accuracy: 0.9695
# Epoch 150/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0763 - accuracy: 0.9757 - val_loss: 0.1020 - val_accuracy: 0.9687
# Epoch 151/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0782 - accuracy: 0.9752 - val_loss: 0.0978 - val_accuracy: 0.9696
# Epoch 152/300
# 20/20 [==============================] - 73s 4s/step - loss: 0.0760 - accuracy: 0.9758 - val_loss: 0.0955 - val_accuracy: 0.9713
# Epoch 153/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0758 - accuracy: 0.9762 - val_loss: 0.0940 - val_accuracy: 0.9705
# Epoch 154/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0704 - accuracy: 0.9778 - val_loss: 0.0910 - val_accuracy: 0.9732
# Epoch 155/300
# 20/20 [==============================] - 73s 4s/step - loss: 0.0704 - accuracy: 0.9775 - val_loss: 0.0939 - val_accuracy: 0.9710
# Epoch 156/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0696 - accuracy: 0.9779 - val_loss: 0.0924 - val_accuracy: 0.9709
# Epoch 157/300
# 20/20 [==============================] - 75s 4s/step - loss: 0.0710 - accuracy: 0.9775 - val_loss: 0.0920 - val_accuracy: 0.9707
# Epoch 158/300
# 20/20 [==============================] - 77s 4s/step - loss: 0.0696 - accuracy: 0.9776 - val_loss: 0.0932 - val_accuracy: 0.9712
# Epoch 159/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0699 - accuracy: 0.9775 - val_loss: 0.0952 - val_accuracy: 0.9704
# Epoch 160/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0724 - accuracy: 0.9769 - val_loss: 0.0990 - val_accuracy: 0.9691
# Epoch 161/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0711 - accuracy: 0.9776 - val_loss: 0.0959 - val_accuracy: 0.9711
# Epoch 162/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0683 - accuracy: 0.9782 - val_loss: 0.0889 - val_accuracy: 0.9729
# Epoch 163/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0661 - accuracy: 0.9795 - val_loss: 0.0848 - val_accuracy: 0.9733
# Epoch 164/300
# 20/20 [==============================] - 73s 4s/step - loss: 0.0667 - accuracy: 0.9789 - val_loss: 0.0955 - val_accuracy: 0.9713
# Epoch 165/300
# 20/20 [==============================] - 73s 4s/step - loss: 0.0679 - accuracy: 0.9784 - val_loss: 0.0875 - val_accuracy: 0.9733
# Epoch 166/300
# 20/20 [==============================] - 73s 4s/step - loss: 0.0656 - accuracy: 0.9789 - val_loss: 0.0894 - val_accuracy: 0.9727
# Epoch 167/300
# 20/20 [==============================] - 75s 4s/step - loss: 0.0649 - accuracy: 0.9794 - val_loss: 0.0969 - val_accuracy: 0.9702
# Epoch 168/300
# 20/20 [==============================] - 74s 4s/step - loss: 0
300
# 20/20 [==============================] - 71s 4s/step - loss: 0.0461 - accuracy: 0.9855 - val_loss: 0.0767 - val_accuracy: 0.9776
# Epoch 224/300
# 20/20 [==============================] - 71s 4s/step - loss: 0.0484 - accuracy: 0.9848 - val_loss: 0.0737 - val_accuracy: 0.9782
# Epoch 225/300
# 20/20 [==============================] - 73s 4s/step - loss: 0.0467 - accuracy: 0.9855 - val_loss: 0.0760 - val_accuracy: 0.9781
# Epoch 226/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0456 - accuracy: 0.9856 - val_loss: 0.0737 - val_accuracy: 0.9785
# Epoch 227/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0463 - accuracy: 0.9853 - val_loss: 0.0780 - val_accuracy: 0.9781
# Epoch 228/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0473 - accuracy: 0.9850 - val_loss: 0.0773 - val_accuracy: 0.9775
# Epoch 229/300
# 20/20 [==============================] - 73s 4s/step - loss: 0.0473 - accuracy: 0.9848 - val_loss: 0.0775 - val_accuracy: 0.9775
# Epoch 230/300
# 20/20 [==============================] - 74s 4s/step - loss: 0.0471 - accuracy: 0.9848 - val_loss: 0.0762 - val_accuracy: 0.9779
# Epoch 231/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0479 - accuracy: 0.9848 - val_loss: 0.0777 - val_accuracy: 0.9774
# Epoch 232/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0468 - accuracy: 0.9853 - val_loss: 0.0838 - val_accuracy: 0.9743
# Epoch 233/300
# 20/20 [==============================] - 75s 4s/step - loss: 0.0502 - accuracy: 0.9843 - val_loss: 0.0822 - val_accuracy: 0.9772
# Epoch 234/300
# 20/20 [==============================] - 75s 4s/step - loss: 0.0468 - accuracy: 0.9851 - val_loss: 0.0821 - val_accuracy: 0.9762
# Epoch 235/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0454 - accuracy: 0.9858 - val_loss: 0.0781 - val_accuracy: 0.9781
# Epoch 236/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0455 - accuracy: 0.9856 - val_loss: 0.0753 - val_accuracy: 0.9783
# Epoch 237/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0459 - accuracy: 0.9857 - val_loss: 0.0767 - val_accuracy: 0.9780
# Epoch 238/300
# 20/20 [==============================] - 73s 4s/step - loss: 0.0434 - accuracy: 0.9862 - val_loss: 0.0758 - val_accuracy: 0.9790
# Epoch 239/300
# 20/20 [==============================] - 73s 4s/step - loss: 0.0451 - accuracy: 0.9859 - val_loss: 0.0762 - val_accuracy: 0.9783
# Epoch 240/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0437 - accuracy: 0.9864 - val_loss: 0.0774 - val_accuracy: 0.9779
# Epoch 241/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0439 - accuracy: 0.9861 - val_loss: 0.0780 - val_accuracy: 0.9783
# Epoch 242/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0437 - accuracy: 0.9863 - val_loss: 0.0774 - val_accuracy: 0.9787
# Epoch 243/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0443 - accuracy: 0.9860 - val_loss: 0.0809 - val_accuracy: 0.9790
# Epoch 244/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0426 - accuracy: 0.9868 - val_loss: 0.0786 - val_accuracy: 0.9778
# Epoch 245/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0436 - accuracy: 0.9863 - val_loss: 0.0758 - val_accuracy: 0.9788
# Epoch 246/300
# 20/20 [==============================] - 79s 4s/step - loss: 0.0427 - accuracy: 0.9867 - val_loss: 0.0784 - val_accuracy: 0.9775
# Epoch 247/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0452 - accuracy: 0.9859 - val_loss: 0.0796 - val_accuracy: 0.9768
# Epoch 248/300
# 20/20 [==============================] - 71s 4s/step - loss: 0.0455 - accuracy: 0.9853 - val_loss: 0.0750 - val_accuracy: 0.9783
# Epoch 249/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0423 - accuracy: 0.9868 - val_loss: 0.0776 - val_accuracy: 0.9773
# Epoch 250/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0445 - accuracy: 0.9856 - val_loss: 0.0776 - val_accuracy: 0.9787
# Epoch 251/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.
300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0381 - accuracy: 0.9882 - val_loss: 0.0731 - val_accuracy: 0.9797
# Epoch 280/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0378 - accuracy: 0.9879 - val_loss: 0.0758 - val_accuracy: 0.9791
# Epoch 281/300
# 20/20 [==============================] - 73s 4s/step - loss: 0.0394 - accuracy: 0.9880 - val_loss: 0.0751 - val_accuracy: 0.9796
# Epoch 282/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0385 - accuracy: 0.9881 - val_loss: 0.0731 - val_accuracy: 0.9806
# Epoch 283/300
# 20/20 [==============================] - 74s 4s/step - loss: 0.0370 - accuracy: 0.9884 - val_loss: 0.0752 - val_accuracy: 0.9784
# Epoch 284/300
# 20/20 [==============================] - 73s 4s/step - loss: 0.0381 - accuracy: 0.9880 - val_loss: 0.0759 - val_accuracy: 0.9804
# Epoch 285/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0393 - accuracy: 0.9874 - val_loss: 0.0773 - val_accuracy: 0.9788
# Epoch 286/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0398 - accuracy: 0.9875 - val_loss: 0.0718 - val_accuracy: 0.9793
# Epoch 287/300
# 20/20 [==============================] - 77s 4s/step - loss: 0.0425 - accuracy: 0.9865 - val_loss: 0.0752 - val_accuracy: 0.9789
# Epoch 288/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0404 - accuracy: 0.9873 - val_loss: 0.0730 - val_accuracy: 0.9799
# Epoch 289/300
# 20/20 [==============================] - 71s 4s/step - loss: 0.0381 - accuracy: 0.9880 - val_loss: 0.0755 - val_accuracy: 0.9788
# Epoch 290/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0394 - accuracy: 0.9874 - val_loss: 0.0752 - val_accuracy: 0.9800
# Epoch 291/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0392 - accuracy: 0.9876 - val_loss: 0.0763 - val_accuracy: 0.9782
# Epoch 292/300
# 20/20 [==============================] - 73s 4s/step - loss: 0.0378 - accuracy: 0.9882 - val_loss: 0.0755 - val_accuracy: 0.9789
# Epoch 293/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0369 - accuracy: 0.9884 - val_loss: 0.0730 - val_accuracy: 0.9799
# Epoch 294/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0374 - accuracy: 0.9883 - val_loss: 0.0734 - val_accuracy: 0.9808
# Epoch 295/300
# 20/20 [==============================] - 76s 4s/step - loss: 0.0362 - accuracy: 0.9885 - val_loss: 0.0721 - val_accuracy: 0.9802
# Epoch 296/300
# 20/20 [==============================] - 75s 4s/step - loss: 0.0348 - accuracy: 0.9891 - val_loss: 0.0718 - val_accuracy: 0.9810
# Epoch 297/300
# 20/20 [==============================] - 80s 4s/step - loss: 0.0353 - accuracy: 0.9889 - val_loss: 0.0756 - val_accuracy: 0.9805
# Epoch 298/300
# 20/20 [==============================] - 73s 4s/step - loss: 0.0355 - accuracy: 0.9889 - val_loss: 0.0760 - val_accuracy: 0.9785
# Epoch 299/300
# 20/20 [==============================] - 72s 4s/step - loss: 0.0374 - accuracy: 0.9883 - val_loss: 0.0735 - val_accuracy: 0.9789
# Epoch 300/300
# 20/20 [==============================] - 73s 4s/step - loss: 0.0367 - accuracy: 0.9886 - val_loss: 0.0742 - val_accuracy: 0.9790
# 22565.77538728714 seconds

# %% [markdown]
# # 4.Evaluate Network

# %% [markdown]
# # 4.1. Plotting Loss and Accuracy¶

# %%
#Loss Curve


plt.plot(figsize = [8,6])

plt.plot(history.history['loss'],'r',linewidth = 3.0)
plt.plot(history.history['val_loss'],'b',linewidth = 3.0)

plt.legend(['Training Loss', 'Validation Loss'], fontsize = 18)

plt.xlabel('Epochs', fontsize = 16)
plt.ylabel('Loss', fontsize = 16)

plt.title('Loss Curve of Deep Neural Netowork' , fontsize = 16 )
# Out:
# Text(0.5, 1.0, 'Loss Curve of Deep Neural Netowork')

# %%
#Accuracy Curve

plt.plot(figsize = [8,6])
plt.plot(history.history['accuracy'],'r',linewidth = 3.0)
plt.plot(history.history['val_accuracy'],'b',linewidth = 3.0)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize = 18)

plt.xlabel('Epochs', fontsize = 16)
plt.ylabel('Accuracy', fontsize = 16)


plt.title('Accuracy Curve of Deep Neural Netowork' , fontsize = 16 )
# Out:
# Text(0.5, 1.0, 'Accuracy Curve of Deep Neural Netowork')

# %% [markdown]
# # 4.2 Make Predictions

# %%
predictions = model.predict(X_test)
predictions = np.argmax(predictions, axis = 1)
# Out:
# 612/612 [==============================] - 10s 15ms/step

# %%
predictions
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# # Transforming from One Hot Encoding

# %%
y_test =np.argmax(y_test, axis=1)
y_test[1]
# Out:
# 0

# %%
from sklearn.metrics import accuracy_score
accuracy = {accuracy_score(y_test, predictions)}
print(f"Accuracy is: {accuracy_score(y_test, predictions)* 100}")
# Out:
# Accuracy is: 97.89952470997086

# %% [markdown]
# # 4.3 Classification Report

# %%
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, classification_report
print('\033[1m' +'Classification report : '+ '\033[0m\n', classification_report(y_test, predictions))

cm = confusion_matrix(predictions, y_test)
print('\033[1m' +'Confusion Matrix : '+ '\033[0m')
sns.heatmap(cm, cmap = 'OrRd',annot = True, fmt='d')
plt.show()
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     10731
#            1       0.99      0.98      0.98       379
#            2       0.98      0.98      0.98       365
#            3       0.95      0.97      0.96       350
#            4       0.97      0.94      0.95       357
#            5       0.96      0.96      0.96       391
#            6       0.98      0.96      0.97       431
#            7       0.97      0.92      0.94       333
#            8       0.96      0.92      0.94       321
#            9       0.97      0.98      0.97       350
#           10       0.99      0.95      0.97       403
#           11       0.98      0.96      0.97       393
#           12       0.97      0.96      0.97       395
#           13       0.99      0.92      0.96       375
#           14       0.94      0.95      0.94       417
#           15       0.92      0.96      0.94       319
#           16       0.92      0.98      0.95       410
#           17       0.97      0.98      0.97       376
#           18       0.96      0.95      0.95       408
#           19       0.97      0.95      0.96       376
#           20       0.99      0.99      0.99       392
#           21       0.99      0.99      0.99       411
#           22       1.00      0.98      0.99       425
#           23       0.97      0.98      0.97       459
#
#     accuracy                           0.98     19567
#    macro avg       0.97      0.96      0.97     19567
# weighted avg       0.98      0.98      0.98     19567
#
# Confusion Matrix :

# %% [markdown]
# # 4.4 Evaluation

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test,predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 0.16982674911841367
# MSE: 2.102059590126233
# RMSE: 1.4498481265726535

# %%
from sklearn.metrics import precision_score
print("Precision Score : ",precision_score(y_test, predictions, average='weighted'))


from sklearn.metrics import recall_score
print("Recall Score : ",recall_score(y_test, predictions,average='weighted'))


from sklearn.metrics import f1_score
print("f1_score : ",f1_score(y_test, predictions,average='weighted'))
# Out:
# Precision Score :  0.9791063506310381
# Recall Score :  0.9789952470997086
# f1_score :  0.9789492593817873
