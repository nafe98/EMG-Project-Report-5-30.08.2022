# %% [markdown]
# # Importing Libraires

# %%
import pandas as pd
from scipy.io import loadmat

# %% [markdown]
# #  Loading Exercise 2

# %%
Exercise_2 = loadmat(r"S1_A1_E2.mat")

# %%
print(Exercise_2)
print("************************************************************************************************************")
print(Exercise_2.keys())
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Mon Jul 28 11:54:17 2014', '__version__': '1.0', '__globals__': [], 'emg': array([[0.0024, 0.0024, 0.0024, ..., 0.0366, 0.0024, 0.0024],
#        [0.0024, 0.0024, 0.0024, ..., 0.0366, 0.0024, 0.0024],
#        [0.0024, 0.0024, 0.0024, ..., 0.0366, 0.0024, 0.0024],
#        ...,
#        [0.022 , 0.0024, 0.0024, ..., 0.0903, 0.0024, 0.0415],
#        [0.0342, 0.0024, 0.0049, ..., 0.1172, 0.0024, 0.0415],
#        [0.0415, 0.0024, 0.0024, ..., 0.1318, 0.0024, 0.0439]]), 'stimulus': array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8), 'glove': array([[160., 124., 118., ..., 159., 132., 112.],
#        [160., 124., 118., ..., 159., 132., 112.],
#        [160., 124., 118., ..., 159., 132., 112.],
#        ...,
#        [139., 141., 119., ..., 145., 131., 118.],
#        [139., 141., 119., ..., 145., 131., 118.],
#        [139., 141., 119., ..., 145., 131., 118.]]), 'subject': array([[1]], dtype=uint8), 'exercise': array([[2]], dtype=uint8), 'repetition': array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8), 'restimulus': array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8), 'rerepetition': array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8)}
# ************************************************************************************************************
# dict_keys(['__header__', '__version__', '__globals__', 'emg', 'stimulus', 'glove', 'subject', 'exercise', 'repetition', 'restimulus', 'rerepetition'])

# %%
emg_2 = Exercise_2['emg']
stimulus_2 = Exercise_2['stimulus']
restimulus_2 = Exercise_2['restimulus']

# %% [markdown]
# # DataFramae

# %% [markdown]
# ### Convert the dictionary into DataFrame

# %%
df_2= pd.DataFrame(emg_2, 
                  columns = ['Emg1','Emg2','Emg3','Emg4','Emg5','Emg6','Emg7','Emg8','Emg9','Emg10'])

# %%
df_2
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 0       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# 1       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# 2       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# 3       0.0195  0.0024  0.0024  0.0024  0.0024  0.0024  0.0049  0.0537
# 4       0.0293  0.0024  0.0024  0.0024  0.0024  0.0024  0.0049  0.0659
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 142971  0.0293  0.0024  0.0024  0.0024  0.0024  0.0024  0.0146  0.1025
# 142972  0.0293  0.0024  0.0024  0.0024  0.0024  0.0024  0.0146  0.1025
# 142973  0.0220  0.0024  0.0024  0.0024  0.0024  0.0024  0.0073  0.0903
# 142974  0.0342  0.0024  0.0049  0.0024  0.0024  0.0024  0.0171  0.1172
# 142975  0.0415  0.0024  0.0024  0.0024  0.0024  0.0024  0.0220  0.1318
#
#           Emg9   Emg10
# 0       0.0024  0.0024
# 1       0.0024  0.0024
# 2       0.0024  0.0024
# 3       0.0024  0.0024
# 4       0.0024  0.0024
# ...        ...     ...
# 142971  0.0024  0.0415
# 142972  0.0024  0.0415
# 142973  0.0024  0.0415
# 142974  0.0024  0.0415
# 142975  0.0024  0.0439
#
# [142976 rows x 10 columns]

# %%
stimulus_2 = pd.DataFrame(stimulus_2)
restimulus_2 = pd.DataFrame(restimulus_2)

# %% [markdown]
# ### Adding new column to existing DataFrame

# %%
df_2['stimulus'] = stimulus_2
df_2['restimulus'] = restimulus_2

# %%
df_2
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 0       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# 1       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# 2       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# 3       0.0195  0.0024  0.0024  0.0024  0.0024  0.0024  0.0049  0.0537
# 4       0.0293  0.0024  0.0024  0.0024  0.0024  0.0024  0.0049  0.0659
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 142971  0.0293  0.0024  0.0024  0.0024  0.0024  0.0024  0.0146  0.1025
# 142972  0.0293  0.0024  0.0024  0.0024  0.0024  0.0024  0.0146  0.1025
# 142973  0.0220  0.0024  0.0024  0.0024  0.0024  0.0024  0.0073  0.0903
# 142974  0.0342  0.0024  0.0049  0.0024  0.0024  0.0024  0.0171  0.1172
# 142975  0.0415  0.0024  0.0024  0.0024  0.0024  0.0024  0.0220  0.1318
#
#           Emg9   Emg10  stimulus  restimulus
# 0       0.0024  0.0024         0           0
# 1       0.0024  0.0024         0           0
# 2       0.0024  0.0024         0           0
# 3       0.0024  0.0024         0           0
# 4       0.0024  0.0024         0           0
# ...        ...     ...       ...         ...
# 142971  0.0024  0.0415         0           0
# 142972  0.0024  0.0415         0           0
# 142973  0.0024  0.0415         0           0
# 142974  0.0024  0.0415         0           0
# 142975  0.0024  0.0439         0           0
#
# [142976 rows x 12 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, classification_report

# %%
raw_data = df_2
raw_data.sample(5)
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 22203   0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0293  0.0586
# 120303  0.0293  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0952
# 5491    0.2344  0.3320  0.0171  0.0024  0.0024  0.0024  0.0464  0.3101
# 82437   0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0244  0.0513
# 113570  0.1123  0.0024  0.0024  0.0024  0.0024  0.0024  0.0537  0.1514
#
#           Emg9   Emg10  stimulus  restimulus
# 22203   0.0024  0.0024         3           3
# 120303  0.0024  0.0586         0           0
# 5491    0.1587  0.0537         1           1
# 82437   0.0024  0.0586         0           0
# 113570  0.0024  0.0464         0           0

# %%
print("The Shape of the Dataset is : ",raw_data.shape)
print("************************************************************************************************************")
print("Column Names of the Dataset are : ",raw_data.columns)
print("************************************************************************************************************")
print(raw_data.info())
print("************************************************************************************************************")
raw_data.describe(include='all')
# Out:
# The Shape of the Dataset is :  (142976, 12)
# ************************************************************************************************************
# Column Names of the Dataset are :  Index(['Emg1', 'Emg2', 'Emg3', 'Emg4', 'Emg5', 'Emg6', 'Emg7', 'Emg8', 'Emg9',
#        'Emg10', 'stimulus', 'restimulus'],
#       dtype='object')
# ************************************************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142976 entries, 0 to 142975
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Emg1        142976 non-null  float64
#  1   Emg2        142976 non-null  float64
#  2   Emg3        142976 non-null  float64
#  3   Emg4        142976 non-null  float64
#  4   Emg5        142976 non-null  float64
#  5   Emg6        142976 non-null  float64
#  6   Emg7        142976 non-null  float64
#  7   Emg8        142976 non-null  float64
#  8   Emg9        142976 non-null  float64
#  9   Emg10       142976 non-null  float64
#  10  stimulus    142976 non-null  uint8
#  11  restimulus  142976 non-null  uint8
# dtypes: float64(10), uint8(2)
# memory usage: 11.2 MB
# None
# ************************************************************************************************************
#                 Emg1           Emg2           Emg3           Emg4  \
# count  142976.000000  142976.000000  142976.000000  142976.000000
# mean        0.117857       0.143417       0.066564       0.041402
# std         0.272271       0.397495       0.239760       0.193168
# min         0.002400       0.000000       0.002400       0.002400
# 25%         0.002400       0.002400       0.002400       0.002400
# 50%         0.017100       0.002400       0.002400       0.002400
# 75%         0.105000       0.009800       0.004900       0.002400
# max         4.226100       4.663100       4.655800       4.663100
#
#                 Emg5           Emg6           Emg7           Emg8  \
# count  142976.000000  142976.000000  142976.000000  142976.000000
# mean        0.009957       0.014334       0.265964       0.227472
# std         0.030656       0.049708       0.599680       0.430314
# min         0.002400       0.000000       0.002400       0.002400
# 25%         0.002400       0.002400       0.012200       0.061000
# 50%         0.002400       0.002400       0.056200       0.105000
# 75%         0.002400       0.002400       0.183100       0.207500
# max         0.468800       1.484400       4.663100       4.665500
#
#                 Emg9          Emg10       stimulus     restimulus
# count  142976.000000  142976.000000  142976.000000  142976.000000
# mean        0.088279       0.108198       5.529494       3.366551
# std         0.249193       0.209482       5.824562       5.330527
# min         0.000000       0.002400       0.000000       0.000000
# 25%         0.002400       0.022000       0.000000       0.000000
# 50%         0.002400       0.056200       4.000000       0.000000
# 75%         0.017100       0.083000      11.000000       6.000000
# max         4.658200       2.927200      17.000000      17.000000

# %%
print("Unique Dependent values and their counts :")
print(raw_data["stimulus"].value_counts())
# Out:
# Unique Dependent values and their counts :
# 0     55113
# 3      5178
# 8      5177
# 2      5176
# 13     5174
# 15     5173
# 12     5170
# 14     5170
# 7      5170
# 4      5169
# 9      5167
# 6      5167
# 11     5166
# 5      5166
# 1      5165
# 17     5162
# 10     5158
# 16     5155
# Name: stimulus, dtype: int64

# %%
count_classes = pd.value_counts(raw_data['stimulus'], sort = True)

count_classes.plot(kind = 'bar', rot=0)

plt.title("stimulus Class Distribution")

plt.xlabel("Class")

plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
print(raw_data.isnull().any())
# Out:
# Emg1          False
# Emg2          False
# Emg3          False
# Emg4          False
# Emg5          False
# Emg6          False
# Emg7          False
# Emg8          False
# Emg9          False
# Emg10         False
# stimulus      False
# restimulus    False
# dtype: bool

# %% [markdown]
# # Custom Outlier Detection

# %%
index_names = raw_data[ (raw_data['stimulus'] != raw_data['restimulus'])].index
raw_data.drop(index_names, inplace = True)

# %%
raw_data.sample(5)
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 97605   0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0269
# 86701   0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0122  0.0024
# 82426   0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0464
# 26679   0.0098  0.0024  0.0952  0.0024  0.0049  0.0024  0.3296  0.2441
# 112929  0.1343  0.1685  0.0610  0.0439  0.0098  0.0708  2.2949  0.9326
#
#           Emg9   Emg10  stimulus  restimulus
# 97605   0.0024  0.0757         0           0
# 86701   0.0024  0.0586         0           0
# 82426   0.0024  0.0757         0           0
# 26679   0.0562  0.1221         4           4
# 112929  0.0781  0.2075        14          14

# %%
raw_data.shape
# Out:
# (107824, 12)

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107824 entries, 0 to 142975
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Emg1        107824 non-null  float64
#  1   Emg2        107824 non-null  float64
#  2   Emg3        107824 non-null  float64
#  3   Emg4        107824 non-null  float64
#  4   Emg5        107824 non-null  float64
#  5   Emg6        107824 non-null  float64
#  6   Emg7        107824 non-null  float64
#  7   Emg8        107824 non-null  float64
#  8   Emg9        107824 non-null  float64
#  9   Emg10       107824 non-null  float64
#  10  stimulus    107824 non-null  uint8
#  11  restimulus  107824 non-null  uint8
# dtypes: float64(10), uint8(2)
# memory usage: 9.3 MB

# %%
print(raw_data.isnull().any())
# Out:
# Emg1          False
# Emg2          False
# Emg3          False
# Emg4          False
# Emg5          False
# Emg6          False
# Emg7          False
# Emg8          False
# Emg9          False
# Emg10         False
# stimulus      False
# restimulus    False
# dtype: bool

# %% [markdown]
# # Initializing Inputs and Outputs Variables

# %%
X = raw_data.iloc[:,0:10]
y = raw_data.stimulus

# %% [markdown]
# # One Hot Encoding

# %%
num_classes = 18

# %%
# One hot encoding for categorical labels
import keras
from keras import utils as np_utils

#y = keras.utils.to_categorical(y, num_classes)
y = keras.utils.np_utils.to_categorical(y, num_classes)

# %%
input_dim = X.shape[1]

# %% [markdown]
# # Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
standardscaler=StandardScaler()

# %%
sc = pd.DataFrame(standardscaler.fit_transform(X))

# %%
sc
# Out:
#                0         1         2         3         4         5         6  \
# 0      -0.472452 -0.416655 -0.310736 -0.233544 -0.283854 -0.277734 -0.488323
# 1      -0.472452 -0.416655 -0.310736 -0.233544 -0.283854 -0.277734 -0.488323
# 2      -0.472452 -0.416655 -0.310736 -0.233544 -0.283854 -0.277734 -0.488323
# 3      -0.416666 -0.416655 -0.310736 -0.233544 -0.283854 -0.277734 -0.484622
# 4      -0.384695 -0.416655 -0.310736 -0.233544 -0.283854 -0.277734 -0.484622
# ...          ...       ...       ...       ...       ...       ...       ...
# 107819 -0.384695 -0.416655 -0.310736 -0.233544 -0.283854 -0.277734 -0.470264
# 107820 -0.384695 -0.416655 -0.310736 -0.233544 -0.283854 -0.277734 -0.470264
# 107821 -0.408510 -0.416655 -0.310736 -0.233544 -0.283854 -0.277734 -0.481070
# 107822 -0.368709 -0.416655 -0.301566 -0.233544 -0.283854 -0.277734 -0.466563
# 107823 -0.344894 -0.416655 -0.310736 -0.233544 -0.283854 -0.277734 -0.459310
#
#                7         8         9
# 0      -0.483348 -0.403785 -0.534527
# 1      -0.483348 -0.403785 -0.534527
# 2      -0.483348 -0.403785 -0.534527
# 3      -0.448177 -0.403785 -0.534527
# 4      -0.423084 -0.403785 -0.534527
# ...          ...       ...       ...
# 107819 -0.347805 -0.403785 -0.369228
# 107820 -0.347805 -0.403785 -0.369228
# 107821 -0.372898 -0.403785 -0.369228
# 107822 -0.317570 -0.403785 -0.369228
# 107823 -0.287540 -0.403785 -0.359081
#
# [107824 rows x 10 columns]

# %% [markdown]
# # Splitting data for training and testing

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 39)

# %% [markdown]
# # Deep Learning Architecture

# %%
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adadelta, Adagrad, Adamax, Nadam, Ftrl

# %% [raw]
# from sklearn.preprocessing import MinMaxScaler
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Input
# from tensorflow.keras.layers import Dense
# from tensorflow.keras.layers import LeakyReLU,ELU
# from tensorflow.keras.layers import BatchNormalization
# from tensorflow.keras.utils import plot_model
# import tensorflow as tf
# from sklearn.model_selection import cross_val_score
# from keras.models import Sequential
# from keras.layers import Dense, BatchNormalization, Dropout
# from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adadelta, Adagrad, Adamax, Nadam, Ftrl
# from keras.callbacks import EarlyStopping, ModelCheckpoint
# from keras.wrappers.scikit_learn import KerasClassifier
# from sklearn.metrics import make_scorer, accuracy_score
# from sklearn.model_selection import StratifiedKFold

# %% [raw]
# from keras.layers import LeakyReLU
# LeakyReLU = LeakyReLU(alpha=0.1)
# from keras.models import Sequential
# from keras.layers import Dense, Flatten, Convolution1D, Dropout
# from keras.initializers import random_uniform

# %% [markdown]
# # 1. Define Network

# %%
num_classes = 18
input_dim = X.shape[1]

# %%
visible = Input(shape=(input_dim,))
hidden1 = Dense(3000, activation='relu')(visible)
hidden2 = Dense(1500, activation='relu')(hidden1)
hidden3 = Dropout(0.2)(hidden2)
hidden4 = Dense(750, activation='relu')(hidden3)
hidden5 = Dense(375, activation='relu')(hidden4)
hidden6 = Dense(48, activation='relu')(hidden5)
output = Dense(num_classes, activation='softmax')(hidden6)
model = Model(inputs=visible, outputs=output)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 10)]              0
#
#  dense (Dense)               (None, 3000)              33000
#
#  dense_1 (Dense)             (None, 1500)              4501500
#
#  dropout (Dropout)           (None, 1500)              0
#
#  dense_2 (Dense)             (None, 750)               1125750
#
#  dense_3 (Dense)             (None, 375)               281625
#
#  dense_4 (Dense)             (None, 48)                18048
#
#  dense_5 (Dense)             (None, 18)                882
#
# =================================================================
# Total params: 5,960,805
# Trainable params: 5,960,805
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 2. Compile Network

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
plot_model(model, 'EMG_ANN.png', show_shapes = True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# # 3. Fit Network

# %%
import time
start_time = time.time()

history = model.fit(X_train, y_train, batch_size=9000, epochs=300, validation_data = (X_test, y_test))

print (time.time() - start_time, "seconds")
# Out:
# Epoch 1/300
# 11/11 [==============================] - 43s 3s/step - loss: 2.1865 - accuracy: 0.5574 - val_loss: 1.3213 - val_accuracy: 0.6529
# Epoch 2/300
# 11/11 [==============================] - 39s 4s/step - loss: 1.1875 - accuracy: 0.6773 - val_loss: 1.0244 - val_accuracy: 0.7201
# Epoch 3/300
# 11/11 [==============================] - 39s 4s/step - loss: 0.9828 - accuracy: 0.7250 - val_loss: 0.8889 - val_accuracy: 0.7533
# Epoch 4/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.8781 - accuracy: 0.7512 - val_loss: 0.8375 - val_accuracy: 0.7588
# Epoch 5/300
# 11/11 [==============================] - 39s 4s/step - loss: 0.8302 - accuracy: 0.7693 - val_loss: 0.8146 - val_accuracy: 0.7811
# Epoch 6/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.7893 - accuracy: 0.7798 - val_loss: 0.7536 - val_accuracy: 0.7840
# Epoch 7/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.7332 - accuracy: 0.7908 - val_loss: 0.7005 - val_accuracy: 0.7998
# Epoch 8/300
# 11/11 [==============================] - 39s 4s/step - loss: 0.6969 - accuracy: 0.7990 - val_loss: 0.6698 - val_accuracy: 0.8081
# Epoch 9/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.6682 - accuracy: 0.8066 - val_loss: 0.6447 - val_accuracy: 0.8183
# Epoch 10/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.6437 - accuracy: 0.8129 - val_loss: 0.6175 - val_accuracy: 0.8217
# Epoch 11/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.6248 - accuracy: 0.8160 - val_loss: 0.6087 - val_accuracy: 0.8229
# Epoch 12/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.6114 - accuracy: 0.8201 - val_loss: 0.6025 - val_accuracy: 0.8286
# Epoch 13/300
# 11/11 [==============================] - 39s 4s/step - loss: 0.6187 - accuracy: 0.8221 - val_loss: 0.5884 - val_accuracy: 0.8269
# Epoch 14/300
# 11/11 [==============================] - 39s 4s/step - loss: 0.5870 - accuracy: 0.8267 - val_loss: 0.5628 - val_accuracy: 0.8337
# Epoch 15/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.5658 - accuracy: 0.8312 - val_loss: 0.5450 - val_accuracy: 0.8390
# Epoch 16/300
# 11/11 [==============================] - 39s 4s/step - loss: 0.5515 - accuracy: 0.8352 - val_loss: 0.5316 - val_accuracy: 0.8408
# Epoch 17/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.5396 - accuracy: 0.8393 - val_loss: 0.5689 - val_accuracy: 0.8437
# Epoch 18/300
# 11/11 [==============================] - 39s 4s/step - loss: 0.5667 - accuracy: 0.8365 - val_loss: 0.5209 - val_accuracy: 0.8465
# Epoch 19/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.5306 - accuracy: 0.8416 - val_loss: 0.5077 - val_accuracy: 0.8477
# Epoch 20/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.5109 - accuracy: 0.8471 - val_loss: 0.4928 - val_accuracy: 0.8551
# Epoch 21/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.5018 - accuracy: 0.8500 - val_loss: 0.4821 - val_accuracy: 0.8554
# Epoch 22/300
# 11/11 [==============================] - 44s 4s/step - loss: 0.4899 - accuracy: 0.8537 - val_loss: 0.4862 - val_accuracy: 0.8576
# Epoch 23/300
# 11/11 [==============================] - 45s 4s/step - loss: 0
300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2760 - accuracy: 0.9180 - val_loss: 0.2919 - val_accuracy: 0.9127
# Epoch 135/300
# 11/11 [==============================] - 41s 4s/step - loss: 0.2655 - accuracy: 0.9216 - val_loss: 0.2812 - val_accuracy: 0.9180
# Epoch 136/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2620 - accuracy: 0.9223 - val_loss: 0.2725 - val_accuracy: 0.9188
# Epoch 137/300
# 11/11 [==============================] - 41s 4s/step - loss: 0.2574 - accuracy: 0.9231 - val_loss: 0.2761 - val_accuracy: 0.9158
# Epoch 138/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2585 - accuracy: 0.9234 - val_loss: 0.2799 - val_accuracy: 0.9163
# Epoch 139/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2642 - accuracy: 0.9213 - val_loss: 0.2755 - val_accuracy: 0.9160
# Epoch 140/300
# 11/11 [==============================] - 44s 4s/step - loss: 0.2607 - accuracy: 0.9216 - val_loss: 0.2738 - val_accuracy: 0.9185
# Epoch 141/300
# 11/11 [==============================] - 45s 4s/step - loss: 0.2557 - accuracy: 0.9240 - val_loss: 0.2732 - val_accuracy: 0.9181
# Epoch 142/300
# 11/11 [==============================] - 45s 4s/step - loss: 0.2519 - accuracy: 0.9247 - val_loss: 0.2682 - val_accuracy: 0.9215
# Epoch 143/300
# 11/11 [==============================] - 42s 4s/step - loss: 0.2498 - accuracy: 0.9258 - val_loss: 0.2691 - val_accuracy: 0.9205
# Epoch 144/300
# 11/11 [==============================] - 39s 4s/step - loss: 0.2511 - accuracy: 0.9249 - val_loss: 0.2657 - val_accuracy: 0.9200
# Epoch 145/300
# 11/11 [==============================] - 39s 4s/step - loss: 0.2510 - accuracy: 0.9252 - val_loss: 0.2688 - val_accuracy: 0.9214
# Epoch 146/300
# 11/11 [==============================] - 45s 4s/step - loss: 0.2608 - accuracy: 0.9225 - val_loss: 0.2814 - val_accuracy: 0.9168
# Epoch 147/300
# 11/11 [==============================] - 44s 4s/step - loss: 0.2560 - accuracy: 0.9235 - val_loss: 0.2756 - val_accuracy: 0.9186
# Epoch 148/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2536 - accuracy: 0.9244 - val_loss: 0.2691 - val_accuracy: 0.9196
# Epoch 149/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2483 - accuracy: 0.9263 - val_loss: 0.2625 - val_accuracy: 0.9221
# Epoch 150/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2478 - accuracy: 0.9263 - val_loss: 0.2740 - val_accuracy: 0.9192
# Epoch 151/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2487 - accuracy: 0.9266 - val_loss: 0.2636 - val_accuracy: 0.9214
# Epoch 152/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2439 - accuracy: 0.9274 - val_loss: 0.2640 - val_accuracy: 0.9214
# Epoch 153/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2446 - accuracy: 0.9263 - val_loss: 0.2593 - val_accuracy: 0.9236
# Epoch 154/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2461 - accuracy: 0.9269 - val_loss: 0.2629 - val_accuracy: 0.9207
# Epoch 155/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2445 - accuracy: 0.9277 - val_loss: 0.2683 - val_accuracy: 0.9213
# Epoch 156/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2438 - accuracy: 0.9264 - val_loss: 0.2607 - val_accuracy: 0.9218
# Epoch 157/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2422 - accuracy: 0.9281 - val_loss: 0.2599 - val_accuracy: 0.9223
# Epoch 158/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2407 - accuracy: 0.9285 - val_loss: 0.2644 - val_accuracy: 0.9201
# Epoch 159/300
# 11/11 [==============================] - 48s 4s/step - loss: 0.2438 - accuracy: 0.9270 - val_loss: 0.2620 - val_accuracy: 0.9219
# Epoch 160/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2495 - accuracy: 0.9259 - val_loss: 0.2630 - val_accuracy: 0.9229
# Epoch 161/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2485 - accuracy: 0.9269 - val_loss: 0.2692 - val_accuracy: 0.9188
# Epoch 162/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2444 - accuracy: 0.9269 - val_loss: 0.2647 - val_accuracy: 0.9227
# Epoch 163/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2402 - accuracy: 0.9284 - val_loss: 0.2633 - val_accuracy: 0.9207
# Epoch 164/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2454 - accuracy: 0.9268 - val_loss: 0.2709 - val_accuracy: 0.9189
# Epoch 165/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2428 - accuracy: 0.9280 - val_loss: 0.2627 - val_accuracy: 0.9222
# Epoch 166/300
# 11/11 [==============================] - 47s 4s/step - loss: 0.2401 - accuracy: 0.9284 - val_loss: 0.2588 - val_accuracy: 0.9235
# Epoch 167/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2378 - accuracy: 0.9290 - val_loss: 0.2585 - val_accuracy: 0.9242
# Epoch 168/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2376 - accuracy: 0.9293 - val_loss: 0.2616 - val_accuracy: 0.9222
# Epoch 169/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2381 - accuracy: 0.9290 - val_loss: 0.2586 - val_accuracy: 0.9241
# Epoch 170/300
# 11/11 [==============================] - 42s 4s/step - loss: 0.2347 - accuracy: 0.9304 - val_loss: 0.2537 - val_accuracy: 0.9254
# Epoch 171/300
# 11/11 [==============================] - 44s 4s/step - loss: 0.2365 - accuracy: 0.9295 - val_loss: 0.2570 - val_accuracy: 0.9233
# Epoch 172/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2362 - accuracy: 0.9297 - val_loss: 0.2570 - val_accuracy: 0.9242
# Epoch 173/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2328 - accuracy: 0.9309 - val_loss: 0.2546 - val_accuracy: 0.9253
# Epoch 174/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2324 - accuracy: 0.9309 - val_loss: 0.2627 - val_accuracy: 0.9224
# Epoch 175/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2342 - accuracy: 0.9307 - val_loss: 0.2511 - val_accuracy: 0.9261
# Epoch 176/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2281 - accuracy: 0.9318 - val_loss: 0.2510 - val_accuracy: 0.9251
# Epoch 177/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2283 - accuracy: 0.9326 - val_loss: 0.2510 - val_accuracy: 0.9252
# Epoch 178/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2295 - accuracy: 0.9318 - val_loss: 0.2508 - val_accuracy: 0.9250
# Epoch 179/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2272 - accuracy: 0.9322 - val_loss: 0.2537 - val_accuracy: 0.9243
# Epoch 180/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2286 - accuracy: 0.9319 - val_loss: 0.2532 - val_accuracy: 0.9251
# Epoch 181/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2281 - accuracy: 0.9321 - val_loss: 0.2620 - val_accuracy: 0.9227
# Epoch 182/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2308 - accuracy: 0.9318 - val_loss: 0.2557 - val_accuracy: 0.9247
# Epoch 183/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2246 - accuracy: 0.9324 - val_loss: 0.2520 - val_accuracy: 0.9241
# Epoch 184/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2267 - accuracy: 0.9332 - val_loss: 0.2565 - val_accuracy: 0.9255
# Epoch 185/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2259 - accuracy: 0.9331 - val_loss: 0.2456 - val_accuracy: 0.9270
# Epoch 186/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2229 - accuracy: 0.9335 - val_loss: 0.2478 - val_accuracy: 0.9247
# Epoch 187/300
# 11/11 [==============================] - 39s 4s/step - loss: 0.2209 - accuracy: 0.9346 - val_loss: 0.2472 - val_accuracy: 0.9257
# Epoch 188/300
# 11/11 [==============================] - 39s 4s/step - loss: 0.2341 - accuracy: 0.9308 - val_loss: 0.2683 - val_accuracy: 0.9235
# Epoch 189/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2447 - accuracy: 0.9278 - val_loss: 0.2595 - val_accuracy: 0.9231
# Epoch 190/300
# 11/11 [==============================] - 39s 4s/step - loss: 0.2302 - accuracy: 0.9319 - val_loss: 0.2576 - val_accuracy: 0.9228
# Epoch 191/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2257 - accuracy: 0.9324 - val_loss: 0.2515 - val_accuracy: 0.9258
# Epoch 192/300
# 11/11 [==============================] - 45s 4s/step - loss: 0.2211 - accuracy: 0.9335 - val_loss: 0.2441 - val_accuracy: 0.9258
# Epoch 193/300
# 11/11 [==============================] - 43s 4s/step - loss: 0.2205 - accuracy: 0.9345 - val_loss: 0.2483 - val_accuracy: 0.9278
# Epoch 194/300
# 11/11 [==============================] - 39s 4s/step - loss: 0.2209 - accuracy: 0.9346 - val_loss: 0.2454 - val_accuracy: 0.9271
# Epoch 195/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2204 - accuracy: 0.9341 - val_loss: 0.2473 - val_accuracy: 0.9276
# Epoch 196/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2274 - accuracy: 0.9330 - val_loss: 0.2543 - val_accuracy: 0.9256
# Epoch 197/300
# 11/11 [==============================] - 39s 4s/step - loss: 0.2198 - accuracy: 0.9348 - val_loss: 0.2457 - val_accuracy: 0.9260
# Epoch 198/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2166 - accuracy: 0.9355 - val_loss: 0.2420 - val_accuracy: 0.9279
# Epoch 199/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2149 - accuracy: 0.9361 - val_loss: 0.2503 - val_accuracy: 0.9261
# Epoch 200/300
# 11/11 [==============================] - 39s 4s/step - loss: 0.2150 - accuracy: 0.9363 - val_loss: 0.2422 - val_accuracy: 0.9276
# Epoch 201/300
# 11/11 [==============================] - 39s 4s/step - loss: 0.2193 - accuracy: 0.9356 - val_loss: 0.2570 - val_accuracy: 0.9266
# Epoch 202/300
# 11/11 [==============================] - 39s 4s/step - loss: 0.2188 - accuracy: 0.9351 - val_loss: 0.2441 - val_accuracy: 0.9271
# Epoch 203/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2179 - accuracy: 0.9345 - val_loss: 0.2504 - val_accuracy: 0.9239
# Epoch 204/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2254 - accuracy: 0.9326 - val_loss: 0.2522 - val_accuracy: 0.9263
# Epoch 205/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2268 - accuracy: 0.9332 - val_loss: 0.2472 - val_accuracy: 0.9277
# Epoch 206/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2142 - accuracy: 0.9365 - val_loss: 0.2487 - val_accuracy: 0.9250
# Epoch 207/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2148 - accuracy: 0.9368 - val_loss: 0.2381 - val_accuracy: 0.9293
# Epoch 208/300
# 11/11 [==============================] - 39s 4s/step - loss: 0.2103 - accuracy: 0.9378 - val_loss: 0.2381 - val_accuracy: 0.9291
# Epoch 209/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2086 - accuracy: 0.9388 - val_loss: 0.2421 - val_accuracy: 0.9271
# Epoch 210/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2094 - accuracy: 0.9375 - val_loss: 0.2390 - val_accuracy: 0.9302
# Epoch 211/300
# 11/11 [==============================] - 39s 4s/step - loss: 0.2077 - accuracy: 0.9387 - val_loss: 0.2407 - val_accuracy: 0.9308
# Epoch 212/300
# 11/11 [==============================] - 39s 4s/step - loss: 0.2101 - accuracy: 0.9376 - val_loss: 0.2391 - val_accuracy: 0.9291
# Epoch 213/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2107 - accuracy: 0.9365 - val_loss: 0.2434 - val_accuracy: 0.9281
# Epoch 214/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2105 - accuracy: 0.9376 - val_loss: 0.2488 - val_accuracy: 0.9266
# Epoch 215/300
# 11/11 [==============================] - 47s 4s/step - loss: 0.2121 - accuracy: 0.9372 - val_loss: 0.2497 - val_accuracy: 0.9266
# Epoch 216/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2094 - accuracy: 0.9378 - val_loss: 0.2415 - val_accuracy: 0.9302
# Epoch 217/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.2109 - accuracy: 0.9381 - val_loss: 0.2397 - val_accuracy: 0.9300
# Epoch 218/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.
300
# 11/11 [==============================] - 39s 4s/step - loss: 0.1927 - accuracy: 0.9429 - val_loss: 0.2290 - val_accuracy: 0.9333
# Epoch 248/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1931 - accuracy: 0.9426 - val_loss: 0.2322 - val_accuracy: 0.9316
# Epoch 249/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1961 - accuracy: 0.9419 - val_loss: 0.2289 - val_accuracy: 0.9318
# Epoch 250/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1944 - accuracy: 0.9427 - val_loss: 0.2378 - val_accuracy: 0.9319
# Epoch 251/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1958 - accuracy: 0.9420 - val_loss: 0.2404 - val_accuracy: 0.9300
# Epoch 252/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1975 - accuracy: 0.9413 - val_loss: 0.2325 - val_accuracy: 0.9325
# Epoch 253/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1970 - accuracy: 0.9413 - val_loss: 0.2330 - val_accuracy: 0.9317
# Epoch 254/300
# 11/11 [==============================] - 39s 4s/step - loss: 0.1956 - accuracy: 0.9426 - val_loss: 0.2300 - val_accuracy: 0.9327
# Epoch 255/300
# 11/11 [==============================] - 41s 4s/step - loss: 0.1950 - accuracy: 0.9431 - val_loss: 0.2320 - val_accuracy: 0.9325
# Epoch 256/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1943 - accuracy: 0.9426 - val_loss: 0.2300 - val_accuracy: 0.9338
# Epoch 257/300
# 11/11 [==============================] - 42s 4s/step - loss: 0.1960 - accuracy: 0.9417 - val_loss: 0.2318 - val_accuracy: 0.9327
# Epoch 258/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1956 - accuracy: 0.9423 - val_loss: 0.2408 - val_accuracy: 0.9319
# Epoch 259/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1983 - accuracy: 0.9418 - val_loss: 0.2364 - val_accuracy: 0.9321
# Epoch 260/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1948 - accuracy: 0.9418 - val_loss: 0.2338 - val_accuracy: 0.9336
# Epoch 261/300
# 11/11 [==============================] - 44s 4s/step - loss: 0.1913 - accuracy: 0.9434 - val_loss: 0.2320 - val_accuracy: 0.9326
# Epoch 262/300
# 11/11 [==============================] - 44s 4s/step - loss: 0.1905 - accuracy: 0.9436 - val_loss: 0.2344 - val_accuracy: 0.9315
# Epoch 263/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1869 - accuracy: 0.9446 - val_loss: 0.2262 - val_accuracy: 0.9342
# Epoch 264/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1923 - accuracy: 0.9433 - val_loss: 0.2372 - val_accuracy: 0.9307
# Epoch 265/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1991 - accuracy: 0.9418 - val_loss: 0.2412 - val_accuracy: 0.9305
# Epoch 266/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1939 - accuracy: 0.9416 - val_loss: 0.2349 - val_accuracy: 0.9329
# Epoch 267/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1883 - accuracy: 0.9447 - val_loss: 0.2246 - val_accuracy: 0.9350
# Epoch 268/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1858 - accuracy: 0.9448 - val_loss: 0.2303 - val_accuracy: 0.9328
# Epoch 269/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1866 - accuracy: 0.9444 - val_loss: 0.2316 - val_accuracy: 0.9333
# Epoch 270/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1853 - accuracy: 0.9451 - val_loss: 0.2319 - val_accuracy: 0.9330
# Epoch 271/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1877 - accuracy: 0.9444 - val_loss: 0.2279 - val_accuracy: 0.9332
# Epoch 272/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1836 - accuracy: 0.9454 - val_loss: 0.2266 - val_accuracy: 0.9335
# Epoch 273/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1873 - accuracy: 0.9441 - val_loss: 0.2363 - val_accuracy: 0.9297
# Epoch 274/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1862 - accuracy: 0.9450 - val_loss: 0.2243 - val_accuracy: 0.9341
# Epoch 275/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1844 - accuracy: 0.9459 - val_loss: 0.2334 - val_accuracy: 0.9319
# Epoch 276/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1931 - accuracy: 0.9428 - val_loss: 0.2331 - val_accuracy: 0.9315
# Epoch 277/300
# 11/11 [==============================] - 39s 4s/step - loss: 0.1875 - accuracy: 0.9453 - val_loss: 0.2265 - val_accuracy: 0.9338
# Epoch 278/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1843 - accuracy: 0.9462 - val_loss: 0.2244 - val_accuracy: 0.9360
# Epoch 279/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1844 - accuracy: 0.9448 - val_loss: 0.2269 - val_accuracy: 0.9344
# Epoch 280/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1854 - accuracy: 0.9449 - val_loss: 0.2263 - val_accuracy: 0.9346
# Epoch 281/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1819 - accuracy: 0.9460 - val_loss: 0.2254 - val_accuracy: 0.9340
# Epoch 282/300
# 11/11 [==============================] - 47s 4s/step - loss: 0.1832 - accuracy: 0.9457 - val_loss: 0.2274 - val_accuracy: 0.9337
# Epoch 283/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1849 - accuracy: 0.9455 - val_loss: 0.2322 - val_accuracy: 0.9342
# Epoch 284/300
# 11/11 [==============================] - 39s 4s/step - loss: 0.1856 - accuracy: 0.9453 - val_loss: 0.2298 - val_accuracy: 0.9321
# Epoch 285/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1834 - accuracy: 0.9461 - val_loss: 0.2301 - val_accuracy: 0.9317
# Epoch 286/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1890 - accuracy: 0.9439 - val_loss: 0.2282 - val_accuracy: 0.9338
# Epoch 287/300
# 11/11 [==============================] - 39s 4s/step - loss: 0.1881 - accuracy: 0.9436 - val_loss: 0.2319 - val_accuracy: 0.9342
# Epoch 288/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1830 - accuracy: 0.9463 - val_loss: 0.2200 - val_accuracy: 0.9355
# Epoch 289/300
# 11/11 [==============================] - 39s 4s/step - loss: 0.1829 - accuracy: 0.9460 - val_loss: 0.2310 - val_accuracy: 0.9314
# Epoch 290/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1820 - accuracy: 0.9460 - val_loss: 0.2226 - val_accuracy: 0.9350
# Epoch 291/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1833 - accuracy: 0.9457 - val_loss: 0.2242 - val_accuracy: 0.9344
# Epoch 292/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1814 - accuracy: 0.9465 - val_loss: 0.2271 - val_accuracy: 0.9347
# Epoch 293/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1827 - accuracy: 0.9463 - val_loss: 0.2280 - val_accuracy: 0.9342
# Epoch 294/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1811 - accuracy: 0.9463 - val_loss: 0.2257 - val_accuracy: 0.9330
# Epoch 295/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1850 - accuracy: 0.9458 - val_loss: 0.2277 - val_accuracy: 0.9334
# Epoch 296/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1878 - accuracy: 0.9442 - val_loss: 0.2392 - val_accuracy: 0.9297
# Epoch 297/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1881 - accuracy: 0.9445 - val_loss: 0.2359 - val_accuracy: 0.9318
# Epoch 298/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1833 - accuracy: 0.9459 - val_loss: 0.2254 - val_accuracy: 0.9348
# Epoch 299/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1821 - accuracy: 0.9462 - val_loss: 0.2239 - val_accuracy: 0.9345
# Epoch 300/300
# 11/11 [==============================] - 40s 4s/step - loss: 0.1836 - accuracy: 0.9453 - val_loss: 0.2329 - val_accuracy: 0.9329
# 12580.57247209549 seconds

# %% [markdown]
# # 4.Evaluate Network

# %% [markdown]
# # 4.1. Plotting Loss and Accuracy¶

# %%
#Loss Curve


plt.plot(figsize = [8,6])

plt.plot(history.history['loss'],'r',linewidth = 3.0)
plt.plot(history.history['val_loss'],'b',linewidth = 3.0)

plt.legend(['Training Loss', 'Validation Loss'], fontsize = 18)

plt.xlabel('Epochs', fontsize = 16)
plt.ylabel('Loss', fontsize = 16)

plt.title('Loss Curve of Deep Neural Netowork' , fontsize = 16 )
# Out:
# Text(0.5, 1.0, 'Loss Curve of Deep Neural Netowork')

# %%
#Accuracy Curve

plt.plot(figsize = [8,6])
plt.plot(history.history['accuracy'],'r',linewidth = 3.0)
plt.plot(history.history['val_accuracy'],'b',linewidth = 3.0)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize = 18)

plt.xlabel('Epochs', fontsize = 16)
plt.ylabel('Accuracy', fontsize = 16)


plt.title('Accuracy Curve of Deep Neural Netowork' , fontsize = 16 )
# Out:
# Text(0.5, 1.0, 'Accuracy Curve of Deep Neural Netowork')

# %% [markdown]
# # 4.2 Make Predictions

# %%
predictions = model.predict(X_test)
predictions = np.argmax(predictions, axis = 1)
# Out:
# 337/337 [==============================] - 5s 15ms/step

# %%
predictions
# Out:
# array([14,  0,  0, ..., 10, 11, 12], dtype=int64)

# %% [markdown]
# # Transforming from One Hot Encoding

# %%
y_test =np.argmax(y_test, axis=1)
y_test[1]
# Out:
# 0

# %%
from sklearn.metrics import accuracy_score
accuracy = {accuracy_score(y_test, predictions)}
print(f"Accuracy is: {accuracy_score(y_test, predictions)* 100}")
# Out:
# Accuracy is: 93.28572753408142

# %% [markdown]
# # 4.3 Classification Report

# %%
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, classification_report
print('\033[1m' +'Classification report : '+ '\033[0m\n', classification_report(y_test, predictions))

cm = confusion_matrix(predictions, y_test)
print('\033[1m' +'Confusion Matrix : '+ '\033[0m')
sns.heatmap(cm, cmap = 'OrRd',annot = True, fmt='d')
plt.show()
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      5555
#            1       0.87      0.87      0.87       328
#            2       0.91      0.89      0.90       301
#            3       0.98      0.85      0.91       312
#            4       0.81      0.81      0.81       299
#            5       0.85      0.86      0.86       225
#            6       0.97      0.89      0.93       386
#            7       0.94      0.85      0.89       300
#            8       0.93      0.91      0.92       274
#            9       0.97      0.87      0.92       363
#           10       0.98      0.90      0.94       326
#           11       0.85      0.88      0.87       278
#           12       0.93      0.85      0.89       360
#           13       0.88      0.89      0.88       300
#           14       0.94      0.87      0.91       187
#           15       0.89      0.93      0.91       258
#           16       0.93      0.95      0.94       339
#           17       0.98      0.83      0.90       392
#
#     accuracy                           0.93     10783
#    macro avg       0.92      0.88      0.90     10783
# weighted avg       0.93      0.93      0.93     10783
#
# Confusion Matrix :

# %% [markdown]
# # 4.4 Evaluation

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test,predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 0.4153760549012334
# MSE: 4.0896781971622
# RMSE: 2.022295279419452

# %%
from sklearn.metrics import precision_score
print("Precision Score : ",precision_score(y_test, predictions, average='weighted'))


from sklearn.metrics import recall_score
print("Recall Score : ",recall_score(y_test, predictions,average='weighted'))


from sklearn.metrics import f1_score
print("f1_score : ",f1_score(y_test, predictions,average='weighted'))
# Out:
# Precision Score :  0.933577609316946
# Recall Score :  0.9328572753408142
# f1_score :  0.9322265102663725
