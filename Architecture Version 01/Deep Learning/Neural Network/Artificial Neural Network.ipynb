# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, classification_report

# %% [markdown]
# # Exploratory Data Analysis

# %%
raw_data = pd.read_excel('Dataset1 .xlsx')
raw_data.sample(50)
# Out:
#          emg1    emg2    emg3    emg4    emg5    emg6    emg7    emg8    emg9  \
# 40079  0.0171  0.0024  0.0049  0.0049  0.0024  0.0024  0.4419  0.1440  0.0757
# 96317  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0513  0.0708  0.0024
# 45744  0.0024  0.0024  0.0269  0.0195  0.0024  0.0024  0.0293  0.0854  0.0024
# 90341  0.1758  0.8081  0.1099  0.0024  0.0024  0.0024  0.1245  0.9131  0.3027
# 90691  0.0244  0.0024  0.0024  0.0024  0.0024  0.0024  0.0073  0.0439  0.0024
# 54177  0.5786  0.2661  0.1855  0.0635  0.0024  0.0024  0.1294  0.1636  0.0854
# 26450  0.0586  0.3833  0.1978  0.0562  0.0098  0.0146  0.9009  0.2856  0.2539
# 62770  0.1001  0.0024  0.0024  0.0024  0.0024  0.0024  0.2222  0.1367  0.0366
# 18817  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0269  0.0073
# 67675  0.0024  0.0415  0.0024  0.0024  0.0024  0.0024  0.0977  0.0830  0.0024
# 87312  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0562  0.0732  0.0024
# 49753  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0098  0.0464  0.0024
# 37607  0.0024  0.0024  0.0098  0.0024  0.0024  0.0024  0.4248  0.1440  0.0024
# 94650  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0684  0.0757  0.0024
# 85636  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.1392  0.0610  0.0024
# 17441  0.0073  0.1147  0.0146  0.0024  0.0024  0.0024  0.0024  0.0708  0.2759
# 28238  0.0488  0.4199  0.3467  0.0024  0.0024  0.0024  0.4858  0.4370  0.3516
# 56746  1.2866  0.4834  0.5151  0.2246  0.0293  0.0464  1.7578  0.4224  0.2417
# 46155  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0317  0.0024
# 76879  0.0977  0.1099  0.2417  0.0195  0.0024  0.0024  0.1953  0.2246  0.0342
# 25764  0.1343  0.4565  0.2881  0.0757  0.0098  0.0562  1.3672  0.4395  0.2905
# 88574  0.0366  0.4053  0.0024  0.0024  0.0024  0.0024  0.0220  0.2905  0.1733
# 74931  0.0952  0.0024  0.0024  0.0024  0.0024  0.0024  0.0073  0.0781  0.0024
# 22656  0.0122  0.0024  0.0464  0.0415  0.0024  0.0024  0.1245  0.1001  0.0146
# 84267  0.0073  0.0024  0.0024  0.0024  0.0024  0.0024  0.1123  0.0635  0.0024
# 81881  0.0244  0.0317  0.1660  0.0195  0.0024  0.0024  0.1831  0.0879  0.0024
# 28030  0.0122  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0537  0.0024
# 22626  0.0098  0.0024  0.0171  0.0171  0.0024  0.0024  0.1367  0.1196  0.0024
# 16456  0.0122  0.3516  0.0024  0.0024  0.0024  0.0024  0.0024  0.0195  0.1978
# 88965  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0537  0.0342  0.0024
# 15882  0.0024  0.0024  0.0024  0.0049  0.0024  0.0024  0.0024  0.0122  0.0024
# 12987  0.0024  0.0513  0.0024  0.0024  0.0024  0.0024  0.0024  0.0146  0.1563
# 32100  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366  0.0024
# 83223  0.0024  0.0024  0.0049  0.0024  0.0024  0.0024  0.1147  0.0464  0.0024
# 44382  0.0830  0.0513  0.0537  0.0977  0.0024  0.0024  0.1782  0.3174  0.1025
# 42368  0.0049  0.0024  0.0415  0.0024  0.0024  0.0024  0.3784  0.1025  0.0024
# 17424  0.0098  0.0464  0.0513  0.0024  0.0024  0.0024  0.0073  0.0684  0.1685
# 65945  0.0830  0.0024  0.0293  0.0024  0.0024  0.0024  0.3125  0.3027  0.2197
# 86957  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366  0.0562  0.0024
# 37745  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.3809  0.1270  0.0024
# 56006  0.5420  0.0464  0.0513  0.0171  0.0024  0.0024  0.2466  0.2246  0.0024
# 8692   0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0342  0.0269  0.0073
# 64079  0.0146  0.0024  0.0024  0.0024  0.0024  0.0024  0.0293  0.0244  0.0024
# 35232  0.0269  0.0024  0.0024  0.0024  0.0024  0.0024  0.0073  0.1904  0.0049
# 80646  0.0098  0.0024  0.0024  0.0024  0.0024  0.0024  0.0781  0.0757  0.0024
# 82718  0.0220  0.0024  0.0439  0.0024  0.0024  0.0024  0.1050  0.0903  0.0024
# 32651  0.0049  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0342  0.0049
# 2387   0.0098  0.1538  0.1074  0.0024  0.0024  0.0024  0.1172  0.0269  0.2271
# 59589  0.0049  0.0024  0.0024  0.0024  0.0024  0.0024  0.0049  0.0366  0.0024
# 1463   0.0342  0.0513  0.0171  0.0024  0.0024  0.0024  0.0977  0.0586  0.1416
#
#         emg10  repetition  rerepetition  stimulus  restimulus
# 40079  0.0708           8             8         5           5
# 96317  0.0244           5             5        12          12
# 45744  0.0562           5             5         6           6
# 90341  0.2246           8             8        11          11
# 90691  0.0049           0             0         0           0
# 54177  0.2588           5             5         7           7
# 26450  0.0439           2             2         4           4
# 62770  0.0220           5             5         8           8
# 18817  0.0024           3             0         3           0
# 67675  0.0391           1             1         9           9
# 87312  0.0024           0             0         0           0
# 49753  0.0024           0             0         0           0
# 37607  0.0854           5             5         5           5
# 94650  0.0171           3             0        12           0
# 85636  0.0073           0             0         0           0
# 17441  0.0244           1             1         3           3
# 28238  0.0464           4             4         4           4
# 56746  0.4688           8             8         7           7
# 46155  0.0122           0             0         0           0
# 76879  0.0220           2             2        10          10
# 25764  0.0830           1             1         4           4
# 88574  0.0024           6             6        11          11
# 74931  0.0049           0             0         0           0
# 22656  0.0342           0             0         0           0
# 84267  0.0024           1             0        11           0
# 81881  0.0024           8             8        10          10
# 28030  0.0171           4             0         4           0
# 22626  0.0488           7             0         3           0
# 16456  0.2710          10            10         2           2
# 88965  0.0024           0             0         0           0
# 15882  0.0024           9             0         2           0
# 12987  0.0879           6             6         2           2
# 32100  0.0049           0             0         0           0
# 83223  0.0024           0             0         0           0
# 44382  0.0293           3             3         6           6
# 42368  0.0684           1             1         6           6
# 17424  0.0342           1             1         3           3
# 65945  0.0635           9             9         8           8
# 86957  0.0073           4             0        11           0
# 37745  0.0610           5             0         5           0
# 56006  0.1147           7             7         7           7
# 8692   0.0073           0             0         0           0
# 64079  0.0049           0             0         0           0
# 35232  0.0146           0             0         0           0
# 80646  0.0024           0             0         0           0
# 82718  0.0024           9             9        10          10
# 32651  0.0342           9             0         4           0
# 2387   0.0171           3             3         1           1
# 59589  0.0171           0             0         0           0
# 1463   0.0049           2             2         1           1

# %%
raw_data.shape
# Out:
# (101014, 14)

# %%
raw_data.columns
# Out:
# Index(['emg1', 'emg2', 'emg3', 'emg4', 'emg5', 'emg6', 'emg7', 'emg8', 'emg9',
#        'emg10', 'repetition', 'rerepetition', 'stimulus', 'restimulus'],
#       dtype='object')

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101014 entries, 0 to 101013
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   emg1          101014 non-null  float64
#  1   emg2          101014 non-null  float64
#  2   emg3          101014 non-null  float64
#  3   emg4          101014 non-null  float64
#  4   emg5          101014 non-null  float64
#  5   emg6          101014 non-null  float64
#  6   emg7          101014 non-null  float64
#  7   emg8          101014 non-null  float64
#  8   emg9          101014 non-null  float64
#  9   emg10         101014 non-null  float64
#  10  repetition    101014 non-null  int64
#  11  rerepetition  101014 non-null  int64
#  12  stimulus      101014 non-null  int64
#  13  restimulus    101014 non-null  int64
# dtypes: float64(10), int64(4)
# memory usage: 10.8 MB

# %%
raw_data.describe(include='all')
# Out:
#                 emg1           emg2           emg3           emg4  \
# count  101014.000000  101014.000000  101014.000000  101014.000000
# mean        0.039693       0.086158       0.041308       0.012502
# std         0.127180       0.231539       0.101912       0.031334
# min         0.002400       0.000000       0.002400       0.000000
# 25%         0.002400       0.002400       0.002400       0.002400
# 50%         0.002400       0.002400       0.002400       0.002400
# 75%         0.024400       0.002400       0.012200       0.002400
# max         2.399900       2.480500       1.340300       0.446800
#
#                 emg5           emg6           emg7           emg8  \
# count  101014.000000  101014.000000  101014.000000  101014.000000
# mean        0.003868       0.005367       0.167648       0.116476
# std         0.009796       0.021238       0.403823       0.174862
# min         0.002400       0.000000       0.002400       0.002400
# 25%         0.002400       0.002400       0.009800       0.039100
# 50%         0.002400       0.002400       0.046400       0.061000
# 75%         0.002400       0.002400       0.129400       0.109900
# max         0.293000       0.639600       4.660600       3.000500
#
#                 emg9          emg10     repetition   rerepetition  \
# count  101014.000000  101014.000000  101014.000000  101014.000000
# mean        0.073460       0.054120       3.372948       2.055349
# std         0.156381       0.112567       3.497555       3.188164
# min         0.000000       0.002400       0.000000       0.000000
# 25%         0.002400       0.004900       0.000000       0.000000
# 50%         0.002400       0.017100       2.000000       0.000000
# 75%         0.068400       0.048800       6.000000       4.000000
# max         1.752900       1.599100      10.000000      10.000000
#
#             stimulus     restimulus
# count  101014.000000  101014.000000
# mean        3.985665       2.329905
# std         4.162080       3.691976
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         3.000000       0.000000
# 75%         8.000000       4.000000
# max        12.000000      12.000000

# %%
print("Unique Dependent values and their counts :")
print(raw_data["stimulus"].value_counts())
# Out:
# Unique Dependent values and their counts :
# 0     39063
# 2      5174
# 4      5173
# 5      5173
# 12     5173
# 8      5172
# 7      5171
# 6      5170
# 11     5166
# 3      5158
# 1      5149
# 10     5137
# 9      5135
# Name: stimulus, dtype: int64

# %%
count_classes = pd.value_counts(raw_data['stimulus'], sort = True)

count_classes.plot(kind = 'bar', rot=0)

plt.title("stimulus Class Distribution")

plt.xlabel("Class")

plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # Data Cleaning and Exploratory Data Analysis with New Data

# %%
index_names = raw_data[ (raw_data['stimulus'] != raw_data['restimulus'])].index
raw_data.drop(index_names, inplace = True)
print(raw_data)
# Out:
#           emg1    emg2    emg3    emg4    emg5    emg6    emg7    emg8  \
# 0       0.0684  0.0024  0.0024  0.0024  0.0024  0.0098  0.0024  0.0488
# 1       0.0586  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0415
# 2       0.0562  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0391
# 3       0.0562  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0342
# 4       0.0488  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 101009  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0024  0.0366
# 101010  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0342
# 101011  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0342
# 101012  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# 101013  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0391
#
#           emg9   emg10  repetition  rerepetition  stimulus  restimulus
# 0       0.0024  0.0342           0             0         0           0
# 1       0.0024  0.0293           0             0         0           0
# 2       0.0024  0.0244           0             0         0           0
# 3       0.0024  0.0171           0             0         0           0
# 4       0.0024  0.0146           0             0         0           0
# ...        ...     ...         ...           ...       ...         ...
# 101009  0.0024  0.0024           0             0         0           0
# 101010  0.0024  0.0024           0             0         0           0
# 101011  0.0024  0.0073           0             0         0           0
# 101012  0.0024  0.0073           0             0         0           0
# 101013  0.0024  0.0024           0             0         0           0
#
# [75043 rows x 14 columns]

# %%
index_names = raw_data[ (raw_data['repetition'] != raw_data['rerepetition'])].index
raw_data.drop(index_names, inplace = True)
print(raw_data)
# Out:
#           emg1    emg2    emg3    emg4    emg5    emg6    emg7    emg8  \
# 0       0.0684  0.0024  0.0024  0.0024  0.0024  0.0098  0.0024  0.0488
# 1       0.0586  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0415
# 2       0.0562  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0391
# 3       0.0562  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0342
# 4       0.0488  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 101009  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0024  0.0366
# 101010  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0342
# 101011  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0342
# 101012  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# 101013  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0391
#
#           emg9   emg10  repetition  rerepetition  stimulus  restimulus
# 0       0.0024  0.0342           0             0         0           0
# 1       0.0024  0.0293           0             0         0           0
# 2       0.0024  0.0244           0             0         0           0
# 3       0.0024  0.0171           0             0         0           0
# 4       0.0024  0.0146           0             0         0           0
# ...        ...     ...         ...           ...       ...         ...
# 101009  0.0024  0.0024           0             0         0           0
# 101010  0.0024  0.0024           0             0         0           0
# 101011  0.0024  0.0073           0             0         0           0
# 101012  0.0024  0.0073           0             0         0           0
# 101013  0.0024  0.0024           0             0         0           0
#
# [75043 rows x 14 columns]

# %%
raw_data.sample(20)
# Out:
#          emg1    emg2    emg3    emg4    emg5    emg6    emg7    emg8    emg9  \
# 69438  0.1440  0.5908  0.0098  0.0024  0.0024  0.0024  0.2441  0.6104  0.1416
# 80673  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.1099  0.0610  0.0024
# 6457   0.0244  0.1953  0.0415  0.0049  0.0024  0.0024  0.2393  0.0830  0.1514
# 97605  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0098  0.0610  0.0024
# 43295  0.1294  0.4492  0.4761  0.1611  0.0024  0.0024  0.3442  0.3125  0.4126
# 51610  0.1611  0.0098  0.0366  0.0244  0.0024  0.0024  0.0464  0.0586  0.0684
# 16123  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0171  0.0024
# 96101  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0854  0.0684  0.0024
# 64749  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0293  0.0269  0.0024
# 47550  0.0171  0.1953  0.0366  0.0073  0.0024  0.0024  0.0024  0.1001  0.0806
# 94958  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366  0.0488  0.0024
# 44076  0.1172  0.5981  0.3223  0.1050  0.0049  0.0024  0.4126  0.2686  0.2441
# 89308  0.0024  0.0122  0.0024  0.0024  0.0024  0.0024  0.0342  0.0781  0.0098
# 41343  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.2417  0.0830  0.0024
# 26616  0.2539  1.1108  0.3833  0.0879  0.0708  0.1953  3.7061  0.9131  0.5786
# 61056  0.0732  0.0073  0.0024  0.0024  0.0024  0.0024  0.2612  0.2344  0.1099
# 95498  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0537  0.0513  0.0024
# 34671  0.0073  0.0024  0.0024  0.0024  0.0024  0.0024  0.1807  0.0684  0.0098
# 77676  0.2026  0.4712  0.5371  0.1538  0.0342  0.0146  0.7666  0.2148  0.0391
# 90644  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0122  0.0562  0.0024
#
#         emg10  repetition  rerepetition  stimulus  restimulus
# 69438  0.1147           3             3         9           9
# 80673  0.0049           0             0         0           0
# 6457   0.0317           8             8         1           1
# 97605  0.0098           0             0         0           0
# 43295  0.3149           2             2         6           6
# 51610  0.0977           2             2         7           7
# 16123  0.0024           0             0         0           0
# 96101  0.0146           5             5        12          12
# 64749  0.0342           0             0         0           0
# 47550  0.0439           7             7         6           6
# 94958  0.0146           0             0         0           0
# 44076  0.5151           3             3         6           6
# 89308  0.0049           7             7        11          11
# 41343  0.0244           0             0         0           0
# 26616  0.3101           2             2         4           4
# 61056  0.0464           3             3         8           8
# 95498  0.0269           4             4        12          12
# 34671  0.0586           0             0         0           0
# 77676  0.0903           3             3        10          10
# 90644  0.0024           0             0         0           0

# %%
raw_data.shape
# Out:
# (75043, 14)

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75043 entries, 0 to 101013
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   emg1          75043 non-null  float64
#  1   emg2          75043 non-null  float64
#  2   emg3          75043 non-null  float64
#  3   emg4          75043 non-null  float64
#  4   emg5          75043 non-null  float64
#  5   emg6          75043 non-null  float64
#  6   emg7          75043 non-null  float64
#  7   emg8          75043 non-null  float64
#  8   emg9          75043 non-null  float64
#  9   emg10         75043 non-null  float64
#  10  repetition    75043 non-null  int64
#  11  rerepetition  75043 non-null  int64
#  12  stimulus      75043 non-null  int64
#  13  restimulus    75043 non-null  int64
# dtypes: float64(10), int64(4)
# memory usage: 10.6 MB

# %%
print(raw_data.isnull().any())
# Out:
# emg1            False
# emg2            False
# emg3            False
# emg4            False
# emg5            False
# emg6            False
# emg7            False
# emg8            False
# emg9            False
# emg10           False
# repetition      False
# rerepetition    False
# stimulus        False
# restimulus      False
# dtype: bool

# %%
X = raw_data.iloc[:,0:10]
y = raw_data.stimulus

# %%
# Splitting data for training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 39)

# %% [markdown]
# # Importing Libraries of Deeplearning

# %%
import tensorflow as tf
import keras
from keras.layers import Dense
from keras.models import Sequential
from keras.layers import Dropout

from keras.callbacks import LearningRateScheduler

import numpy as np
from matplotlib import pyplot as plt

from sklearn.model_selection import GridSearchCV
from keras.constraints import maxnorm
from keras.optimizers import SGD

# %%
num_classes = 13

# %%
# One hot encoding for categorical labels
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
#Take a subset of train for grid search. Let us take 10% for now
from sklearn.model_selection import train_test_split
x_grid, x_not_use, y_grid, y_not_use = train_test_split(X_train, y_train, test_size=0.9, random_state=42)

# %%
# build the model
input_dim = x_grid.shape[1]

# %%
#NOTE: Add default optimizer, otherwise throws error 'optimizer not legal parameter'
def define_model(dropout_rate=0.0, weight_constraint=0, neurons=10,learning_rate=0.01, momentum=0.1):   
    model = Sequential()
    model.add(Dense(neurons, activation='relu', kernel_initializer='he_uniform', 
                    input_dim = input_dim, kernel_constraint=maxnorm(weight_constraint))) 
    model.add(Dropout(dropout_rate))
    model.add(Dense(neurons, kernel_initializer='he_uniform', activation='relu'))
    model.add(Dense(num_classes, kernel_initializer='he_uniform', activation='softmax'))
    optimizer = SGD(lr=learning_rate, momentum=momentum)
    # compile the model
    model.compile(loss='categorical_crossentropy',
                  optimizer=optimizer,      
                  metrics=['acc'])
    return model

# %%
# implement the Scikit-Learn classifier interface
# requires model defined as a function, which we already have
from keras.wrappers.scikit_learn import KerasClassifier

model = KerasClassifier(build_fn=define_model, 
                        verbose=1)

dropout_rate = [0.0, 0.2, 0.4]
weight_constraint = [1, 2, 3]
neurons = [10, 32, 64]
batch_size = [100, 200, 400]
epochs = [1, 5, 10]
learning_rate = [0.0001, 0.001, 0.01, 0.1]
momentum = [0.3, 0.5, 0.7, 0.9]

param_grid = dict(dropout_rate=dropout_rate, 
                  weight_constraint=weight_constraint,
                  neurons=neurons, batch_size=batch_size, 
                  epochs=epochs,learning_rate=learning_rate, momentum=momentum)

#n_jobs=16 uses 16 CPUs. Try not to do -1 on your system as it may hang!!!
# -1 refers to using all available CPUs
#Cross validation, cv=3
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=16, cv=3)

grid_result = grid.fit(x_grid, y_grid)
# Out:
# C:\Users\nafem\anaconda3\lib\site-packages\joblib\externals\loky\process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Epoch 1/10
# 61/61 [==============================] - 0s 3ms/step - loss: 1.4718 - acc: 0.6077
# Epoch 2/10
# 61/61 [==============================] - 0s 2ms/step - loss: 1.0791 - acc: 0.6998
# Epoch 3/10
# 61/61 [==============================] - 0s 2ms/step - loss: 0.9432 - acc: 0.7266
# Epoch 4/10
# 61/61 [==============================] - 0s 2ms/step - loss: 0.9443 - acc: 0.7278
# Epoch 5/10
# 61/61 [==============================] - 0s 2ms/step - loss: 0.8694 - acc: 0.7516
# Epoch 6/10
# 61/61 [==============================] - 0s 2ms/step - loss: 0.8782 - acc: 0.7468
# Epoch 7/10
# 61/61 [==============================] - 0s 2ms/step - loss: 0.8352 - acc: 0.7588
# Epoch 8/10
# 61/61 [==============================] - 0s 2ms/step - loss: 0.8394 - acc: 0.7536
# Epoch 9/10
# 61/61 [==============================] - 0s 3ms/step - loss: 0.8332 - acc: 0.7626
# Epoch 10/10
# 61/61 [==============================] - 0s 2ms/step - loss: 0.7871 - acc: 0.7711

# %%
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("Mean = %f (std=%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.758454 using {'batch_size': 100, 'dropout_rate': 0.2, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.099783 (std=0.077740) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.070798 (std=0.056679) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.052307 (std=0.011715) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.183575 (std=0.110695) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.029818 (std=0.015868) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.034816 (std=0.003063) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.068966 (std=0.048416) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.049975 (std=0.014842) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.170581 (std=0.197143) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.195069 (std=0.181685) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.056805 (std=0.022126) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.114943 (std=0.124039) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.153090 (std=0.035862) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.091621 (std=0.034634) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.121772 (std=0.083489) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.164418 (std=0.128639) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.207230 (std=0.239359) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.198401 (std=0.211628) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.256705 (std=0.144125) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.203232 (std=0.230283) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.087123 (std=0.046995) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.370815 (std=0.198282) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.133600 (std=0.061519) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.190405 (std=0.178468) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.299850 (std=0.182034) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.045477 (std=0.008549) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.044478 (std=0.018448) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.383808 (std=0.137856) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.175745 (std=0.025795) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.288522 (std=0.066748) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.223555 (std=0.070610) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.144261 (std=0.016875) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.216558 (std=0.050369) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.390805 (std=0.086578) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.202565 (std=0.040407) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.166750 (std=0.040016) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.0001, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.402465 (std=0.087689) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.445444 (std=0.045720) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.358321 (std=0.035288) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.457605 (std=0.040176) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.352824 (std=0.084256) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.472430 (std=0.036365) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.390305 (std=0.067097) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.383642 (std=0.102602) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.464101 (std=0.019916) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.430285 (std=0.069396) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.468432 (std=0.024368) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.510578 (std=0.010138) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.515409 (std=0.021030) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.424621 (std=0.086425) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.440613 (std=0.099194) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.501249 (std=0.020850) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.379977 (std=0.027080) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.470765 (std=0.029186) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.519740 (std=0.019191) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.460436 (std=0.045006) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.466267 (std=0.017688) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.510078 (std=0.022514) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.482592 (std=0.031386) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.470098 (std=0.047203) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.509079 (std=0.015313) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.492754 (std=0.044218) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.496752 (std=0.043912) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.533067 (std=0.006482) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.503582 (std=0.011296) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.508079 (std=0.005804) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.542562 (std=0.016746) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.490255 (std=0.024645) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.527403 (std=0.012944) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.509412 (std=0.012148) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.527403 (std=0.026895) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.522905 (std=0.006795) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.001, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.511578 (std=0.012298) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.520073 (std=0.007724) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.511578 (std=0.014196) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.509579 (std=0.014031) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.513077 (std=0.008755) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.516242 (std=0.016977) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.509912 (std=0.013923) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.535232 (std=0.013795) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.529735 (std=0.014282) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.526403 (std=0.016491) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.517741 (std=0.010003) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.509745 (std=0.014188) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.526237 (std=0.031313) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.516575 (std=0.014161) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.510745 (std=0.013077) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.511244 (std=0.015114) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.516408 (std=0.011072) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.525571 (std=0.007550) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.508412 (std=0.013199) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.514909 (std=0.012466) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.512744 (std=0.017230) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.511744 (std=0.015597) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.510245 (std=0.014282) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.517075 (std=0.021846) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.509245 (std=0.012383) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.520406 (std=0.023159) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.519740 (std=0.016301) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.509745 (std=0.014188) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.512077 (std=0.014347) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.510578 (std=0.014894) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.510245 (std=0.013153) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.518741 (std=0.015903) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.518741 (std=0.008780) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.524904 (std=0.009361) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.536565 (std=0.020128) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.540063 (std=0.022254) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.01, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.513910 (std=0.018513) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.517908 (std=0.013262) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.509412 (std=0.011786) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.537565 (std=0.011027) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.564218 (std=0.020682) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.564051 (std=0.024086) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.559887 (std=0.009693) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.577711 (std=0.015761) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.587206 (std=0.031427) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.523238 (std=0.017655) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.523238 (std=0.010411) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.510411 (std=0.014883) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.568882 (std=0.021220) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.560220 (std=0.018298) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.550391 (std=0.022096) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.571548 (std=0.019387) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.602865 (std=0.017946) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.615692 (std=0.020143) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.535732 (std=0.013077) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.523572 (std=0.011644) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.534733 (std=0.016183) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.559554 (std=0.012257) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.585707 (std=0.021672) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.589705 (std=0.002272) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.619190 (std=0.021719) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.637681 (std=0.007079) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.618357 (std=0.005570) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.586040 (std=0.004087) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.580043 (std=0.005570) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.577545 (std=0.020832) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.565051 (std=0.004401) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.651008 (std=0.014266) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.620023 (std=0.011892) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.634516 (std=0.021593) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.672330 (std=0.010334) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.641013 (std=0.015999) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 1, 'learning_rate': 0.1, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.274196 (std=0.107110) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.129768 (std=0.057258) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.419790 (std=0.170039) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.255372 (std=0.033217) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.123105 (std=0.018066) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.216725 (std=0.077266) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.302515 (std=0.063933) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.236215 (std=0.130875) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.249209 (std=0.096311) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.344494 (std=0.070137) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.411961 (std=0.131189) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.364484 (std=0.064505) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.480926 (std=0.030317) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.418457 (std=0.046292) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.513910 (std=0.019214) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.378644 (std=0.083282) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.279693 (std=0.110032) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.218891 (std=0.090438) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.474263 (std=0.036957) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.475096 (std=0.080853) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.453440 (std=0.035809) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.426120 (std=0.067866) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.437615 (std=0.043095) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.332500 (std=0.017713) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.445444 (std=0.058446) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.398967 (std=0.104156) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.317008 (std=0.079503) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.509079 (std=0.023069) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.501749 (std=0.021730) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.501083 (std=0.026913) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.511744 (std=0.014831) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.500750 (std=0.025778) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.463268 (std=0.050803) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.510911 (std=0.031428) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.513577 (std=0.017120) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.515742 (std=0.009349) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.0001, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.499250 (std=0.008837) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.496418 (std=0.015427) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.520073 (std=0.027799) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.521406 (std=0.011207) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.545227 (std=0.019701) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.509579 (std=0.004495) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.540896 (std=0.026771) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.524238 (std=0.026532) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.498251 (std=0.040254) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.518907 (std=0.006546) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.530068 (std=0.019833) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.515576 (std=0.008952) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.517908 (std=0.011020) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.523572 (std=0.024162) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.519240 (std=0.009895) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.531568 (std=0.001885) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.532567 (std=0.012107) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.528569 (std=0.028940) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.522072 (std=0.003565) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.520073 (std=0.012352) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.524738 (std=0.026561) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.508579 (std=0.013312) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.522239 (std=0.017674) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.518574 (std=0.011644) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.509079 (std=0.012957) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.525071 (std=0.014336) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.543728 (std=0.012826) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.508412 (std=0.013199) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.515909 (std=0.018584) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.511078 (std=0.014137) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.515076 (std=0.019511) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.526070 (std=0.006596) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.514243 (std=0.005336) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.511244 (std=0.009928) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.516575 (std=0.012880) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.527570 (std=0.021109) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.001, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.509579 (std=0.011551) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.509745 (std=0.012383) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.516742 (std=0.010003) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.513077 (std=0.015620) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.531901 (std=0.013350) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.533567 (std=0.011110) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.523405 (std=0.014961) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.544728 (std=0.005756) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.535066 (std=0.016526) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.514909 (std=0.019485) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.518741 (std=0.020512) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.515076 (std=0.017486) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.517075 (std=0.015593) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.529735 (std=0.017446) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.540230 (std=0.009802) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.541896 (std=0.010261) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.566383 (std=0.005199) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.558221 (std=0.012022) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.516742 (std=0.003892) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.534899 (std=0.019357) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.515242 (std=0.004598) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.549559 (std=0.008717) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.568549 (std=0.014782) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.569049 (std=0.002623) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.580710 (std=0.009903) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.614026 (std=0.009711) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.605031 (std=0.006596) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.539230 (std=0.003340) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.525737 (std=0.006742) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.551391 (std=0.028843) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.621523 (std=0.003857) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.646677 (std=0.015966) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.640347 (std=0.006881) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.660170 (std=0.015586) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.680160 (std=0.015549) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.688822 (std=0.012052) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.01, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.558221 (std=0.039895) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.594703 (std=0.031228) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.560553 (std=0.044763) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.465101 (std=0.214914) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.656339 (std=0.003921) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.629852 (std=0.007979) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.651508 (std=0.008494) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.675162 (std=0.028729) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.501749 (std=0.227155) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.426287 (std=0.231575) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.625854 (std=0.019672) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.569382 (std=0.026740) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.651841 (std=0.007405) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.678328 (std=0.016425) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.519574 (std=0.235461) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.677495 (std=0.004586) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.704481 (std=0.015039) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.706647 (std=0.003892) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.449442 (std=0.211858) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.640680 (std=0.025140) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.641679 (std=0.025276) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.679160 (std=0.004544) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.548559 (std=0.232806) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.683325 (std=0.026574) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.678661 (std=0.030971) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.522739 (std=0.209517) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.588539 (std=0.187439) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.582875 (std=0.026540) with: {'batch_size': 100, 'dropout_rate': 0.0, 'epochs': 5, 'learning_rate': 0.1, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 1}
# ...
# Mean = 0.515742 (std=0.016789) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.001, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.515242 (std=0.021265) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.001, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.507746 (std=0.023782) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.001, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.516742 (std=0.016967) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.001, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.525571 (std=0.025369) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.001, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.520573 (std=0.008164) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.001, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.512077 (std=0.008174) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.001, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.525237 (std=0.007557) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.001, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.504248 (std=0.010103) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.001, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.511244 (std=0.014931) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.001, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.523738 (std=0.022241) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.001, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.515409 (std=0.018363) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.001, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.514576 (std=0.017974) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.001, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.508412 (std=0.013199) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.001, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.517408 (std=0.014894) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.001, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.508746 (std=0.013077) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.001, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.514576 (std=0.008366) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.001, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.512077 (std=0.015915) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.001, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.511411 (std=0.008961) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.001, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.513743 (std=0.006361) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.001, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.516575 (std=0.017816) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.001, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.508746 (std=0.012728) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.510911 (std=0.015678) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.514576 (std=0.008952) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.508579 (std=0.013312) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.510078 (std=0.013350) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.509245 (std=0.013077) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.509079 (std=0.013664) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.517575 (std=0.019442) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.522072 (std=0.015215) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.508412 (std=0.013199) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.508579 (std=0.013325) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.510578 (std=0.014894) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.508746 (std=0.012728) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.510578 (std=0.013761) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.508746 (std=0.013435) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.511411 (std=0.015061) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.525071 (std=0.009326) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.530901 (std=0.002623) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.510411 (std=0.013350) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.508412 (std=0.013199) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.509079 (std=0.012257) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.516908 (std=0.003657) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.529069 (std=0.015721) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.515076 (std=0.017979) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.533067 (std=0.014090) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.538064 (std=0.009736) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.540396 (std=0.011892) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.512910 (std=0.012121) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.527570 (std=0.013193) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.515576 (std=0.018674) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.552557 (std=0.008793) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.553723 (std=0.002159) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.547560 (std=0.007036) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.597201 (std=0.008491) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.610528 (std=0.008802) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.629352 (std=0.011428) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.01, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.542229 (std=0.009005) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.524904 (std=0.024862) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.533900 (std=0.025549) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.3, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.580043 (std=0.016496) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.599867 (std=0.004550) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.601699 (std=0.012166) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.3, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.623688 (std=0.011770) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.659337 (std=0.001027) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.636182 (std=0.008151) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.3, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.543395 (std=0.004108) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.531901 (std=0.010114) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.541896 (std=0.020141) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.5, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.589039 (std=0.005775) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.600866 (std=0.028153) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.631518 (std=0.010204) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.5, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.621689 (std=0.010695) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.636682 (std=0.014931) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.664668 (std=0.021277) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.5, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.560553 (std=0.027510) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.572214 (std=0.008856) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.563552 (std=0.014284) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.7, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.629019 (std=0.006193) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.640680 (std=0.017355) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.645344 (std=0.009432) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.7, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.651341 (std=0.016736) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.670665 (std=0.018171) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.681659 (std=0.033258) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.7, 'neurons': 64, 'weight_constraint': 3}
# Mean = 0.551724 (std=0.028297) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 1}
# Mean = 0.547060 (std=0.017552) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 2}
# Mean = 0.590205 (std=0.011182) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.9, 'neurons': 10, 'weight_constraint': 3}
# Mean = 0.619690 (std=0.010703) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 1}
# Mean = 0.659337 (std=0.008020) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 2}
# Mean = 0.662002 (std=0.014423) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.9, 'neurons': 32, 'weight_constraint': 3}
# Mean = 0.665167 (std=0.015262) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 1}
# Mean = 0.709812 (std=0.004868) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 2}
# Mean = 0.696652 (std=0.021944) with: {'batch_size': 400, 'dropout_rate': 0.4, 'epochs': 10, 'learning_rate': 0.1, 'momentum': 0.9, 'neurons': 64, 'weight_constraint': 3}
